# %%
# !git clone https://github.com/huggingface/transformers.js-examples.git
# Out:
# Cloning into 'transformers.js-examples'...
# remote: Enumerating objects: 1459, done.
# remote: Counting objects: 100% (472/472), done.
# remote: Compressing objects: 100% (149/149), done.
# remote: Total 1459 (delta 368), reused 353 (delta 323), pack-reused 987 (from 3)
# Receiving objects: 100% (1459/1459), 32.70 MiB | 17.24 MiB/s, done.
# Resolving deltas: 100% (829/829), done.

# %%
# %cd transformers.js-examples/deepseek-r1-webgpu
# Out:
# /content/transformers.js-examples/deepseek-r1-webgpu

# %%
# !npm i
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴
# added 353 packages, and audited 354 packages in 28s
# ⠴
# ⠴127 packages are looking for funding
# ⠴  run `npm fund` for details
# ⠴
# found 0 vulnerabilities
# ⠴

# %%
# !npm run dev
# Out:
# > deepseek-r1-webgpu@0.0.0 dev
# > vite
#
#
#
#   VITE v6.0.11  ready in 577 ms
#
#   ➜  Local:   http://localhost:5173/
#   ➜  Network: use --host to expose
#   ➜  press h + enter to show help
# ^C

# %%
# !git clone https://github.com/huggingface/transformers.js-examples.git
# %cd transformers.js-examples/deepseek-r1-webgpu
# !npm i
# !npm run dev

# %%
# !npm install @eslint/js globals eslint-plugin-react eslint-plugin-react-hooks eslint-plugin-react-refresh
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴
# added 1 package, changed 3 packages, and audited 355 packages in 2s
# ⠴
# ⠴127 packages are looking for funding
# ⠴  run `npm fund` for details
# ⠴
# found 0 vulnerabilities
# ⠴

# %%
# !node /content/transformers.js-examples/deepseek-r1-webgpu/eslint.config.js

# %%
# !npm install
# Out:
# ⠙⠹⠸⠼⠴⠦
# up to date, audited 355 packages in 1s
# ⠦
# ⠦127 packages are looking for funding
# ⠦  run `npm fund` for details
# ⠦
# found 0 vulnerabilities
# ⠦

# %%
# !npm run dev
# Out:
# > deepseek-r1-webgpu@0.0.0 dev
# > vite
#
# Re-optimizing dependencies because lockfile has changed
#
#   VITE v6.0.11  ready in 564 ms
#
#   ➜  Local:   http://localhost:5173/
#   ➜  Network: use --host to expose
#   ➜  press h + enter to show help
# ^C

# %%
# !!npm install -g localtunnel
# !lt --port 5173

# %%
# !npm install -g localtunnel
# !lt --port 5173
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏
# changed 22 packages in 2s
# ⠋
# ⠋3 packages are looking for funding
# ⠋  run `npm fund` for details
# ⠋^C

# %%
# !wget -q -O - https://loca.lt/mytunnelpassword
# Out:
# ^C

# %%
# !curl https://loca.lt/mytunnelpassword
# Out:
# ^C

# %%
# !echo $PASSWORD

# %%
# !pip install pyngrok
# !ngrok http 5173
# Out:
# ...
# ERROR: Operation cancelled by user
# /bin/bash: line 1: ngrok: command not found

# %%
# !pip install gradio
import gradio as gr

# إعداد الواجهة
...
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.8/57.8 MB 14.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 321.9/321.9 kB 30.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.8/94.8 kB 9.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.5/12.5 MB 117.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 kB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 6.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: markupsafe
#     Found existing installation: MarkupSafe 3.0.2
#     Uninstalling MarkupSafe-3.0.2:
#       Successfully uninstalled MarkupSafe-3.0.2
# ...
# Ellipsis

# %%
import { useEffect, useState, useRef } from "react";

import Chat from "./components/Chat";
import ArrowRightIcon from "./components/icons/ArrowRightIcon";
import StopIcon from "./components/icons/StopIcon";
import Progress from "./components/Progress";

const IS_WEBGPU_AVAILABLE = !!navigator.gpu;
const STICKY_SCROLL_THRESHOLD = 120;
const EXAMPLES = [
  "Solve the equation x^2 - 3x + 2 = 0",
  "Lily is three times older than her son. In 15 years, she will be twice as old as him. How old is she now?",
  "Write python code to compute the nth fibonacci number.",
];

function App() {
  // Create a reference to the worker object.
  const worker = useRef(null);

  const textareaRef = useRef(null);
  const chatContainerRef = useRef(null);

  // Model loading and progress
  const [status, setStatus] = useState(null);
  const [error, setError] = useState(null);
  const [loadingMessage, setLoadingMessage] = useState("");
  const [progressItems, setProgressItems] = useState([]);
  const [isRunning, setIsRunning] = useState(false);

  // Inputs and outputs
  const [input, setInput] = useState("");
  const [messages, setMessages] = useState([]);
  const [tps, setTps] = useState(null);
  const [numTokens, setNumTokens] = useState(null);

  function onEnter(message) {
    setMessages((prev) => [...prev, { role: "user", content: message }]);
    setTps(null);
    setIsRunning(true);
    setInput("");
  }

  function onInterrupt() {
    // NOTE: We do not set isRunning to false here because the worker
    // will send a 'complete' message when it is done.
    worker.current.postMessage({ type: "interrupt" });
  }

  useEffect(() => {
    resizeInput();
  }, [input]);

  function resizeInput() {
    if (!textareaRef.current) return;

    const target = textareaRef.current;
    target.style.height = "auto";
    const newHeight = Math.min(Math.max(target.scrollHeight, 24), 200);
    target.style.height = `${newHeight}px`;
  }

  // We use the `useEffect` hook to setup the worker as soon as the `App` component is mounted.
  useEffect(() => {
    // Create the worker if it does not yet exist.
    if (!worker.current) {
      worker.current = new Worker(new URL("./worker.js", import.meta.url), {
        type: "module",
      });
      worker.current.postMessage({ type: "check" }); // Do a feature check
    }

    // Create a callback function for messages from the worker thread.
    const onMessageReceived = (e) => {
      switch (e.data.status) {
        case "loading":
          // Model file start load: add a new progress item to the list.
          setStatus("loading");
          setLoadingMessage(e.data.data);
          break;

        case "initiate":
          setProgressItems((prev) => [...prev, e.data]);
          break;

        case "progress":
          // Model file progress: update one of the progress items.
          setProgressItems((prev) =>
            prev.map((item) => {
              if (item.file === e.data.file) {
                return { ...item, ...e.data };
              }
              return item;
            }),
          );
          break;

        case "done":
          // Model file loaded: remove the progress item from the list.
          setProgressItems((prev) =>
            prev.filter((item) => item.file !== e.data.file),
          );
          break;

        case "ready":
          // Pipeline ready: the worker is ready to accept messages.
          setStatus("ready");
          break;

        case "start":
          {
            // Start generation
            setMessages((prev) => [
              ...prev,
              { role: "assistant", content: "" },
            ]);
          }
          break;

        case "update":
          {
            // Generation update: update the output text.
            // Parse messages
            const { output, tps, numTokens, state } = e.data;
            setTps(tps);
            setNumTokens(numTokens);
            setMessages((prev) => {
              const cloned = [...prev];
              const last = cloned.at(-1);
              const data = {
                ...last,
                content: last.content + output,
              };
              if (data.answerIndex === undefined && state === "answering") {
                // When state changes to answering, we set the answerIndex
                data.answerIndex = last.content.length;
              }
              cloned[cloned.length - 1] = data;
              return cloned;
            });
          }
          break;

        case "complete":
          // Generation complete: re-enable the "Generate" button
          setIsRunning(false);
          break;

        case "error":
          setError(e.data.data);
          break;
      }
    };

    const onErrorReceived = (e) => {
      console.error("Worker error:", e);
    };

    // Attach the callback function as an event listener.
    worker.current.addEventListener("message", onMessageReceived);
    worker.current.addEventListener("error", onErrorReceived);

    // Define a cleanup function for when the component is unmounted.
    return () => {
      worker.current.removeEventListener("message", onMessageReceived);
      worker.current.removeEventListener("error", onErrorReceived);
    };
  }, []);

  // Send the messages to the worker thread whenever the `messages` state changes.
  useEffect(() => {
    if (messages.filter((x) => x.role === "user").length === 0) {
      // No user messages yet: do nothing.
      return;
    }
    if (messages.at(-1).role === "assistant") {
      // Do not update if the last message is from the assistant
      return;
    }
    setTps(null);
    worker.current.postMessage({ type: "generate", data: messages });
  }, [messages, isRunning]);

  useEffect(() => {
    if (!chatContainerRef.current || !isRunning) return;
    const element = chatContainerRef.current;
    if (
      element.scrollHeight - element.scrollTop - element.clientHeight <
      STICKY_SCROLL_THRESHOLD
    ) {
      element.scrollTop = element.scrollHeight;
    }
  }, [messages, isRunning]);

  return IS_WEBGPU_AVAILABLE ? (
    <div className="flex flex-col h-screen mx-auto items justify-end text-gray-800 dark:text-gray-200 bg-white dark:bg-gray-900">
      {status === null && messages.length === 0 && (
        <div className="h-full overflow-auto scrollbar-thin flex justify-center items-center flex-col relative">
          <div className="flex flex-col items-center mb-1 max-w-[400px] text-center">
            <img
              src="logo.png"
              width="80%"
              height="auto"
              className="block drop-shadow-lg bg-transparent"
            ></img>
            <h1 className="text-4xl font-bold mb-1">DeepSeek-R1 WebGPU</h1>
            <h2 className="font-semibold">
              A next-generation reasoning model that runs locally in your
              browser with WebGPU acceleration.
            </h2>
          </div>

          <div className="flex flex-col items-center px-4">
            <p className="max-w-[510px] mb-4">
              <br />
              You are about to load{" "}
              <a
                href="https://huggingface.co/onnx-community/DeepSeek-R1-Distill-Qwen-1.5B-ONNX"
                target="_blank"
                rel="noreferrer"
                className="font-medium underline"
              >
                DeepSeek-R1-Distill-Qwen-1.5B
              </a>
              , a 1.5B parameter reasoning LLM optimized for in-browser
              inference. Everything runs entirely in your browser with{" "}
              <a
                href="https://huggingface.co/docs/transformers.js"
                target="_blank"
                rel="noreferrer"
                className="underline"
              >
                🤗&nbsp;Transformers.js
              </a>{" "}
              and ONNX Runtime Web, meaning no data is sent to a server. Once
              loaded, it can even be used offline. The source code for the demo
              is available on{" "}
              <a
                href="https://github.com/huggingface/transformers.js-examples/tree/main/deepseek-r1-webgpu"
                target="_blank"
                rel="noreferrer"
                className="font-medium underline"
              >
                GitHub
              </a>
              .
            </p>

            {error && (
              <div className="text-red-500 text-center mb-2">
                <p className="mb-1">
                  Unable to load model due to the following error:
                </p>
                <p className="text-sm">{error}</p>
              </div>
            )}

            <button
              className="border px-4 py-2 rounded-lg bg-blue-400 text-white hover:bg-blue-500 disabled:bg-blue-100 cursor-pointer disabled:cursor-not-allowed select-none"
              onClick={() => {
                worker.current.postMessage({ type: "load" });
                setStatus("loading");
              }}
              disabled={status !== null || error !== null}
            >
              Load model
            </button>
          </div>
        </div>
      )}
      {status === "loading" && (
        <>
          <div className="w-full max-w-[500px] text-left mx-auto p-4 bottom-0 mt-auto">
            <p className="text-center mb-1">{loadingMessage}</p>
            {progressItems.map(({ file, progress, total }, i) => (
              <Progress
                key={i}
                text={file}
                percentage={progress}
                total={total}
              />
            ))}
          </div>
        </>
      )}

      {status === "ready" && (
        <div
          ref={chatContainerRef}
          className="overflow-y-auto scrollbar-thin w-full flex flex-col items-center h-full"
        >
          <Chat messages={messages} />
          {messages.length === 0 && (
            <div>
              {EXAMPLES.map((msg, i) => (
                <div
                  key={i}
                  className="m-1 border border-gray-300 dark:border-gray-600 rounded-md p-2 bg-gray-100 dark:bg-gray-700 cursor-pointer"
                  onClick={() => onEnter(msg)}
                >
                  {msg}
                </div>
              ))}
            </div>
          )}
          <p className="text-center text-sm min-h-6 text-gray-500 dark:text-gray-300">
            {tps && messages.length > 0 && (
              <>
                {!isRunning && (
                  <span>
                    Generated {numTokens} tokens in{" "}
                    {(numTokens / tps).toFixed(2)} seconds&nbsp;&#40;
                  </span>
                )}
                {
                  <>
                    <span className="font-medium text-center mr-1 text-black dark:text-white">
                      {tps.toFixed(2)}
                    </span>
                    <span className="text-gray-500 dark:text-gray-300">
                      tokens/second
                    </span>
                  </>
                }
                {!isRunning && (
                  <>
                    <span className="mr-1">&#41;.</span>
                    <span
                      className="underline cursor-pointer"
                      onClick={() => {
                        worker.current.postMessage({ type: "reset" });
                        setMessages([]);
                      }}
                    >
                      Reset
                    </span>
                  </>
                )}
              </>
            )}
          </p>
        </div>
      )}

      <div className="mt-2 border border-gray-300 dark:bg-gray-700 rounded-lg w-[600px] max-w-[80%] max-h-[200px] mx-auto relative mb-3 flex">
        <textarea
          ref={textareaRef}
          className="scrollbar-thin w-[550px] dark:bg-gray-700 px-3 py-4 rounded-lg bg-transparent border-none outline-hidden text-gray-800 disabled:text-gray-400 dark:text-gray-200 placeholder-gray-500 dark:placeholder-gray-400 disabled:placeholder-gray-200 resize-none disabled:cursor-not-allowed"
          placeholder="Type your message..."
          type="text"
          rows={1}
          value={input}
          disabled={status !== "ready"}
          title={status === "ready" ? "Model is ready" : "Model not loaded yet"}
          onKeyDown={(e) => {
            if (
              input.length > 0 &&
              # !isRunning &&
              e.key === "Enter" &&
              # !e.shiftKey
            ) {
              e.preventDefault(); // Prevent default behavior of Enter key
              onEnter(input);
            }
          }}
          onInput={(e) => setInput(e.target.value)}
        />
        {isRunning ? (
          <div className="cursor-pointer" onClick={onInterrupt}>
            <StopIcon className="h-8 w-8 p-1 rounded-md text-gray-800 dark:text-gray-100 absolute right-3 bottom-3" />
          </div>
        ) : input.length > 0 ? (
          <div className="cursor-pointer" onClick={() => onEnter(input)}>
            <ArrowRightIcon
              className={`h-8 w-8 p-1 bg-gray-800 dark:bg-gray-100 text-white dark:text-black rounded-md absolute right-3 bottom-3`}
            />
          </div>
        ) : (
          <div>
            <ArrowRightIcon
              className={`h-8 w-8 p-1 bg-gray-200 dark:bg-gray-600 text-gray-50 dark:text-gray-800 rounded-md absolute right-3 bottom-3`}
            />
          </div>
        )}
      </div>

      <p className="text-xs text-gray-400 text-center mb-3">
        Disclaimer: Generated content may be inaccurate or false.
      </p>
    </div>
  ) : (
    <div className="fixed w-screen h-screen bg-black z-10 bg-opacity-[92%] text-white text-2xl font-semibold flex justify-center items-center text-center">
      WebGPU is not supported
      <br />
      by this browser :&#40;
    </div>
  );
}

export default App;

# %%
# !npm install -g yarn
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧
# added 1 package in 2s
# ⠧

# %%
# !npm run dev
# Out:
# > deepseek-r1-webgpu@0.0.0 dev
# > vite
#
#
#
#   VITE v6.0.11  ready in 550 ms
#
#   ➜  Local:   http://localhost:5173/
#   ➜  Network: use --host to expose
#   ➜  press h + enter to show help
# ^C

# %%
# !yarn dev
# Out:
# yarn run v1.22.22
# $ vite
#
#
#   VITE v6.0.11  ready in 641 ms
#
#   ➜  Local:   http://localhost:5173/
#   ➜  Network: use --host to expose
#   ➜  press h + enter to show help
# ^C

# %%
# !npm i @huggingface/transformers
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸
# changed 6 packages, and audited 355 packages in 11s
# ⠸
# ⠸127 packages are looking for funding
# ⠸  run `npm fund` for details
# ⠸
# found 0 vulnerabilities
# ⠸

# %%
import { pipeline, TextStreamer } from "@huggingface/transformers";

// Create a text generation pipeline
const generator = await pipeline(
  "text-generation",
  "onnx-community/DeepSeek-R1-Distill-Qwen-1.5B-ONNX",
  { dtype: "q4f16" },
);

// Define the list of messages
const messages = [
  { role: "user", content:  "Solve the equation: x^2 - 3x + 2 = 0" },
];

// Create text streamer
const streamer = new TextStreamer(generator.tokenizer, {
  skip_prompt: true,
  // callback_function: (text) => { }, // Optional callback function
})

// Generate a response
const output = await generator(messages, { max_new_tokens: 512, do_sample: false, streamer });
console.log(output[0].generated_text.at(-1).content);

# %%
# !node /content/1.mjs
# Out:
# node:internal/errors:496
#     ErrorCaptureStackTrace(err);
#     ^
#
# Error [ERR_MODULE_NOT_FOUND]: Cannot find package '@huggingface/transformers' imported from /content/1.mjs
#     at new NodeError (node:internal/errors:405:5)
#     at packageResolve (node:internal/modules/esm/resolve:916:9)
#     at moduleResolve (node:internal/modules/esm/resolve:973:20)
#     at defaultResolve (node:internal/modules/esm/resolve:1206:11)
#     at ModuleLoader.defaultResolve (node:internal/modules/esm/loader:404:12)
#     at ModuleLoader.resolve (node:internal/modules/esm/loader:373:25)
#     at ModuleLoader.getModuleJob (node:internal/modules/esm/loader:250:38)
#     at ModuleWrap.<anonymous> (node:internal/modules/esm/module_job:76:39)
#     at link (node:internal/modules/esm/module_job:75:36) {
#   code: 'ERR_MODULE_NOT_FOUND'
# }
#
# Node.js v18.20.5

# %%
# !node /content/1mjs.mjs
# Out:
# node:internal/modules/cjs/loader:1143
#   throw err;
#   ^
#
# Error: Cannot find module '/content/1mjs.mjs'
#     at Module._resolveFilename (node:internal/modules/cjs/loader:1140:15)
#     at Module._load (node:internal/modules/cjs/loader:981:27)
#     at Function.executeUserEntryPoint [as runMain] (node:internal/modules/run_main:128:12)
#     at node:internal/main/run_main_module:28:49 {
#   code: 'MODULE_NOT_FOUND',
#   requireStack: []
# }
#
# Node.js v18.20.5

# %%
# !npm install @huggingface/transformers
# Out:
# ⠙⠹⠸⠼⠴⠦
# up to date, audited 355 packages in 2s
# ⠦
# ⠦127 packages are looking for funding
# ⠦  run `npm fund` for details
# ⠦
# found 0 vulnerabilities
# ⠦

# %%
# !yarn add @huggingface/transformers
# Out:
# yarn add v1.22.22
# info No lockfile found.
# warning package-lock.json found. Your project contains lock files generated by tools other than Yarn. It is advised not to mix package managers in order to avoid resolution inconsistencies caused by unsynchronized lock files. To clear this warning, remove package-lock.json.
# [1/4] Resolving packages...
# [2/4] Fetching packages...
# ...

# %%
# !npm list @huggingface/transformers
# Out:
# ⠙⠹⠸deepseek-r1-webgpu@0.0.0 /content/transformers.js-examples/deepseek-r1-webgpu
# └── @huggingface/transformers@3.3.3
#
# ⠼

# %%
# !node /content/1.mjs
# Out:
# node:internal/errors:496
#     ErrorCaptureStackTrace(err);
#     ^
#
# Error [ERR_MODULE_NOT_FOUND]: Cannot find package '@huggingface/transformers' imported from /content/1.mjs
#     at new NodeError (node:internal/errors:405:5)
#     at packageResolve (node:internal/modules/esm/resolve:916:9)
#     at moduleResolve (node:internal/modules/esm/resolve:973:20)
#     at defaultResolve (node:internal/modules/esm/resolve:1206:11)
#     at ModuleLoader.defaultResolve (node:internal/modules/esm/loader:404:12)
#     at ModuleLoader.resolve (node:internal/modules/esm/loader:373:25)
#     at ModuleLoader.getModuleJob (node:internal/modules/esm/loader:250:38)
#     at ModuleWrap.<anonymous> (node:internal/modules/esm/module_job:76:39)
#     at link (node:internal/modules/esm/module_job:75:36) {
#   code: 'ERR_MODULE_NOT_FOUND'
# }
#
# Node.js v18.20.5

# %%
# !npm i onnxruntime-web
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦
# added 10 packages, removed 16 packages, changed 60 packages, and audited 355 packages in 6s
# ⠦
# ⠦127 packages are looking for funding
# ⠦  run `npm fund` for details
# ⠦
# found 0 vulnerabilities
# ⠦

# %%
# !node /content/1.mjs
# Out:
# node:internal/errors:496
#     ErrorCaptureStackTrace(err);
#     ^
#
# Error [ERR_MODULE_NOT_FOUND]: Cannot find package '@huggingface/transformers' imported from /content/1.mjs
#     at new NodeError (node:internal/errors:405:5)
#     at packageResolve (node:internal/modules/esm/resolve:916:9)
#     at moduleResolve (node:internal/modules/esm/resolve:973:20)
#     at defaultResolve (node:internal/modules/esm/resolve:1206:11)
#     at ModuleLoader.defaultResolve (node:internal/modules/esm/loader:404:12)
#     at ModuleLoader.resolve (node:internal/modules/esm/loader:373:25)
#     at ModuleLoader.getModuleJob (node:internal/modules/esm/loader:250:38)
#     at ModuleWrap.<anonymous> (node:internal/modules/esm/module_job:76:39)
#     at link (node:internal/modules/esm/module_job:75:36) {
#   code: 'ERR_MODULE_NOT_FOUND'
# }
#
# Node.js v18.20.5

# %%
# !npm install onnxruntime-web@dev
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙
# added 19 packages in 4s
# ⠙

# %%
# !node /content/1.mjs
# Out:
# node:internal/errors:496
#     ErrorCaptureStackTrace(err);
#     ^
#
# Error [ERR_MODULE_NOT_FOUND]: Cannot find package '@huggingface/transformers' imported from /content/1.mjs
#     at new NodeError (node:internal/errors:405:5)
#     at packageResolve (node:internal/modules/esm/resolve:916:9)
#     at moduleResolve (node:internal/modules/esm/resolve:973:20)
#     at defaultResolve (node:internal/modules/esm/resolve:1206:11)
#     at ModuleLoader.defaultResolve (node:internal/modules/esm/loader:404:12)
#     at ModuleLoader.resolve (node:internal/modules/esm/loader:373:25)
#     at ModuleLoader.getModuleJob (node:internal/modules/esm/loader:250:38)
#     at ModuleWrap.<anonymous> (node:internal/modules/esm/module_job:76:39)
#     at link (node:internal/modules/esm/module_job:75:36) {
#   code: 'ERR_MODULE_NOT_FOUND'
# }
#
# Node.js v18.20.5

# %%
# !npm init -y
# !npm i @huggingface/transformers
# Out:
# Wrote to /content/package.json:
#
# {
#   "dependencies": {
#     "onnxruntime-web": "^1.21.0-dev.20250206-d981b153d3"
#   },
#   "name": "content",
#   "version": "1.0.0",
#   "main": "index.js",
#   "devDependencies": {},
#   "scripts": {
#     "test": "echo \"Error: no test specified\" && exit 1"
#   },
#   "keywords": [],
#   "author": "",
#   "license": "ISC",
#   "description": ""
# }
#
#
#
# ⠙⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦
# added 61 packages, and audited 81 packages in 22s
# ⠦
# ⠦18 packages are looking for funding
# ⠦  run `npm fund` for details
# ⠦
# found 0 vulnerabilities
# ⠦

# %%
# !node /content/app.js

# %%
// Get the pipeline instance
const classificationPipeline = await MyClassificationPipeline.getInstance();

// Classify text
const result = await classificationPipeline("This is a positive sentence.");

// Display result
console.log(result);

# %%
import http from 'http';
import querystring from 'querystring';
import url from 'url';

import { pipeline, env } from '@huggingface/transformers';

class MyClassificationPipeline {
  static task = 'text-classification';
  static model = 'Xenova/distilbert-base-uncased-finetuned-sst-2-english';
  static instance = null;

  static async getInstance(progress_callback = null) {
    if (this.instance === null) {
      // NOTE: Uncomment this to change the cache directory
      // env.cacheDir = './.cache';

      this.instance = pipeline(this.task, this.model, { progress_callback });
    }

    return this.instance;
  }
}

async function classifyText() {
  // Get the pipeline instance
  const classificationPipeline = await MyClassificationPipeline.getInstance();

  // Classify text
  const result = await classificationPipeline("This is a positive sentence.");

  // Display result
  console.log(result);
}

classifyText(); // Call the function to execute

# %%
# !node /content/app.js
# Out:
# dtype not specified for "model". Using the default dtype (fp32) for this device (cpu).
# [ { label: 'POSITIVE', score: 0.9994041323661804 } ]

# %%
import http from 'http';
import querystring from 'querystring';
import url from 'url';

import { pipeline, env } from '@huggingface/transformers';

class MyClassificationPipeline {
  static task = 'text-generation'; // Changed task to text-generation
  static model = 'onnx-community/DeepSeek-R1-Distill-Qwen-1.5B-ONNX'; // Updated model
  static instance = null;

  static async getInstance(progress_callback = null) {
    if (this.instance === null) {
      // NOTE: Uncomment this to change the cache directory
      // env.cacheDir = './.cache';

      this.instance = pipeline(this.task, this.model, { progress_callback });
    }

    return this.instance;
  }
}

async function classifyText() {
  // Get the pipeline instance
  const classificationPipeline = await MyClassificationPipeline.getInstance();

  // Classify text (using text-generation now)
  const result = await classificationPipeline("This is a positive sentence.", {
    max_new_tokens: 50, // Adjust as needed
  });

  // Display result
  console.log(result);
}

classifyText(); // Call the function to execute

# %%
# !node 2.js

# %%
import http from 'http';
import querystring from 'querystring';
import url from 'url';

import { pipeline, env } from '@huggingface/transformers';

class MyClassificationPipeline {
  static task = 'text-generation';
  static model = 'onnx-community/DeepSeek-R1-Distill-Qwen-1.5B-ONNX';
  static instance = null;

  static async getInstance(progress_callback = null) {
    if (this.instance === null) {
      this.instance = pipeline(this.task, this.model, { progress_callback });
    }

    return this.instance;
  }
}

async function classifyText() {
  const classificationPipeline = await MyClassificationPipeline.getInstance();

  // Adjust the input and parameters for text generation
  const result = await classificationPipeline("This is a positive sentence.", {
    max_new_tokens: 50,
    // ... any other required parameters
  });

  console.log(result);
}

classifyText();

# %%
const generator = await pipeline(
  "text-generation",
  "onnx-community/DeepSeek-R1-Distill-Qwen-1.5B-ONNX",
  { dtype: "q4f16" },
);

# %%
# !node 2.js
# Out:
# 2025-02-11 00:51:42.159742892 [E:onnxruntime:, sequential_executor.cc:516 ExecuteKernel] Non-zero status code returned while running Cast node. Name:'InsertedPrecisionFreeCast_/model/layers.1/attn/v_proj/repeat_kv/Reshape_4/output_0' Status Message: /onnxruntime_src/onnxruntime/core/framework/op_kernel.cc:83 virtual OrtValue* onnxruntime::OpKernelContext::OutputMLValue(int, const onnxruntime::TensorShape&) status.IsOK() was false. Shape mismatch attempting to re-use buffer. {1,1,1536} != {1,22,1536}. Validate usage of dim_value (values should be > 0) and dim_param (all values with the same string should equate to the same size) in shapes in the model.
#
# ...

# %%
# !node 2.js
# Out:
# 2025-02-11 00:54:35.607858896 [E:onnxruntime:, inference_session.cc:2117 operator()] Exception during initialization: filesystem error: cannot get file size: No such file or directory [model.onnx_data]
# Error: Exception during initialization: filesystem error: cannot get file size: No such file or directory [model.onnx_data]
#     at new OnnxruntimeSessionHandler (/content/node_modules/onnxruntime-node/dist/backend.js:27:92)
#     at Immediate.<anonymous> (/content/node_modules/onnxruntime-node/dist/backend.js:64:29)
#     at process.processImmediate (node:internal/timers:476:21)

# %%
# !npm install onnxruntime-node@latest
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦
# added 2 packages, and audited 83 packages in 2s
# ⠦
# ⠦20 packages are looking for funding
# ⠦  run `npm fund` for details
# ⠦
# found 0 vulnerabilities
# ⠦

# %%
# !npm install onnxruntime-node
# Out:
# ⠙⠹⠸⠼⠴⠦
# up to date, audited 83 packages in 1s
# ⠦
# ⠦20 packages are looking for funding
# ⠦  run `npm fund` for details
# ⠦
# found 0 vulnerabilities
# ⠦

# %%
from transformers import AutoModelForSequenceClassification

model = AutoModelForSequenceClassification.from_pretrained(
    "onnx-community/DeepSeek-R1-Distill-Qwen-1.5B-ONNX",
    cache_dir="/content/1",  # تحديد اسم المجلد
)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/903 [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-16-81bb3ca5d321> in <cell line: 0>()
#       1 from transformers import AutoModelForSequenceClassification
#       2
# ----> 3 model = AutoModelForSequenceClassification.from_pretrained(
# ...

# %%
# !node 2.js

# %%
# !npm install onnxruntime-node tokenizer
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸
# added 1 package, and audited 84 packages in 2s
# ⠸
# ⠸20 packages are looking for funding
# ⠸  run `npm fund` for details
# ⠸
# found 0 vulnerabilities
# ⠸

# %%
import ort from "onnxruntime-node";
import fs from "fs";
import { AutoTokenizer } from "tokenizers";

// 🔹 مسار مجلد النموذج ONNX
const modelPath = "onnx-community/DeepSeek-R1-Distill-Qwen-1.5B-ONNX/model.onnx";
const tokenizerPath = "onnx-community/DeepSeek-R1-Distill-Qwen-1.5B-ONNX/tokenizer.json";

async function loadModel() {
  try {
    // 🔹 تحميل النموذج باستخدام ONNX Runtime
    const session = await ort.InferenceSession.create(modelPath);
    console.log("✅ نموذج ONNX تم تحميله بنجاح!");

    // 🔹 تحميل التوكنيزر
    const tokenizer = await AutoTokenizer.fromFile(tokenizerPath);
    console.log("✅ تم تحميل التوكنيزر!");

    // 🔹 نص الإدخال
    const inputText = "Solve the equation: x^2 - 3x + 2 = 0";

    // 🔹 تحويل النص إلى ID باستخدام التوكنيزر
    const encoded = tokenizer.encode(inputText);
    const inputIds = encoded.ids;

    // 🔹 إعداد إدخال ONNX
    const inputTensor = new ort.Tensor("int64", BigInt64Array.from(inputIds), [1, inputIds.length]);

    // 🔹 تنفيذ النموذج
    const feeds = { "input_ids": inputTensor };
    const results = await session.run(feeds);

    // 🔹 استخراج الإخراج وفك ترميزه
    const outputIds = results["logits"].data;
    const generatedText = tokenizer.decode(outputIds);

    console.log("📝 الإخراج:", generatedText);
  } catch (error) {
    console.error("❌ خطأ أثناء تشغيل النموذج:", error);
  }
}

// 🔹 تشغيل البرنامج
loadModel();

# %%
# !node 2.js
# Out:
# node:internal/errors:496
#     ErrorCaptureStackTrace(err);
#     ^
#
# Error [ERR_MODULE_NOT_FOUND]: Cannot find package 'tokenizers' imported from /content/2.js
#     at new NodeError (node:internal/errors:405:5)
#     at packageResolve (node:internal/modules/esm/resolve:916:9)
#     at moduleResolve (node:internal/modules/esm/resolve:973:20)
#     at defaultResolve (node:internal/modules/esm/resolve:1206:11)
#     at ModuleLoader.defaultResolve (node:internal/modules/esm/loader:404:12)
#     at ModuleLoader.resolve (node:internal/modules/esm/loader:373:25)
#     at ModuleLoader.getModuleJob (node:internal/modules/esm/loader:250:38)
#     at ModuleWrap.<anonymous> (node:internal/modules/esm/module_job:76:39)
#     at link (node:internal/modules/esm/module_job:75:36) {
#   code: 'ERR_MODULE_NOT_FOUND'
# }
#
# Node.js v18.20.5

# %%
# !npm install onnxruntime-node @huggingface/tokenizers
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸npm error code E404
# ⠸npm error 404 Not Found - GET https://registry.npmjs.org/@huggingface%2ftokenizers - Not found
# ⠸npm error 404
# ⠸npm error 404  '@huggingface/tokenizers@*' is not in this registry.
# ⠸npm error 404
# ⠸npm error 404 Note that you can also install from a
# ⠸npm error 404 tarball, folder, http url, or git url.
# ⠸npm error A complete log of this run can be found in: /root/.npm/_logs/2025-02-11T01_07_38_456Z-debug-0.log
# ⠸

# %%
from huggingface_hub import snapshot_download

# تحميل النموذج إلى المجلد "DeepSeek-ONNX"
snapshot_download(repo_id="onnx-community/DeepSeek-R1-Distill-Qwen-1.5B-ONNX",
                  repo_type="model",
                  local_dir="DeepSeek-ONNX")
# Out:
# Fetching 17 files:   0%|          | 0/17 [00:00<?, ?it/s]
# model.onnx:   0%|          | 0.00/531k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/903 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/2.79k [00:00<?, ?B/s]
# .gitattributes:   0%|          | 0.00/1.64k [00:00<?, ?B/s]
# model_fp16.onnx:   0%|          | 0.00/1.51G [00:00<?, ?B/s]
# model_bnb4.onnx:   0%|          | 0.00/1.87G [00:00<?, ?B/s]
# model.onnx_data:   0%|          | 0.00/7.18G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/132 [00:00<?, ?B/s]
# model_fp16.onnx_data:   0%|          | 0.00/2.09G [00:00<?, ?B/s]
# model_int8.onnx:   0%|          | 0.00/1.85G [00:00<?, ?B/s]
# model_q4f16.onnx:   0%|          | 0.00/1.37G [00:00<?, ?B/s]
# model_q4.onnx:   0%|          | 0.00/1.97G [00:00<?, ?B/s]
# model_quantized.onnx:   0%|          | 0.00/1.85G [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# ...

# %%
# !wget https://huggingface.co/onnx-community/DeepSeek-R1-Distill-Qwen-1.5B-ONNX/resolve/main/onnx/model_q4f16.onnx

# %%
const generator = await pipeline(
  "text-generation",
  "./DeepSeek-ONNX/model_q4f16.onnx", // استخدم المسار الصحيح
  { dtype: "q4f16" }
);

# %% [markdown]
# تحميل ملف واحد فقط

# %%
from huggingface_hub import hf_hub_download

# تحميل ملف معين فقط
hf_hub_download(repo_id="onnx-community/DeepSeek-R1-Distill-Qwen-1.5B-ONNX",
                filename="onnx/model_q4f16.onnx",
                local_dir="DeepSeek-ONNX")

# %%
import { pipeline } from "@xenova/transformers";

// إنشاء دالة لاستخدام النموذج
async function generateText(prompt) {
    // تحميل النموذج باستخدام ONNX
    const generator = await pipeline(
        "text-generation",
        "./DeepSeek-ONNX/model_q4f16.onnx", // تأكد من صحة المسار
        { dtype: "q4f16" }
    );

    // توليد النص من الإدخال
    const output = await generator(prompt, {
        max_new_tokens: 512,
        do_sample: false,
    });

    console.log("Generated Text:", output[0].generated_text);
}

// تشغيل الاستدلال
generateText("Solve the equation: x^2 - 3x + 2 = 0");

# %%
# !npm install @xenova/transformers onnxruntime tokenizers
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙npm warn deprecated npmlog@4.1.2: This package is no longer supported.
# ⠙npm warn deprecated are-we-there-yet@1.1.7: This package is no longer supported.
# ⠹npm warn deprecated gauge@2.7.4: This package is no longer supported.
# ⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧npm error code 127
# ⠧npm error path /content/node_modules/onnxruntime
# ⠧npm error command failed
# ⠧npm error command sh -c prebuild-install -r napi || (tsc && node ./script/build)
# ⠧npm error sh: 1: prebuild-install: Permission denied
# npm error sh: 1: tsc: not found
# ⠧npm error A complete log of this run can be found in: /root/.npm/_logs/2025-02-11T01_18_06_833Z-debug-0.log
# ⠧

# %% [markdown]
# ayhgشغال

# %%
# !npm i @xenova/transformers
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴
# added 57 packages, and audited 141 packages in 8s
# ⠴
# ⠴30 packages are looking for funding
# ⠴  run `npm fund` for details
# ⠴
# found 0 vulnerabilities
# ⠴

# %%
# !npm update
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸
# added 1 package, removed 1 package, changed 1 package, and audited 84 packages in 11s
# ⠸
# ⠸20 packages are looking for funding
# ⠸  run `npm fund` for details
# ⠸
# found 0 vulnerabilities
# ⠸

# %%
# !node /content/2.js
# Out:
# file:///content/node_modules/@xenova/transformers/src/utils/hub.js:238
#     throw Error(`${message}: "${remoteURL}".`);
#           ^
#
# Error: Could not locate file: "https://huggingface.co/content/DeepSeek-ONNX/onnx/model_q4f16.onnx/resolve/main/tokenizer.json".
#     at handleError (file:///content/node_modules/@xenova/transformers/src/utils/hub.js:238:11)
#     at getModelFile (file:///content/node_modules/@xenova/transformers/src/utils/hub.js:471:24)
#     at process.processTicksAndRejections (node:internal/process/task_queues:95:5)
#     at async getModelJSON (file:///content/node_modules/@xenova/transformers/src/utils/hub.js:572:18)
#     at async Promise.all (index 0)
#     at async loadTokenizer (file:///content/node_modules/@xenova/transformers/src/tokenizers.js:61:18)
#     at async AutoTokenizer.from_pretrained (file:///content/node_modules/@xenova/transformers/src/tokenizers.js:4459:50)
#     at async Promise.all (index 0)
# ...

# %%
# !wget -P DeepSeek-ONNX https://huggingface.co/onnx-community/DeepSeek-R1-Distill-Qwen-1.5B-ONNX/resolve/main/tokenizer.json
# Out:
# --2025-02-11 01:21:38--  https://huggingface.co/onnx-community/DeepSeek-R1-Distill-Qwen-1.5B-ONNX/resolve/main/tokenizer.json
# Resolving huggingface.co (huggingface.co)... 13.35.202.34, 13.35.202.97, 13.35.202.40, ...
# Connecting to huggingface.co (huggingface.co)|13.35.202.34|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9117072 (8.7M) [text/plain]
# Saving to: ‘DeepSeek-ONNX/tokenizer.json’
#
# tokenizer.json      100%[===================>]   8.69M  13.4MB/s    in 0.6s
#
# 2025-02-11 01:21:39 (13.4 MB/s) - ‘DeepSeek-ONNX/tokenizer.json’ saved [9117072/9117072]

# %%
from transformers import AutoTokenizer

# اسم النموذج الأصلي
model_id = "deepseek-ai/deepseek-llm-1.5b"

# تحميل التوكنزر
tokenizer = AutoTokenizer.from_pretrained(model_id)

# حفظ tokenizer.json داخل مجلد DeepSeek-ONNX
tokenizer.save_pretrained("DeepSeek-ONNX")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_http.py in hf_raise_for_status(response, endpoint_name)
#     405     try:
# --> 406         response.raise_for_status()
#     407     except HTTPError as e:
#
# /usr/local/lib/python3.11/dist-packages/requests/models.py in raise_for_status(self)
# ...

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To log in, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):
# Add token as git credential? (Y/n) Y
# Token is valid (permission: read).
# The token `read` has been saved to /root/.cache/huggingface/stored_tokens
# Cannot authenticate through git-credential as no helper is defined on your machine.
# ...

# %%
# !node /content/2.js
# Out:
# file:///content/node_modules/@xenova/transformers/src/utils/hub.js:238
#     throw Error(`${message}: "${remoteURL}".`);
#           ^
#
# Error: Could not locate file: "https://huggingface.co/content/DeepSeek-ONNX/model_q4f16.onnx/resolve/main/config.json".
#     at handleError (file:///content/node_modules/@xenova/transformers/src/utils/hub.js:238:11)
#     at getModelFile (file:///content/node_modules/@xenova/transformers/src/utils/hub.js:471:24)
#     at process.processTicksAndRejections (node:internal/process/task_queues:95:5)
#     at async getModelJSON (file:///content/node_modules/@xenova/transformers/src/utils/hub.js:572:18)
#     at async loadConfig (file:///content/node_modules/@xenova/transformers/src/configs.js:46:16)
#     at async PretrainedConfig.from_pretrained (file:///content/node_modules/@xenova/transformers/src/configs.js:85:30)
#     at async AutoModelForCausalLM.from_pretrained (file:///content/node_modules/@xenova/transformers/src/models.js:5504:18)
# ...

# %%
# !rm -rf node_modules package-lock.json
# !npm install @xenova/transformers onnxruntime tokenizers
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋npm warn deprecated npmlog@4.1.2: This package is no longer supported.
# ⠋npm warn deprecated are-we-there-yet@1.1.7: This package is no longer supported.
# ⠋⠙npm warn deprecated gauge@2.7.4: This package is no longer supported.
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼npm error code 127
# ⠼npm error path /content/node_modules/onnxruntime
# ⠼npm error command failed
# ⠼npm error command sh -c prebuild-install -r napi || (tsc && node ./script/build)
# ...

# %%
# !npm install onnxruntime-web
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏
# added 138 packages, and audited 139 packages in 27s
# ⠏
# ⠏28 packages are looking for funding
# ⠏  run `npm fund` for details
# ⠏
# found 0 vulnerabilities
# ⠏

# %%
# !npm install @xenova/transformers
# Out:
# ⠙⠹⠸⠼⠴
# added 2 packages, and audited 141 packages in 973ms
# ⠴
# ⠴30 packages are looking for funding
# ⠴  run `npm fund` for details
# ⠴
# found 0 vulnerabilities
# ⠴

# %%
# !node /content/2.js
# Out:
# node:internal/errors:496
#     ErrorCaptureStackTrace(err);
#     ^
#
# Error [ERR_MODULE_NOT_FOUND]: Cannot find package '@xenova/transformers' imported from /content/2.js
#     at new NodeError (node:internal/errors:405:5)
#     at packageResolve (node:internal/modules/esm/resolve:916:9)
#     at moduleResolve (node:internal/modules/esm/resolve:973:20)
#     at defaultResolve (node:internal/modules/esm/resolve:1206:11)
#     at ModuleLoader.defaultResolve (node:internal/modules/esm/loader:404:12)
#     at ModuleLoader.resolve (node:internal/modules/esm/loader:373:25)
#     at ModuleLoader.getModuleJob (node:internal/modules/esm/loader:250:38)
#     at ModuleWrap.<anonymous> (node:internal/modules/esm/module_job:76:39)
#     at link (node:internal/modules/esm/module_job:75:36) {
#   code: 'ERR_MODULE_NOT_FOUND'
# }
#
# Node.js v18.20.5

# %%
# !node /content/2.js
# Out:
# file:///content/node_modules/@xenova/transformers/src/utils/hub.js:238
#     throw Error(`${message}: "${remoteURL}".`);
#           ^
#
# Error: Unauthorized access to file: "https://huggingface.co/./DeepSeek-ONNX/model_q4f16.onnx/resolve/main/tokenizer_config.json".
#     at handleError (file:///content/node_modules/@xenova/transformers/src/utils/hub.js:238:11)
#     at getModelFile (file:///content/node_modules/@xenova/transformers/src/utils/hub.js:471:24)
#     at process.processTicksAndRejections (node:internal/process/task_queues:95:5)
#     at async getModelJSON (file:///content/node_modules/@xenova/transformers/src/utils/hub.js:572:18)
#     at async Promise.all (index 1)
#     at async loadTokenizer (file:///content/node_modules/@xenova/transformers/src/tokenizers.js:61:18)
#     at async AutoTokenizer.from_pretrained (file:///content/node_modules/@xenova/transformers/src/tokenizers.js:4459:50)
#     at async Promise.all (index 0)
# ...

# %%
# !node /content/3.js
# Out:
# 2025-02-11 01:37:13.548629020 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.5/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 01:37:13.548713347 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.1/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 01:37:13.548790030 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.2/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 01:37:13.548850169 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.0/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# ...

# %% [markdown]
# https://huggingface.co/docs/transformers.js/api/pipelines#module_pipelines.TextGenerationPipeline

# %%
import { pipeline } from "@xenova/transformers";

const generator = await pipeline('text-generation', 'onnx-community/DeepSeek-R1-Distill-Qwen-1.5B-ONNX');
const text = 'I enjoy walking with my cute dog,';
const output = await generator(text);

// عرض النتيجة
console.log(output[0].generated_text);

# %%
onnx-community/DeepSeek-R1-Distill-Qwen-1.5B-ONNX

# %%
# !node /content/4.js
# Out:
# file:///content/node_modules/@xenova/transformers/src/utils/hub.js:238
#     throw Error(`${message}: "${remoteURL}".`);
#           ^
#
# Error: Could not locate file: "https://huggingface.co/onnx-community/DeepSeek-R1-Distill-Qwen-1.5B-ONNX/resolve/main/onnx/decoder_model_merged_quantized.onnx".
#     at handleError (file:///content/node_modules/@xenova/transformers/src/utils/hub.js:238:11)
#     at getModelFile (file:///content/node_modules/@xenova/transformers/src/utils/hub.js:471:24)
#     at process.processTicksAndRejections (node:internal/process/task_queues:95:5)
#     at async constructSession (file:///content/node_modules/@xenova/transformers/src/models.js:123:18)
#     at async Promise.all (index 1)
#     at async Qwen2ForCausalLM.from_pretrained (file:///content/node_modules/@xenova/transformers/src/models.js:761:20)
#     at async AutoModelForCausalLM.from_pretrained (file:///content/node_modules/@xenova/transformers/src/models.js:5519:20)
# ...

# %%
import { pipeline } from "@xenova/transformers";

    const generator = await pipeline(
        "text-generation",
        "./DeepSeek-ONNX/model_q4f16.onnx", // Updated to model_q4f16.onnx
        { dtype: "q4f16" }
    );
    const text = "I enjoy walking with my cute dog,";
    const output = await generator(text);

    console.log(output[0].generated_text); // Display the result

# %%
# !node /content/5.js
# Out:
# file:///content/node_modules/@xenova/transformers/src/utils/hub.js:238
#     throw Error(`${message}: "${remoteURL}".`);
#           ^
#
# Error: Unauthorized access to file: "https://huggingface.co/./DeepSeek-ONNX/model_q4f16.onnx/resolve/main/config.json".
#     at handleError (file:///content/node_modules/@xenova/transformers/src/utils/hub.js:238:11)
#     at getModelFile (file:///content/node_modules/@xenova/transformers/src/utils/hub.js:471:24)
#     at process.processTicksAndRejections (node:internal/process/task_queues:95:5)
#     at async getModelJSON (file:///content/node_modules/@xenova/transformers/src/utils/hub.js:572:18)
#     at async loadConfig (file:///content/node_modules/@xenova/transformers/src/configs.js:46:16)
#     at async PretrainedConfig.from_pretrained (file:///content/node_modules/@xenova/transformers/src/configs.js:85:30)
#     at async AutoModelForCausalLM.from_pretrained (file:///content/node_modules/@xenova/transformers/src/models.js:5504:18)
# ...

# %%
# !wget -P DeepSeek-ONNX https://huggingface.co/onnx-community/DeepSeek-R1-Distill-Qwen-1.5B-ONNX/resolve/main/tokenizer.json
# Out:
# --2025-02-11 01:41:59--  https://huggingface.co/onnx-community/DeepSeek-R1-Distill-Qwen-1.5B-ONNX/resolve/main/tokenizer.json
# Resolving huggingface.co (huggingface.co)... 13.35.202.34, 13.35.202.40, 13.35.202.97, ...
# Connecting to huggingface.co (huggingface.co)|13.35.202.34|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9117072 (8.7M) [text/plain]
# Saving to: ‘DeepSeek-ONNX/tokenizer.json’
#
# tokenizer.json      100%[===================>]   8.69M  10.3MB/s    in 0.8s
#
# 2025-02-11 01:42:00 (10.3 MB/s) - ‘DeepSeek-ONNX/tokenizer.json’ saved [9117072/9117072]

# %%
import { pipeline } from "@xenova/transformers";

   const generator = await pipeline(
       "text-generation",
       "./DeepSeek-ONNX/model_q4f16.onnx",
       {
           dtype: "q4f16",
           tokenizer: "./DeepSeek-ONNX/tokenizer.json" // Adjust path if necessary
       }
   );
   const text = "I enjoy walking with my cute dog,";
   const output = await generator(text);

   console.log(output[0].generated_text);

# %%
# !wget -P DeepSeek-ONNX https://huggingface.co/onnx-community/DeepSeek-R1-Distill-Qwen-1.5B-ONNX/resolve/main/config.json
# Out:
# --2025-02-11 01:42:57--  https://huggingface.co/onnx-community/DeepSeek-R1-Distill-Qwen-1.5B-ONNX/resolve/main/config.json
# Resolving huggingface.co (huggingface.co)... 13.35.202.40, 13.35.202.34, 13.35.202.121, ...
# Connecting to huggingface.co (huggingface.co)|13.35.202.40|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 903 [text/plain]
# Saving to: ‘DeepSeek-ONNX/config.json.1’
#
# config.json.1       100%[===================>]     903  --.-KB/s    in 0s
#
# 2025-02-11 01:42:57 (506 MB/s) - ‘DeepSeek-ONNX/config.json.1’ saved [903/903]

# %%
import { pipeline } from "@xenova/transformers";

   const generator = await pipeline(
       "text-generation",
       "./DeepSeek-ONNX/model_q4f16.onnx",
       {
           dtype: "q4f16",
           tokenizer: "/content/DeepSeek-ONNX/tokenizer.json",
           config: 'onnx-community/DeepSeek-R1-Distill-Qwen-1.5B-ONNX'
       }
   );
   const text = "I enjoy walking with my cute dog,";
   const output = await generator(text);

   console.log(output[0].generated_text);

# %%
import { pipeline, env } from '@xenova/transformers';

// تحديد مجلد تحميل النموذج
env.localModelPath = './my-models'; // استبدل 'my-models' باسم المجلد المطلوب

const generator = await pipeline(
  'text-generation',
  'onnx-community/DeepSeek-R1-Distill-Qwen-1.5B-ONNX',
  { dtype: 'q4f16' }
);

const text = 'I enjoy walking with my cute dog,';
const output = await generator(text);

// عرض النتيجة
console.log(output[0].generated_text);

# %%
import { pipeline, env } from '@xenova/transformers';

env.localModelPath = './downloaded_models';

const generator = await pipeline(
  'text-generation',
  'onnx-community/DeepSeek-R1-Distill-Qwen-1.5B-ONNX',
  { dtype: 'q4f16' }
);

// ... باقي الكود
const text = 'I enjoy walking with my cute dog,';
const output = await generator(text);

// عرض النتيجة
console.log(output[0].generated_text);

# %%
from huggingface_hub import hf_hub_download

# تحميل ملف معين فقط
hf_hub_download(repo_id="onnx-community/DeepSeek-R1-Distill-Qwen-1.5B-ONNX",
                filename="onnx/model_q4f16.onnx",
                local_dir="DeepSeek-ONNX")

# %%
from huggingface_hub import hf_hub_download
from transformers import AutoTokenizer

# تحميل ملف معين فقط
hf_hub_download(repo_id="onnx-community/DeepSeek-R1-Distill-Qwen-1.5B-ONNX",
                filename="onnx/model_q4f16.onnx",
                local_dir="DeepSeek-ONNX")

# اسم النموذج الأصلي
model_id = "deepseek-ai/deepseek-llm-1.5b"

# تحميل التوكنزر
tokenizer = AutoTokenizer.from_pretrained(model_id)

# حفظ tokenizer.json داخل مجلد DeepSeek-ONNX
tokenizer.save_pretrained("DeepSeek-ONNX")

# %%
from huggingface_hub import notebook_login

notebook_login()

# %%
# !npm i @xenova/transformers
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴
# up to date, audited 79 packages in 2s
# ⠴
# ⠴10 packages are looking for funding
# ⠴  run `npm fund` for details
# ⠴
# found 0 vulnerabilities
# ⠴

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To log in, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):
# Add token as git credential? (Y/n) Y
# Token is valid (permission: read).
# The token `read` has been saved to /root/.cache/huggingface/stored_tokens
# Cannot authenticate through git-credential as no helper is defined on your machine.
# ...

# %%
# !HF_TOKEN=xxxx node /content/2.js
# Out:
# (node:15530) Warning: To load an ES module, set "type": "module" in the package.json or use the .mjs extension.
# (Use `node --trace-warnings ...` to show where the warning was created)
# /content/2.js:1
# import { pipeline, TextStreamer } from "@huggingface/transformers";
# ^^^^^^
#
# SyntaxError: Cannot use import statement outside a module
#     at internalCompileFunction (node:internal/vm:76:18)
#     at wrapSafe (node:internal/modules/cjs/loader:1283:20)
#     at Module._compile (node:internal/modules/cjs/loader:1328:27)
#     at Module._extensions..js (node:internal/modules/cjs/loader:1422:10)
#     at Module.load (node:internal/modules/cjs/loader:1203:32)
#     at Module._load (node:internal/modules/cjs/loader:1019:12)
#     at Function.executeUserEntryPoint [as runMain] (node:internal/modules/run_main:128:12)
#     at node:internal/main/run_main_module:28:49
#
# Node.js v18.20.5

# %%
# %cd /content/DeepSeek-ONNX/onnx
# !wget https://huggingface.co/onnx-community/DeepSeek-R1-Distill-Qwen-1.5B-ONNX/resolve/main/onnx/model_fp16.onnx_data
# Out:
# /content/DeepSeek-ONNX/onnx
# --2025-02-11 02:29:45--  https://huggingface.co/onnx-community/DeepSeek-R1-Distill-Qwen-1.5B-ONNX/resolve/main/onnx/model_fp16.onnx_data
# Resolving huggingface.co (huggingface.co)... 3.171.171.128, 3.171.171.65, 3.171.171.6, ...
# Connecting to huggingface.co (huggingface.co)|3.171.171.128|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
import { pipeline, TextStreamer } from "@huggingface/transformers";

// Create a text generation pipeline
const generator = await pipeline(
  "text-generation",
  "onnx-community/DeepSeek-R1-Distill-Qwen-1.5B-ONNX",
  { dtype: "q4f16" },
);

// Define the list of messages
const messages = [
  { role: "user", content:  "Solve the equation: x^2 - 3x + 2 = 0" },
];

// Create text streamer
const streamer = new TextStreamer(generator.tokenizer, {
  skip_prompt: true,
  // callback_function: (text) => { }, // Optional callback function
})

// Generate a response
const output = await generator(messages, { max_new_tokens: 512, do_sample: false, streamer });
console.log(output[0].generated_text.at(-1).content);

# %%
/content/DeepSeek-ONNX/onnx/model_fp16.onnx_data
/content/DeepSeek-ONNX/onnx/model_q4f16.onnx

# %%
# !node /content/2.js
# Out:
# (node:15267) Warning: To load an ES module, set "type": "module" in the package.json or use the .mjs extension.
# (Use `node --trace-warnings ...` to show where the warning was created)
# /content/2.js:1
# import { pipeline, TextStreamer } from "@huggingface/transformers";
# ^^^^^^
#
# SyntaxError: Cannot use import statement outside a module
#     at internalCompileFunction (node:internal/vm:76:18)
#     at wrapSafe (node:internal/modules/cjs/loader:1283:20)
#     at Module._compile (node:internal/modules/cjs/loader:1328:27)
#     at Module._extensions..js (node:internal/modules/cjs/loader:1422:10)
#     at Module.load (node:internal/modules/cjs/loader:1203:32)
#     at Module._load (node:internal/modules/cjs/loader:1019:12)
#     at Function.executeUserEntryPoint [as runMain] (node:internal/modules/run_main:128:12)
#     at node:internal/main/run_main_module:28:49
#
# Node.js v18.20.5

# %%
# !npm install @huggingface/transformers
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼npm error code ETARGET
# ⠴npm error notarget No matching version found for type@module.
# ⠴npm error notarget In most cases you or one of your dependencies are requesting
# npm error notarget a package version that doesn't exist.
# ⠴npm error A complete log of this run can be found in: /root/.npm/_logs/2025-02-11T02_41_49_686Z-debug-0.log
# ⠴

# %%
# !node /content/4.js
# Out:
# node:internal/errors:496
#     ErrorCaptureStackTrace(err);
#     ^
#
# Error [ERR_MODULE_NOT_FOUND]: Cannot find package '@huggingface/transformers' imported from /content/4.js
#     at new NodeError (node:internal/errors:405:5)
#     at packageResolve (node:internal/modules/esm/resolve:916:9)
#     at moduleResolve (node:internal/modules/esm/resolve:973:20)
#     at defaultResolve (node:internal/modules/esm/resolve:1206:11)
#     at ModuleLoader.defaultResolve (node:internal/modules/esm/loader:404:12)
#     at ModuleLoader.resolve (node:internal/modules/esm/loader:373:25)
#     at ModuleLoader.getModuleJob (node:internal/modules/esm/loader:250:38)
#     at ModuleWrap.<anonymous> (node:internal/modules/esm/module_job:76:39)
#     at link (node:internal/modules/esm/module_job:75:36) {
#   code: 'ERR_MODULE_NOT_FOUND'
# }
#
# Node.js v18.20.5

# %%
# !npm cache clean --force
# Out:
# npm warn using --force Recommended protections disabled.
# ⠙⠹⠸⠼⠴

# %%
# !npm install
# Out:
# ⠙⠹⠸⠼⠴⠦⠧
# up to date, audited 79 packages in 1s
# ⠧
# ⠧10 packages are looking for funding
# ⠧  run `npm fund` for details
# ⠧
# found 0 vulnerabilities
# ⠧

# %%
# !npm install @huggingface/transformers
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹npm error code ETARGET
# ⠹npm error notarget No matching version found for type@module.
# ⠹npm error notarget In most cases you or one of your dependencies are requesting
# npm error notarget a package version that doesn't exist.
# ⠹npm error A complete log of this run can be found in: /root/.npm/_logs/2025-02-11T02_46_40_890Z-debug-0.log
# ⠹

# %%
# !npm install
# Out:
# ⠙⠹⠸⠼npm error code ETARGET
# ⠼npm error notarget No matching version found for type@module.
# ⠼npm error notarget In most cases you or one of your dependencies are requesting
# npm error notarget a package version that doesn't exist.
# ⠼npm error A complete log of this run can be found in: /root/.npm/_logs/2025-02-11T02_47_14_500Z-debug-0.log
# ⠼

# %%
# !npm i @xenova/transformers
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇
# up to date, audited 79 packages in 2s
# ⠇
# ⠇10 packages are looking for funding
# ⠇  run `npm fund` for details
# ⠇
# found 0 vulnerabilities
# ⠇

# %%
# !npm install @huggingface/transformers
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴
# added 58 packages, and audited 137 packages in 27s
# ⠴
# ⠴28 packages are looking for funding
# ⠴  run `npm fund` for details
# ⠴
# found 0 vulnerabilities
# ⠦

# %%
# !npm install onnxruntime-node
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙
# added 4 packages, removed 2 packages, changed 1 package, and audited 139 packages in 16s
# ⠙
# ⠙30 packages are looking for funding
# ⠙  run `npm fund` for details
# ⠙
# found 0 vulnerabilities
# ⠙

# %% [markdown]
# https://github.com/microsoft/onnxruntime-inference-examples/tree/main/js/chat

# %%
# !npm install onnxruntime-node

# %%
# !git clone https://github.com/microsoft/onnxruntime-inference-examples.git
# Out:
# Cloning into 'onnxruntime-inference-examples'...
# remote: Enumerating objects: 5780, done.
# remote: Counting objects: 100% (1060/1060), done.
# remote: Compressing objects: 100% (258/258), done.
# remote: Total 5780 (delta 898), reused 807 (delta 800), pack-reused 4720 (from 1)
# Receiving objects: 100% (5780/5780), 438.36 MiB | 28.14 MiB/s, done.
# Resolving deltas: 100% (2414/2414), done.
# Updating files: 100% (1014/1014), done.

# %%
# %cd /content/onnxruntime-inference-examples/js/chat
# !npm install
# Out:
# /content/onnxruntime-inference-examples/js/chat
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼
# added 399 packages, and audited 400 packages in 43s
# ⠼
# ⠼72 packages are looking for funding
# ⠼  run `npm fund` for details
# ⠼
# found 0 vulnerabilities
# ⠼

# %%
# !npm run build
# Out:
# > localchat@0.0.0 build
# > webpack
#
# assets by path dist/*.wasm 37.3 MiB
#   asset dist/ort-wasm-simd-threaded.jsep.wasm 19.7 MiB [emitted] [from: node_modules/onnxruntime-web/dist/ort-wasm-simd-threaded.jsep.wasm] [copied]
#   asset dist/ort-wasm-simd.jsep.wasm 17.6 MiB [emitted] [from: node_modules/onnxruntime-web/dist/ort-wasm-simd.jsep.wasm] [copied]
# assets by path dist/*.js 4.75 MiB
#   asset dist/main.min.js 2.37 MiB [emitted] [javascript module] (name: dist/main.min) 1 related asset
#   asset dist/main.js 2.37 MiB [emitted] [javascript module] (name: dist/main) 1 related asset
# runtime modules 3.54 KiB 8 modules
# modules by path ./ 2.22 MiB
#   modules by path ./node_modules/ 2.21 MiB 30 modules
#   modules by path ./*.js 16.5 KiB
#     ./main.js 9.02 KiB [built] [code generated]
#     ./llm.js 7.5 KiB [built] [code generated]
# fs (ignored) 15 bytes [built] [code generated]
# path (ignored) 15 bytes [built] [code generated]
# ...

# %%
# !npm run dev
# Out:
# > localchat@0.0.0 dev
# > webpack serve --no-client-overlay
#
# /content/onnxruntime-inference-examples/js/chat/node_modules/webpack-dev-server/lib/Server.js:2602
#         throw error;
#         ^
#
# Error: listen EADDRINUSE: address already in use :::8080
#     at Server.setupListenHandle [as _listen2] (node:net:1817:16)
#     at listenInCluster (node:net:1865:12)
#     at Server.listen (node:net:1953:7)
#     at READ_WRITE (/content/onnxruntime-inference-examples/js/chat/node_modules/webpack-dev-server/lib/Server.js:3349:23)
#     at new Promise (<anonymous>)
#     at Server.start (/content/onnxruntime-inference-examples/js/chat/node_modules/webpack-dev-server/lib/Server.js:3347:7)
#     at async Command.<anonymous> (/content/onnxruntime-inference-examples/js/chat/node_modules/@webpack-cli/serve/lib/index.js:158:21)
#     at async Command.parseAsync (/content/onnxruntime-inference-examples/js/chat/node_modules/webpack-cli/node_modules/commander/lib/command.js:935:5)
# ...

# %% [markdown]
# https://github.com/microsoft/onnxruntime-inference-examples/tree/main/js/chat

# %%
# !node /content/3.js
# Out:
# file:///content/node_modules/@huggingface/transformers/dist/transformers.mjs:31095
#     throw Error(`${message}: "${remoteURL}".`);
#           ^
#
# Error: Could not locate file: "https://huggingface.co/content/DeepSeek-ONNX/onnx/resolve/main/tokenizer.json".
#     at handleError (file:///content/node_modules/@huggingface/transformers/dist/transformers.mjs:31095:11)
#     at getModelFile (file:///content/node_modules/@huggingface/transformers/dist/transformers.mjs:31328:24)
#     at process.processTicksAndRejections (node:internal/process/task_queues:95:5)
#     at async getModelJSON (file:///content/node_modules/@huggingface/transformers/dist/transformers.mjs:31427:18)
#     at async Promise.all (index 0)
#     at async loadTokenizer (file:///content/node_modules/@huggingface/transformers/dist/transformers.mjs:24731:18)
#     at async AutoTokenizer.from_pretrained (file:///content/node_modules/@huggingface/transformers/dist/transformers.mjs:29020:50)
# ...

# %%
# !node /content/5.js
# Out:
# file:///content/5.js:1
# const generator = await pipeline('text-generation', 'Xenova/distilgpt2');
#                   ^
#
# ReferenceError: pipeline is not defined
#     at file:///content/5.js:1:19
#     at ModuleJob.run (node:internal/modules/esm/module_job:195:25)
#     at async ModuleLoader.import (node:internal/modules/esm/loader:337:24)
#     at async loadESM (node:internal/process/esm_loader:34:7)
#     at async handleMainPromise (node:internal/modules/run_main:106:12)
#
# Node.js v18.20.5

# %%
# !npm install @xenova/transformers onnxruntime tokenizers
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦npm warn deprecated npmlog@4.1.2: This package is no longer supported.
# ⠦npm warn deprecated are-we-there-yet@1.1.7: This package is no longer supported.
# ⠦npm warn deprecated gauge@2.7.4: This package is no longer supported.
# ⠦⠧⠇⠏⠋⠙⠹⠸npm error code 127
# ⠸npm error path /content/node_modules/onnxruntime
# ⠸npm error command failed
# ⠸npm error command sh -c prebuild-install -r napi || (tsc && node ./script/build)
# ⠸npm error prebuild-install WARN install No prebuilt binaries found (target=3 runtime=napi arch=x64 libc= platform=linux)
# npm error sh: 1: tsc: not found
# ⠸npm error A complete log of this run can be found in: /root/.npm/_logs/2025-02-11T03_12_58_214Z-debug-0.log
# ⠸

# %%
import { pipeline } from '@xenova/transformers';

async function generateText() {
  const generator = await pipeline('text-generation', './path/to/your/model.onnx'); // replace with your path or model ID
  const text = 'Once upon a time, there was';
  const output = await generator(text, {
    temperature: 2,
    max_new_tokens: 10,
    repetition_penalty: 1.5,
    no_repeat_ngram_size: 2,
    num_beams: 2,
    num_return_sequences: 2,
  });

  console.log(output);
}

generateText();

# %%
import { pipeline } from '@xenova/transformers';
const generator = await pipeline('text-generation', 'Xenova/distilgpt2');
const text = 'Once upon a time, there was';
const output = await generator(text, {
  temperature: 2,
  max_new_tokens: 10,
  repetition_penalty: 1.5,
  no_repeat_ngram_size: 2,
  num_beams: 2,
  num_return_sequences: 2,
});
console.log(output);

# %%
# !node /content/5.js
# Out:
# 2025-02-11 03:14:54.001677503 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.5/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 03:14:54.001809555 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.1/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 03:14:54.001915425 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.2/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 03:14:54.001999792 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.0/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# ...

# %% [markdown]
# aشغال

# %%
import { pipeline } from '@xenova/transformers';
const generator = await pipeline('text-generation', 'Xenova/distilgpt2');
const text = 'Once upon a time, there was';
const output = await generator(text, {
  temperature: 2,
  max_new_tokens: 10,
  repetition_penalty: 1.5,
  no_repeat_ngram_size: 2,
  num_beams: 2,
  num_return_sequences: 2,
});
console.log(output);

# %%
onnx-community/Qwen2.5-0.5B-Instruct-ONNX-MHA

# %% [markdown]
# شغال

# %%
import { pipeline } from '@xenova/transformers';
const generator = await pipeline('text-generation', 'Xenova/WizardCoder-1B-V1.0');
const text = 'Once upon a time, there was';
const output = await generator(text, {
  temperature: 2,
  max_new_tokens: 10,
  repetition_penalty: 1.5,
  no_repeat_ngram_size: 2,
  num_beams: 2,
  num_return_sequences: 2,
});
console.log(output);

# %%
# !node /content/6.js
# Out:
# 2025-02-11 03:19:55.658383236 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.23/attn/Constant_9_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 03:19:55.658487356 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.21/attn/Constant_9_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 03:19:55.658515106 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.19/attn/Constant_9_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 03:19:55.658558807 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.16/attn/Constant_9_output_0'. It is not used by any node and should be removed from the model.
# ...

# %%
# !node /content/7.js
# Out:
# 2025-02-11 03:21:53.081465353 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.23/attn/Constant_9_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 03:21:53.081544944 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.21/attn/Constant_9_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 03:21:53.081565944 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.19/attn/Constant_9_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 03:21:53.081611715 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.16/attn/Constant_9_output_0'. It is not used by any node and should be removed from the model.
# ...

# %% [markdown]
# شغال

# %%
import { pipeline } from '@xenova/transformers';
const generator = await pipeline('text-generation', 'Xenova/Qwen1.5-0.5B-Chat');
const text = 'Once upon a time, there was';
const output = await generator(text, {
  temperature: 2,
  max_new_tokens: 10,
  repetition_penalty: 1.5,
  no_repeat_ngram_size: 2,
  num_beams: 2,
  num_return_sequences: 2,
});
console.log(output);

# %%
# !node /content/8.js
# Out:
# [
#   {
#     generated_text: 'Once upon a time, there was quite an adventurous young man named A-Lo who'
#   },
#   {
#     generated_text: 'Once upon a time, there was quite an adventurous young man named Anele with'
#   }
# ]

# %%
// npm i @huggingface/transformers
import { pipeline } from '@huggingface/transformers';

// Allocate pipeline
const pipe = await pipeline('text-generation', 'Xenova/Qwen1.5-0.5B-Chat');

# %%
onnx-community/Qwen2.5-0.5B-Instruct-ONNX-MHA

# %%
import { pipeline } from '@huggingface/transformers';

const generator = await pipeline('text-generation', 'onnx-community/Qwen2.5-0.5B-Instruct-ONNX-MHA');
const text = 'Once upon a time, there was';
const output = await generator(text, {
  temperature: 2,
  max_new_tokens: 10,
  repetition_penalty: 1.5,
  no_repeat_ngram_size: 2,
  num_beams: 2,
  num_return_sequences: 2,
});
console.log(output);

# %% [markdown]
# https://huggingface.co/docs/transformers.js/api/pipelines#pipelinestextgenerationpipeline

# %% [markdown]
# https://huggingface.co/docs/transformers.js/guides/dtypes

# %%
# !node /content/9.js
# Out:
# dtype not specified for "model". Using the default dtype (fp32) for this device (cpu).
# ^C

# %%
//const generator = await pipeline('text-generation', 'onnx-community/Qwen2.5-0.5B-Instruct-ONNX-MHA');

# %%
import { pipeline } from '@huggingface/transformers';


const generator = await pipeline(
  "text-generation",
  "onnx-community/Qwen2.5-0.5B-Instruct",
  { dtype: "fp32", device: "cpu" },
);
const text = 'Once upon a time, there was';
const output = await generator(text, {
  temperature: 2,
  max_new_tokens: 10,
  repetition_penalty: 1.5,
  no_repeat_ngram_size: 2,
  num_beams: 2,
  num_return_sequences: 2,
});
console.log(output);

# %% [markdown]
# aشغال

# %%
#/content/9.js
import { pipeline } from '@huggingface/transformers';


const generator = await pipeline(
  "text-generation",
  "onnx-community/Qwen2.5-0.5B-Instruct",
  { dtype: "fp32", device: "cpu" },
);
const text = 'Once upon a time, there was';
const output = await generator(text, {
  temperature: 2,
  max_new_tokens: 10,
  repetition_penalty: 1.5,
  no_repeat_ngram_size: 2,
  num_beams: 2,
  num_return_sequences: 2,
});
console.log(output);

# %%
# !node /content/9.js
# Out:
# [
#   {
#     generated_text: 'Once upon a time, there was a person named Xiao Lin. One day in the'
#   }
# ]

# %%
#https://huggingface.co/docs/transformers.js/guides/dtypes

import { pipeline } from "@huggingface/transformers";

// Create a text generation pipeline
const generator = await pipeline(
  "text-generation",
  "onnx-community/Qwen2.5-0.5B-Instruct",
  { dtype: "q4", device: "webgpu" },
);

// Define the list of messages
const messages = [
  { role: "system", content: "You are a helpful assistant." },
  { role: "user", content: "Tell me a funny joke." },
];

// Generate a response
const output = await generator(messages, { max_new_tokens: 128 });
console.log(output[0].generated_text.at(-1).content);

# %% [markdown]
# شغال

# %%
#!node /content/10.js


import { pipeline } from '@huggingface/transformers';


const generator = await pipeline(
  "text-generation",
  "onnx-community/Qwen2.5-0.5B-Instruct",
  { dtype: "fp32", device: "cpu" },
);
const text = 'Who is Napoleon Bonaparte?';
const output = await generator(text, {
  temperature: 2,
  max_new_tokens: 10,
  repetition_penalty: 1.5,
  no_repeat_ngram_size: 2,
  num_beams: 2,
  num_return_sequences: 2,
});
console.log(output);

# %%
# !node /content/10.js
# Out:
# [
#   {
#     generated_text: 'Who is Napoleon Bonaparte? He was a French military and political leader, who'
#   }
# ]
