# %%
# !npm i @huggingface/transformers
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴
# added 80 packages in 42s
# ⠴
# ⠴18 packages are looking for funding
# ⠴  run `npm fund` for details
# ⠴

# %% [markdown]
# microsoft/Phi-3.5-mini-instruct

# %%
# !python -m pip install optimum
# Out:
# Collecting optimum
#   Downloading optimum-1.24.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: transformers>=4.29 in /usr/local/lib/python3.11/dist-packages (from optimum) (4.48.2)
# Requirement already satisfied: torch>=1.11 in /usr/local/lib/python3.11/dist-packages (from optimum) (2.5.1+cu124)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from optimum) (24.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optimum) (1.26.4)
# Requirement already satisfied: huggingface-hub>=0.8.0 in /usr/local/lib/python3.11/dist-packages (from optimum) (0.28.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.8.0->optimum) (3.17.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.8.0->optimum) (2024.10.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.8.0->optimum) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.8.0->optimum) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.8.0->optimum) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.8.0->optimum) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->optimum) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->optimum) (3.1.5)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.11->optimum)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.11->optimum)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.11->optimum)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.11->optimum)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.11->optimum)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.11->optimum)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.11->optimum)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.11->optimum)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.11->optimum)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->optimum) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->optimum) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.11->optimum)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->optimum) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->optimum) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.11->optimum) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.29->optimum) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.29->optimum) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.29->optimum) (0.5.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.11->optimum) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.8.0->optimum) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.8.0->optimum) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.8.0->optimum) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.8.0->optimum) (2025.1.31)
# Downloading optimum-1.24.0-py3-none-any.whl (433 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 433.6/433.6 kB 8.6 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 90.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 74.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 48.1 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.0 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.1 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 6.5 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.0 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 83.3 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, optimum
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 optimum-1.24.0

# %%
# !pip install --upgrade --upgrade-strategy eager optimum[onnxruntime]
# Out:
# Requirement already satisfied: optimum[onnxruntime] in /usr/local/lib/python3.11/dist-packages (1.24.0)
# Requirement already satisfied: transformers>=4.29 in /usr/local/lib/python3.11/dist-packages (from optimum[onnxruntime]) (4.48.2)
# Collecting transformers>=4.29 (from optimum[onnxruntime])
#   Downloading transformers-4.48.3-py3-none-any.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.11 in /usr/local/lib/python3.11/dist-packages (from optimum[onnxruntime]) (2.5.1+cu124)
# Collecting torch>=1.11 (from optimum[onnxruntime])
#   Downloading torch-2.6.0-cp311-cp311-manylinux1_x86_64.whl.metadata (28 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from optimum[onnxruntime]) (24.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optimum[onnxruntime]) (1.26.4)
# Collecting numpy (from optimum[onnxruntime])
#   Downloading numpy-2.2.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 4.9 MB/s eta 0:00:00
# Requirement already satisfied: huggingface-hub>=0.8.0 in /usr/local/lib/python3.11/dist-packages (from optimum[onnxruntime]) (0.28.1)
# Collecting onnx (from optimum[onnxruntime])
#   Downloading onnx-1.17.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (16 kB)
# Collecting onnxruntime>=1.11.0 (from optimum[onnxruntime])
#   Downloading onnxruntime-1.20.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.5 kB)
# Collecting datasets>=1.2.1 (from optimum[onnxruntime])
#   Downloading datasets-3.2.0-py3-none-any.whl.metadata (20 kB)
# Collecting evaluate (from optimum[onnxruntime])
#   Downloading evaluate-0.4.3-py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: protobuf>=3.20.1 in /usr/local/lib/python3.11/dist-packages (from optimum[onnxruntime]) (4.25.6)
# Collecting protobuf>=3.20.1 (from optimum[onnxruntime])
#   Downloading protobuf-5.29.3-cp38-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets>=1.2.1->optimum[onnxruntime]) (3.17.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets>=1.2.1->optimum[onnxruntime]) (17.0.0)
# Collecting pyarrow>=15.0.0 (from datasets>=1.2.1->optimum[onnxruntime])
#   Downloading pyarrow-19.0.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (3.3 kB)
# Collecting dill<0.3.9,>=0.3.0 (from datasets>=1.2.1->optimum[onnxruntime])
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets>=1.2.1->optimum[onnxruntime]) (2.2.2)
# Collecting pandas (from datasets>=1.2.1->optimum[onnxruntime])
#   Downloading pandas-2.2.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 5.1 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets>=1.2.1->optimum[onnxruntime]) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/dist-packages (from datasets>=1.2.1->optimum[onnxruntime]) (4.67.1)
# Collecting xxhash (from datasets>=1.2.1->optimum[onnxruntime])
#   Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets>=1.2.1->optimum[onnxruntime])
#   Downloading multiprocess-0.70.16-py311-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2024.9.0,>=2023.1.0 (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets>=1.2.1->optimum[onnxruntime])
#   Downloading fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets>=1.2.1->optimum[onnxruntime]) (3.11.12)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets>=1.2.1->optimum[onnxruntime]) (6.0.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.8.0->optimum[onnxruntime]) (4.12.2)
# Collecting coloredlogs (from onnxruntime>=1.11.0->optimum[onnxruntime])
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.11/dist-packages (from onnxruntime>=1.11.0->optimum[onnxruntime]) (25.1.24)
# Collecting flatbuffers (from onnxruntime>=1.11.0->optimum[onnxruntime])
#   Downloading flatbuffers-25.2.10-py2.py3-none-any.whl.metadata (875 bytes)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from onnxruntime>=1.11.0->optimum[onnxruntime]) (1.13.1)
# Collecting sympy (from onnxruntime>=1.11.0->optimum[onnxruntime])
#   Downloading sympy-1.13.3-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->optimum[onnxruntime]) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->optimum[onnxruntime]) (3.1.5)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->optimum[onnxruntime]) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->optimum[onnxruntime]) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->optimum[onnxruntime]) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->optimum[onnxruntime]) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->optimum[onnxruntime]) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->optimum[onnxruntime]) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->optimum[onnxruntime]) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->optimum[onnxruntime]) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->optimum[onnxruntime]) (12.3.1.170)
# Collecting nvidia-cusparselt-cu12==0.6.2 (from torch>=1.11->optimum[onnxruntime])
#   Downloading nvidia_cusparselt_cu12-0.6.2-py3-none-manylinux2014_x86_64.whl.metadata (6.8 kB)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->optimum[onnxruntime]) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->optimum[onnxruntime]) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->optimum[onnxruntime]) (12.4.127)
# Collecting triton==3.2.0 (from torch>=1.11->optimum[onnxruntime])
#   Downloading triton-3.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.4 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->onnxruntime>=1.11.0->optimum[onnxruntime]) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.29->optimum[onnxruntime]) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.29->optimum[onnxruntime]) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.29->optimum[onnxruntime]) (0.5.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=1.2.1->optimum[onnxruntime]) (2.4.4)
# Collecting aiohappyeyeballs>=2.3.0 (from aiohttp->datasets>=1.2.1->optimum[onnxruntime])
#   Downloading aiohappyeyeballs-2.4.6-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=1.2.1->optimum[onnxruntime]) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=1.2.1->optimum[onnxruntime]) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=1.2.1->optimum[onnxruntime]) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=1.2.1->optimum[onnxruntime]) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=1.2.1->optimum[onnxruntime]) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=1.2.1->optimum[onnxruntime]) (1.18.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets>=1.2.1->optimum[onnxruntime]) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets>=1.2.1->optimum[onnxruntime]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets>=1.2.1->optimum[onnxruntime]) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets>=1.2.1->optimum[onnxruntime]) (2025.1.31)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.11.0->optimum[onnxruntime])
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.11->optimum[onnxruntime]) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets>=1.2.1->optimum[onnxruntime]) (2.8.2)
# Collecting python-dateutil>=2.8.2 (from pandas->datasets>=1.2.1->optimum[onnxruntime])
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets>=1.2.1->optimum[onnxruntime]) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets>=1.2.1->optimum[onnxruntime]) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets>=1.2.1->optimum[onnxruntime]) (1.17.0)
# Downloading datasets-3.2.0-py3-none-any.whl (480 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 18.4 MB/s eta 0:00:00
# Downloading numpy-2.2.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 84.8 MB/s eta 0:00:00
# Downloading onnxruntime-1.20.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (13.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 84.4 MB/s eta 0:00:00
# Downloading protobuf-5.29.3-cp38-abi3-manylinux2014_x86_64.whl (319 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 319.7/319.7 kB 22.5 MB/s eta 0:00:00
# Downloading torch-2.6.0-cp311-cp311-manylinux1_x86_64.whl (766.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 766.7/766.7 MB 2.3 MB/s eta 0:00:00
# Downloading nvidia_cusparselt_cu12-0.6.2-py3-none-manylinux2014_x86_64.whl (150.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.1/150.1 MB 7.1 MB/s eta 0:00:00
# Downloading triton-3.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (253.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.2/253.2 MB 5.3 MB/s eta 0:00:00
# Downloading transformers-4.48.3-py3-none-any.whl (9.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 59.5 MB/s eta 0:00:00
# Downloading evaluate-0.4.3-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 kB 6.5 MB/s eta 0:00:00
# Downloading onnx-1.17.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 43.3 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 9.1 MB/s eta 0:00:00
# Downloading fsspec-2024.9.0-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 14.6 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py311-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 11.4 MB/s eta 0:00:00
# Downloading pyarrow-19.0.0-cp311-cp311-manylinux_2_28_x86_64.whl (42.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.1/42.1 MB 19.8 MB/s eta 0:00:00
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.5 MB/s eta 0:00:00
# Downloading flatbuffers-25.2.10-py2.py3-none-any.whl (30 kB)
# Downloading pandas-2.2.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 67.7 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 15.0 MB/s eta 0:00:00
# Downloading aiohappyeyeballs-2.4.6-py3-none-any.whl (14 kB)
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 6.9 MB/s eta 0:00:00
# Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.9/229.9 kB 17.5 MB/s eta 0:00:00
# Installing collected packages: triton, nvidia-cusparselt-cu12, flatbuffers, xxhash, python-dateutil, pyarrow, protobuf, numpy, humanfriendly, fsspec, dill, aiohappyeyeballs, pandas, onnx, multiprocess, coloredlogs, torch, onnxruntime, transformers, datasets, evaluate
#   Attempting uninstall: triton
#     Found existing installation: triton 3.1.0
#     Uninstalling triton-3.1.0:
#       Successfully uninstalled triton-3.1.0
#   Attempting uninstall: flatbuffers
#     Found existing installation: flatbuffers 25.1.24
#     Uninstalling flatbuffers-25.1.24:
#       Successfully uninstalled flatbuffers-25.1.24
#   Attempting uninstall: python-dateutil
#     Found existing installation: python-dateutil 2.8.2
#     Uninstalling python-dateutil-2.8.2:
#       Successfully uninstalled python-dateutil-2.8.2
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 17.0.0
#     Uninstalling pyarrow-17.0.0:
#       Successfully uninstalled pyarrow-17.0.0
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.25.6
#     Uninstalling protobuf-4.25.6:
#       Successfully uninstalled protobuf-4.25.6
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
#   Attempting uninstall: aiohappyeyeballs
#     Found existing installation: aiohappyeyeballs 2.4.4
#     Uninstalling aiohappyeyeballs-2.4.4:
#       Successfully uninstalled aiohappyeyeballs-2.4.4
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
#   Attempting uninstall: torch
#     Found existing installation: torch 2.5.1+cu124
#     Uninstalling torch-2.5.1+cu124:
#       Successfully uninstalled torch-2.5.1+cu124
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.48.2
#     Uninstalling transformers-4.48.2:
#       Successfully uninstalled transformers-4.48.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# torchvision 0.20.1+cu124 requires torch==2.5.1, but you have torch 2.6.0 which is incompatible.
# langchain 0.3.17 requires numpy<2,>=1.22.4; python_version < "3.12", but you have numpy 2.2.2 which is incompatible.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
# fastai 2.7.18 requires torch<2.6,>=1.10, but you have torch 2.6.0 which is incompatible.
# tensorflow 2.18.0 requires numpy<2.1.0,>=1.26.0, but you have numpy 2.2.2 which is incompatible.
# pytensor 2.26.4 requires numpy<2,>=1.17.0, but you have numpy 2.2.2 which is incompatible.
# numba 0.61.0 requires numpy<2.2,>=1.24, but you have numpy 2.2.2 which is incompatible.
# torchaudio 2.5.1+cu124 requires torch==2.5.1, but you have torch 2.6.0 which is incompatible.
# cudf-cu12 24.12.0 requires pyarrow<19.0.0a0,>=14.0.0; platform_machine == "x86_64", but you have pyarrow 19.0.0 which is incompatible.
# thinc 8.2.5 requires numpy<2.0.0,>=1.19.0; python_version >= "3.9", but you have numpy 2.2.2 which is incompatible.
# gensim 4.3.3 requires numpy<2.0,>=1.18.5, but you have numpy 2.2.2 which is incompatible.
# pylibcudf-cu12 24.12.0 requires pyarrow<19.0.0a0,>=14.0.0; platform_machine == "x86_64", but you have pyarrow 19.0.0 which is incompatible.
# Successfully installed aiohappyeyeballs-2.4.6 coloredlogs-15.0.1 datasets-3.2.0 dill-0.3.8 evaluate-0.4.3 flatbuffers-25.2.10 fsspec-2024.9.0 humanfriendly-10.0 multiprocess-0.70.16 numpy-2.2.2 nvidia-cusparselt-cu12-0.6.2 onnx-1.17.0 onnxruntime-1.20.1 pandas-2.2.3 protobuf-5.29.3 pyarrow-19.0.0 python-dateutil-2.9.0.post0 torch-2.6.0 transformers-4.48.3 triton-3.2.0 xxhash-3.5.0

# %%
# !pip install --upgrade torchvision
# Out:
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (0.20.1+cu124)
# Collecting torchvision
#   Downloading torchvision-0.21.0-cp311-cp311-manylinux1_x86_64.whl.metadata (6.1 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision) (2.2.2)
# Requirement already satisfied: torch==2.6.0 in /usr/local/lib/python3.11/dist-packages (from torchvision) (2.6.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision) (11.1.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision) (2024.9.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch==2.6.0->torchvision) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch==2.6.0->torchvision) (3.0.2)
# Downloading torchvision-0.21.0-cp311-cp311-manylinux1_x86_64.whl (7.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 34.6 MB/s eta 0:00:00
# Installing collected packages: torchvision
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.20.1+cu124
#     Uninstalling torchvision-0.20.1+cu124:
#       Successfully uninstalled torchvision-0.20.1+cu124
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# fastai 2.7.18 requires torch<2.6,>=1.10, but you have torch 2.6.0 which is incompatible.
# Successfully installed torchvision-0.21.0

# %% [markdown]
# onnx-community/DeepSeek-R1-Distill-Qwen-1.5B-ONNX

# %%
from optimum.onnxruntime import ORTModelForSequenceClassification
from transformers import pipeline, AutoTokenizer

model = ORTModelForSequenceClassification.from_pretrained(save_directory, file_name="model_quantized.onnx")
tokenizer = AutoTokenizer.from_pretrained(save_directory)
classifier = pipeline("text-classification", model=model, tokenizer=tokenizer)
results = classifier("I love burritos!")
print(results)

# %%
import { pipeline, TextStreamer } from "@huggingface/transformers";

// Create a text generation pipeline
const generator = await pipeline(
  "text-generation",
  "onnx-community/DeepSeek-R1-Distill-Qwen-1.5B-ONNX",
  { dtype: "q4f16" },
);

// Define the list of messages
const messages = [
  { role: "user", content:  "Solve the equation: x^2 - 3x + 2 = 0" },
];

// Create text streamer
const streamer = new TextStreamer(generator.tokenizer, {
  skip_prompt: true,
  // callback_function: (text) => { }, // Optional callback function
})

// Generate a response
const output = await generator(messages, { max_new_tokens: 512, do_sample: false, streamer });
console.log(output[0].generated_text.at(-1).content);

# %%
# !node /content/1.js

# %%
# !npm i @huggingface/transformers
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏
# added 2 packages, and audited 83 packages in 3s
# ⠏
# ⠏20 packages are looking for funding
# ⠏  run `npm fund` for details
# ⠏
# found 0 vulnerabilities
# ⠏

# %% [markdown]
# ayhgشغال

# %%
#/content/package.json
 {
  "dependencies": {
    "@huggingface/transformers": "^3.3.3"
  },
  "type": "module"
}

# %%
# !node /content/1.js

# %% [markdown]
# Manually Download the Model

# %%
from huggingface_hub import snapshot_download

snapshot_download(repo_id="onnx-community/DeepSeek-R1-Distill-Qwen-1.5B-ONNX")

# %%
const generator = await pipeline(
  "text-generation",
  "/path/to/local/model",
  { dtype: "fp16" }
);

# %%
# !pip install onnxruntime
# Out:
# Requirement already satisfied: onnxruntime in /usr/local/lib/python3.11/dist-packages (1.20.1)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.11/dist-packages (from onnxruntime) (15.0.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.11/dist-packages (from onnxruntime) (25.2.10)
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/lib/python3.11/dist-packages (from onnxruntime) (2.2.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from onnxruntime) (24.2)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from onnxruntime) (5.29.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from onnxruntime) (1.13.1)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.11/dist-packages (from coloredlogs->onnxruntime) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->onnxruntime) (1.3.0)

# %%
# !npm install onnxruntime-node
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼
# up to date, audited 83 packages in 2s
# ⠼
# ⠼20 packages are looking for funding
# ⠼  run `npm fund` for details
# ⠼
# found 0 vulnerabilities
# ⠼

# %%
# !npm install onnxruntime-web
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋
# up to date, audited 83 packages in 3s
# ⠋
# ⠋20 packages are looking for funding
# ⠋  run `npm fund` for details
# ⠋
# found 0 vulnerabilities
# ⠋

# %%
# !node /content/1.js
# Out:
# file:///content/node_modules/@huggingface/transformers/dist/transformers.mjs:31095
#     throw Error(`${message}: "${remoteURL}".`);
#           ^
#
# Error: Unauthorized access to file: "https://huggingface.co/onnx-community/DeepSeek-R1-Qwen-1.5B-ONNX/resolve/main/tokenizer_config.json".
#     at handleError (file:///content/node_modules/@huggingface/transformers/dist/transformers.mjs:31095:11)
#     at getModelFile (file:///content/node_modules/@huggingface/transformers/dist/transformers.mjs:31328:24)
#     at process.processTicksAndRejections (node:internal/process/task_queues:95:5)
#     at async getModelJSON (file:///content/node_modules/@huggingface/transformers/dist/transformers.mjs:31427:18)
#     at async Promise.all (index 1)
#     at async loadTokenizer (file:///content/node_modules/@huggingface/transformers/dist/transformers.mjs:24731:18)
#     at async AutoTokenizer.from_pretrained (file:///content/node_modules/@huggingface/transformers/dist/transformers.mjs:29020:50)
#     at async Promise.all (index 0)
#     at async loadItems (file:///content/node_modules/@huggingface/transformers/dist/transformers.mjs:24602:5)
#     at async pipeline (file:///content/node_modules/@huggingface/transformers/dist/transformers.mjs:24532:21)
#
# Node.js v18.20.5

# %%
// npm i @huggingface/transformers
import { pipeline } from '@huggingface/transformers';

// Allocate pipeline
const pipe = await pipeline('text-generation', 'onnx-community/Qwen2.5-0.5B-Instruct-ONNX-MHA');

# %% [markdown]
# تحميل ملف معين

# %%
from huggingface_hub import hf_hub_download

# تحميل ملف معين فقط من النموذج
file_path = hf_hub_download(
    repo_id="onnx-community/DeepSeek-R1-Distill-Qwen-1.5B-ONNX",
    filename="tokenizer_config.json",  # اسم الملف المطلوب
    cache_dir="./model_files"  # تحديد مجلد التخزين المحلي (اختياري)
)

print(f"تم تحميل الملف في: {file_path}")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/6.63k [00:00<?, ?B/s]
# تم تحميل الملف في: ./model_files/models--onnx-community--DeepSeek-R1-Distill-Qwen-1.5B-ONNX/snapshots/f9c94fd59ec97bdb5e7587d09343797481a8c385/tokenizer_config.json

# %%
model.onnx_data

# %%
from huggingface_hub import hf_hub_download

# تحميل ملف معين فقط من النموذج
file_path = hf_hub_download(
    repo_id="onnx-community/DeepSeek-R1-Distill-Qwen-1.5B-ONNX",
    filename="model.onnx",  # اسم الملف المطلوب
    cache_dir="./model_files"  # تحديد مجلد التخزين المحلي (اختياري)
)

print(f"تم تحميل الملف في: {file_path}")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_http.py in hf_raise_for_status(response, endpoint_name)
#     405     try:
# --> 406         response.raise_for_status()
#     407     except HTTPError as e:
#
# /usr/local/lib/python3.11/dist-packages/requests/models.py in raise_for_status(self)
#    1023         if http_error_msg:
# -> 1024             raise HTTPError(http_error_msg, response=self)
#    1025
#
# HTTPError: 404 Client Error: Not Found for url: https://huggingface.co/onnx-community/DeepSeek-R1-Distill-Qwen-1.5B-ONNX/resolve/main/model.onnx
#
# The above exception was the direct cause of the following exception:
#
# EntryNotFoundError                        Traceback (most recent call last)
# <ipython-input-10-0a3e0a7878ba> in <cell line: 0>()
#       2
#       3 # تحميل ملف معين فقط من النموذج
# ----> 4 file_path = hf_hub_download(
#       5     repo_id="onnx-community/DeepSeek-R1-Distill-Qwen-1.5B-ONNX",
#       6     filename="model.onnx",  # اسم الملف المطلوب
#
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_validators.py in _inner_fn(*args, **kwargs)
#     112             kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
#     113
# --> 114         return fn(*args, **kwargs)
#     115
#     116     return _inner_fn  # type: ignore
#
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/file_download.py in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, user_agent, force_download, proxies, etag_timeout, token, local_files_only, headers, endpoint, resume_download, force_filename, local_dir_use_symlinks)
#     858         )
#     859     else:
# --> 860         return _hf_hub_download_to_cache_dir(
#     861             # Destination
#     862             cache_dir=cache_dir,
#
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/file_download.py in _hf_hub_download_to_cache_dir(cache_dir, repo_id, filename, repo_type, revision, endpoint, etag_timeout, headers, proxies, token, local_files_only, force_download)
#     921     # Try to get metadata (etag, commit_hash, url, size) from the server.
#     922     # If we can't, a HEAD request error is returned.
# --> 923     (url_to_download, etag, commit_hash, expected_size, head_call_error) = _get_metadata_or_catch_error(
#     924         repo_id=repo_id,
#     925         filename=filename,
#
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/file_download.py in _get_metadata_or_catch_error(repo_id, filename, repo_type, revision, endpoint, proxies, etag_timeout, headers, token, local_files_only, relative_filename, storage_folder)
#    1372         try:
#    1373             try:
# -> 1374                 metadata = get_hf_file_metadata(
#    1375                     url=url, proxies=proxies, timeout=etag_timeout, headers=headers, token=token
#    1376                 )
#
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_validators.py in _inner_fn(*args, **kwargs)
#     112             kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
#     113
# --> 114         return fn(*args, **kwargs)
#     115
#     116     return _inner_fn  # type: ignore
#
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/file_download.py in get_hf_file_metadata(url, token, proxies, timeout, library_name, library_version, user_agent, headers)
#    1292
#    1293     # Retrieve metadata
# -> 1294     r = _request_wrapper(
#    1295         method="HEAD",
#    1296         url=url,
#
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/file_download.py in _request_wrapper(method, url, follow_relative_redirects, **params)
#     276     # Recursively follow relative redirects
#     277     if follow_relative_redirects:
# --> 278         response = _request_wrapper(
#     279             method=method,
#     280             url=url,
#
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/file_download.py in _request_wrapper(method, url, follow_relative_redirects, **params)
#     300     # Perform request and return if status_code is not in the retry list.
#     301     response = get_session().request(method=method, url=url, **params)
# --> 302     hf_raise_for_status(response)
#     303     return response
#     304
#
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_http.py in hf_raise_for_status(response, endpoint_name)
#     415         elif error_code == "EntryNotFound":
#     416             message = f"{response.status_code} Client Error." + "\n\n" + f"Entry Not Found for url: {response.url}."
# --> 417             raise _format(EntryNotFoundError, message, response) from e
#     418
#     419         elif error_code == "GatedRepo":
#
# EntryNotFoundError: 404 Client Error. (Request ID: Root=1-67abae26-27e47f24620843c71c039a76;4ee62d4b-b507-454e-aa4d-8ba85faeb19b)
#
# Entry Not Found for url: https://huggingface.co/onnx-community/DeepSeek-R1-Distill-Qwen-1.5B-ONNX/resolve/main/model.onnx.

# %% [markdown]
# https://onnxruntime.ai/

# %%
# !pip install onnxruntime
# Out:
# Requirement already satisfied: onnxruntime in /usr/local/lib/python3.11/dist-packages (1.20.1)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.11/dist-packages (from onnxruntime) (15.0.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.11/dist-packages (from onnxruntime) (25.2.10)
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/lib/python3.11/dist-packages (from onnxruntime) (2.2.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from onnxruntime) (24.2)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from onnxruntime) (5.29.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from onnxruntime) (1.13.1)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.11/dist-packages (from coloredlogs->onnxruntime) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->onnxruntime) (1.3.0)

# %%
# !pip install onnxruntime-genai
# Out:
# Collecting onnxruntime-genai
#   Downloading onnxruntime_genai-0.5.2-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (648 bytes)
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/lib/python3.11/dist-packages (from onnxruntime-genai) (2.2.2)
# Requirement already satisfied: onnxruntime>=1.20.1 in /usr/local/lib/python3.11/dist-packages (from onnxruntime-genai) (1.20.1)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.11/dist-packages (from onnxruntime>=1.20.1->onnxruntime-genai) (15.0.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.11/dist-packages (from onnxruntime>=1.20.1->onnxruntime-genai) (25.2.10)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from onnxruntime>=1.20.1->onnxruntime-genai) (24.2)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from onnxruntime>=1.20.1->onnxruntime-genai) (5.29.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from onnxruntime>=1.20.1->onnxruntime-genai) (1.13.1)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.11/dist-packages (from coloredlogs->onnxruntime>=1.20.1->onnxruntime-genai) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->onnxruntime>=1.20.1->onnxruntime-genai) (1.3.0)
# Downloading onnxruntime_genai-0.5.2-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 14.8 MB/s eta 0:00:00
# Installing collected packages: onnxruntime-genai
# Successfully installed onnxruntime-genai-0.5.2

# %% [markdown]
# https://github.com/microsoft/onnxruntime/tree/main/js/node

# %%
# !npm install onnxruntime-node
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴
# up to date, audited 83 packages in 3s
# ⠴
# ⠴20 packages are looking for funding
# ⠴  run `npm fund` for details
# ⠴
# found 0 vulnerabilities
# ⠴

# %% [markdown]
# https://github.com/microsoft/onnxruntime-inference-examples/tree/main/js

# %%
# !git clone https://github.com/microsoft/onnxruntime-inference-examples.git
# Out:
# Cloning into 'onnxruntime-inference-examples'...
# remote: Enumerating objects: 5780, done.
# remote: Counting objects: 100% (1059/1059), done.
# remote: Compressing objects: 100% (260/260), done.
# remote: Total 5780 (delta 899), reused 804 (delta 797), pack-reused 4721 (from 1)
# Receiving objects: 100% (5780/5780), 438.46 MiB | 20.88 MiB/s, done.
# Resolving deltas: 100% (2421/2421), done.
# Updating files: 100% (1014/1014), done.

# %%
# %cd /content/onnxruntime-inference-examples/js/chat
# Out:
# /content/onnxruntime-inference-examples/js/chat

# %%
# !npm install
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦
# added 399 packages, and audited 400 packages in 1m
# ⠦
# ⠦72 packages are looking for funding
# ⠦  run `npm fund` for details
# ⠦
# found 0 vulnerabilities
# ⠦

# %%
# !npm run build
# Out:
# > localchat@0.0.0 build
# > webpack
#
# assets by path dist/*.wasm 37.3 MiB
#   asset dist/ort-wasm-simd-threaded.jsep.wasm 19.7 MiB [emitted] [from: node_modules/onnxruntime-web/dist/ort-wasm-simd-threaded.jsep.wasm] [copied]
#   asset dist/ort-wasm-simd.jsep.wasm 17.6 MiB [emitted] [from: node_modules/onnxruntime-web/dist/ort-wasm-simd.jsep.wasm] [copied]
# assets by path dist/*.js 4.75 MiB
#   asset dist/main.min.js 2.37 MiB [emitted] [javascript module] (name: dist/main.min) 1 related asset
#   asset dist/main.js 2.37 MiB [emitted] [javascript module] (name: dist/main) 1 related asset
# runtime modules 3.54 KiB 8 modules
# modules by path ./ 2.22 MiB
#   modules by path ./node_modules/ 2.21 MiB 30 modules
#   modules by path ./*.js 16.5 KiB
#     ./main.js 9.02 KiB [built] [code generated]
#     ./llm.js 7.5 KiB [built] [code generated]
# fs (ignored) 15 bytes [built] [code generated]
# path (ignored) 15 bytes [built] [code generated]
# url (ignored) 15 bytes [built] [code generated]
# sharp (ignored) 15 bytes [built] [code generated]
# fs (ignored) 15 bytes [built] [code generated]
# path (ignored) 15 bytes [built] [code generated]
# onnxruntime-node (ignored) 15 bytes [built] [code generated]
# webpack 5.97.1 compiled successfully in 3220 ms
# ⠙

# %%
# !npm run dev
# Out:
# > localchat@0.0.0 dev
# > webpack serve --no-client-overlay
#
# /content/onnxruntime-inference-examples/js/chat/node_modules/webpack-dev-server/lib/Server.js:2602
#         throw error;
#         ^
#
# Error: listen EADDRINUSE: address already in use :::8080
#     at Server.setupListenHandle [as _listen2] (node:net:1817:16)
#     at listenInCluster (node:net:1865:12)
#     at Server.listen (node:net:1953:7)
#     at READ_WRITE (/content/onnxruntime-inference-examples/js/chat/node_modules/webpack-dev-server/lib/Server.js:3349:23)
#     at new Promise (<anonymous>)
#     at Server.start (/content/onnxruntime-inference-examples/js/chat/node_modules/webpack-dev-server/lib/Server.js:3347:7)
#     at async Command.<anonymous> (/content/onnxruntime-inference-examples/js/chat/node_modules/@webpack-cli/serve/lib/index.js:158:21)
#     at async Command.parseAsync (/content/onnxruntime-inference-examples/js/chat/node_modules/webpack-cli/node_modules/commander/lib/command.js:935:5)
#     at async Command.<anonymous> (/content/onnxruntime-inference-examples/js/chat/node_modules/webpack-cli/lib/webpack-cli.js:1356:13)
#     at async Command.parseAsync (/content/onnxruntime-inference-examples/js/chat/node_modules/webpack-cli/node_modules/commander/lib/command.js:935:5) {
#   code: 'EADDRINUSE',
#   errno: -98,
#   syscall: 'listen',
#   address: '::',
#   port: 8080
# }
#
# Node.js v18.20.5
# ⠙

# %% [markdown]
# https://onnxruntime.ai/docs/build/inferencing.html

# %% [markdown]
# https://huggingface.co/docs/optimum/quicktour

# %%
# !optimum-cli export onnx --model gpt2 gpt2_onnx/
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# 2025-02-11 20:20:44.382951: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1739305244.684025   14238 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1739305244.764837   14238 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-11 20:20:45.366998: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# config.json: 100% 665/665 [00:00<00:00, 3.08MB/s]
# model.safetensors: 100% 548M/548M [00:08<00:00, 65.3MB/s]
# generation_config.json: 100% 124/124 [00:00<00:00, 612kB/s]
# tokenizer_config.json: 100% 26.0/26.0 [00:00<00:00, 166kB/s]
# vocab.json: 100% 1.04M/1.04M [00:00<00:00, 1.98MB/s]
# merges.txt: 100% 456k/456k [00:00<00:00, 2.59MB/s]
# tokenizer.json: 100% 1.36M/1.36M [00:00<00:00, 7.02MB/s]
# /usr/local/lib/python3.11/dist-packages/transformers/modeling_attn_mask_utils.py:116: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if (input_shape[-1] > 1 or self.sliding_window is not None) and self.is_causal:
# /usr/local/lib/python3.11/dist-packages/optimum/exporters/onnx/model_patcher.py:454: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if past_key_values_length > 0:
# Found different candidate ONNX initializers (likely duplicate) for the tied weights:
# 	lm_head.weight: {'onnx::MatMul_3510'}
# 	transformer.wte.weight: {'transformer.wte.weight'}

# %%
# !mv /content/onnxruntime-inference-examples/js/chat/gpt2_onnx /content/gpt2_onnx

# %%
from optimum.onnxruntime import ORTModelForSequenceClassification
from transformers import pipeline, AutoTokenizer

model = ORTModelForSequenceClassification.from_pretrained(save_directory, file_name="/content/gpt2_onnx/model.onnx")
tokenizer = AutoTokenizer.from_pretrained(save_directory)
classifier = pipeline("text-classification", model=model, tokenizer=tokenizer)
results = classifier("I love burritos!")
print(results)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-b47f10e16ba4> in <cell line: 0>()
#       2 from transformers import pipeline, AutoTokenizer
#       3
# ----> 4 model = ORTModelForSequenceClassification.from_pretrained(save_directory, file_name="/content/gpt2_onnx/model.onnx")
#       5 tokenizer = AutoTokenizer.from_pretrained(save_directory)
#       6 classifier = pipeline("text-classification", model=model, tokenizer=tokenizer)
#
# NameError: name 'save_directory' is not defined

# %%
from optimum.onnxruntime import ORTModelForSequenceClassification
from transformers import pipeline, AutoTokenizer

model = ORTModelForSequenceClassification.from_pretrained(save_directory, file_name="/content/gpt2_onnx/model.onnx")
tokenizer = AutoTokenizer.from_pretrained(save_directory)
classifier = pipeline("text", model=model, tokenizer=tokenizer)
results = classifier("who is ai?")
print(results)

# %%
from optimum.onnxruntime import ORTModelForCausalLM  # Or ORTModel if necessary
from transformers import pipeline, AutoTokenizer

model = ORTModelForCausalLM.from_pretrained(save_directory, file_name="/content/gpt2_onnx/model.onnx")
tokenizer = AutoTokenizer.from_pretrained(save_directory)
classifier = pipeline("text-generation", model=model, tokenizer=tokenizer)
results = classifier("who is ai?")
print(results)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-e4dbc5021546> in <cell line: 0>()
#       2 from transformers import pipeline, AutoTokenizer
#       3
# ----> 4 model = ORTModelForCausalLM.from_pretrained(save_directory, file_name="/content/gpt2_onnx/model.onnx")
#       5 tokenizer = AutoTokenizer.from_pretrained(save_directory)
#       6 classifier = pipeline("text-generation", model=model, tokenizer=tokenizer)
#
# NameError: name 'save_directory' is not defined

# %%
from optimum.onnxruntime import ORTModelForCausalLM  # Or ORTModel if necessary
from transformers import pipeline, AutoTokenizer

model = ORTModelForCausalLM.from_pretrained(save_directory, file_name="/content/gpt2_onnx/model.onnx")
tokenizer = AutoTokenizer.from_pretrained(save_directory)
classifier = pipeline("text-generation", model=model, tokenizer=tokenizer)
results = classifier("who is ai?")
print(results)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-e4dbc5021546> in <cell line: 0>()
#       2 from transformers import pipeline, AutoTokenizer
#       3
# ----> 4 model = ORTModelForCausalLM.from_pretrained(save_directory, file_name="/content/gpt2_onnx/model.onnx")
#       5 tokenizer = AutoTokenizer.from_pretrained(save_directory)
#       6 classifier = pipeline("text-generation", model=model, tokenizer=tokenizer)
#
# NameError: name 'save_directory' is not defined

# %% [markdown]
# شغال من مسار

# %%
from optimum.onnxruntime import ORTModelForCausalLM
from transformers import pipeline, AutoTokenizer

save_directory = "/content/gpt2_onnx"  # Replace with your actual path

model = ORTModelForCausalLM.from_pretrained(save_directory, file_name="model.onnx")
tokenizer = AutoTokenizer.from_pretrained(save_directory)
classifier = pipeline("text-generation", model=model, tokenizer=tokenizer)
results = classifier("who is ai?")
print(results)
# Out:
# Device set to use cpu
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': 'who is ai?\n\nWhat is this?\n\nIs this a "special treatment?" And what is your response once it\'s done?\n\nWhere it goes\n\nWhen you\'ve done this interview in person, the first day,'}]

# %%
import { pipeline, TextStreamer } from "@huggingface/transformers";

// Create a text generation pipeline
const generator = await pipeline(
  "text-generation",
  "onnx-community/DeepSeek-R1-Distill-Qwen-1.5B-ONNX",
  { dtype: "q4f16" },
);

// Define the list of messages
const messages = [
  { role: "user", content:  "Solve the equation: x^2 - 3x + 2 = 0" },
];

// Create text streamer
const streamer = new TextStreamer(generator.tokenizer, {
  skip_prompt: true,
  // callback_function: (text) => { }, // Optional callback function
})

// Generate a response
const output = await generator(messages, { max_new_tokens: 512, do_sample: false, streamer });
console.log(output[0].generated_text.at(-1).content);

# %%
import os
os.environ['HF_READ_TOKEN'] = 'x'

# %%
# !node /content/1.js
# Out:
# file:///content/node_modules/@huggingface/transformers/dist/transformers.mjs:31095
#     throw Error(`${message}: "${remoteURL}".`);
#           ^
#
# Error: Unauthorized access to file: "https://huggingface.co/content/gpt2_onnx/resolve/main/tokenizer_config.json".
#     at handleError (file:///content/node_modules/@huggingface/transformers/dist/transformers.mjs:31095:11)
#     at getModelFile (file:///content/node_modules/@huggingface/transformers/dist/transformers.mjs:31328:24)
#     at process.processTicksAndRejections (node:internal/process/task_queues:95:5)
#     at async getModelJSON (file:///content/node_modules/@huggingface/transformers/dist/transformers.mjs:31427:18)
#     at async Promise.all (index 1)
#     at async loadTokenizer (file:///content/node_modules/@huggingface/transformers/dist/transformers.mjs:24731:18)
#     at async AutoTokenizer.from_pretrained (file:///content/node_modules/@huggingface/transformers/dist/transformers.mjs:29020:50)
#     at async Promise.all (index 0)
#     at async loadItems (file:///content/node_modules/@huggingface/transformers/dist/transformers.mjs:24602:5)
#     at async pipeline (file:///content/node_modules/@huggingface/transformers/dist/transformers.mjs:24532:21)
#
# Node.js v18.20.5

# %%
import { pipeline } from '@huggingface/transformers';

const generator = await pipeline(
  "text-generation",
  "/content/gpt2_onnx", // Path to your locally downloaded model
);

const prompt = "Write a story about a cat who goes on an adventure:";

const generatedText = await generator(prompt, {
  max_new_tokens: 100, // Adjust as needed
});

console.log(generatedText[0].generated_text); // Print the generated text

# %%
import { pipeline } from '@huggingface/transformers';

const generator = await pipeline(
  "text-generation",
  "./deepseek_model", // Path to your locally downloaded model
);

# %%
- from transformers import AutoModelForSequenceClassification
+ from optimum.intel.openvino import OVModelForSequenceClassification
  from transformers import AutoTokenizer, pipeline

  # Download a tokenizer and model from the Hub and convert to OpenVINO format
  tokenizer = AutoTokenizer.from_pretrained(model_id)
  model_id = "distilbert-base-uncased-finetuned-sst-2-english"
- model = AutoModelForSequenceClassification.from_pretrained(model_id)
+ model = OVModelForSequenceClassification.from_pretrained(model_id, export=True)

  # Run inference!
  classifier = pipeline("text-classification", model=model, tokenizer=tokenizer)
  results = classifier("He's a dreadful magician.")

# %%
- from transformers import AutoModelForSequenceClassification
+ from optimum.intel.openvino import OVModelForSequenceClassification
  from transformers import AutoTokenizer, pipeline

  # Download a tokenizer and model from the Hub and convert to OpenVINO format
  tokenizer = AutoTokenizer.from_pretrained(model_id)
  model_id = "distilbert-base-uncased-finetuned-sst-2-english"
- model = AutoModelForSequenceClassification.from_pretrained(model_id)
+ model = OVModelForSequenceClassification.from_pretrained(model_id, export=True)

  # Run inference!
  classifier = pipeline("text-classification", model=model, tokenizer=tokenizer)
  results = classifier("He's a dreadful magician.")

# %%
from transformers import AutoModelForSequenceClassification
from transformers import AutoTokenizer, pipeline


model_id = "distilbert-base-uncased-finetuned-sst-2-english"
model = OVModelForSequenceClassification.from_pretrained(model_id, export=True)
classifier = pipeline("text-classification", model=model, tokenizer=tokenizer)
results = classifier("He's a dreadful magician.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-230fcbeb2e13> in <cell line: 0>()
#       2 from transformers import AutoTokenizer, pipeline
#       3
# ----> 4 tokenizer = AutoTokenizer.from_pretrained(model_id)
#       5 model_id = "distilbert-base-uncased-finetuned-sst-2-english"
#       6 model = OVModelForSequenceClassification.from_pretrained(model_id, export=True)
#
# NameError: name 'model_id' is not defined

# %%
# -------------------------------------------------------------------------
# Copyright (c) Microsoft Corporation. All rights reserved.
# Licensed under the MIT License.
# --------------------------------------------------------------------------
from __future__ import annotations

import collections
import collections.abc
import os
import typing
import warnings
from collections.abc import Sequence
from typing import Any

from onnxruntime.capi import _pybind_state as C

if typing.TYPE_CHECKING:
    import onnxruntime


def get_ort_device_type(device_type: str, device_index) -> C.OrtDevice:
    if device_type == "cuda":
        return C.OrtDevice.cuda()
    elif device_type == "cann":
        return C.OrtDevice.cann()
    elif device_type == "cpu":
        return C.OrtDevice.cpu()
    elif device_type == "dml":
        return C.OrtDevice.dml()
    elif device_type == "webgpu":
        return C.OrtDevice.webgpu()
    elif device_type == "ort":
        return C.get_ort_device(device_index).device_type()
    else:
        raise Exception("Unsupported device type: " + device_type)


class AdapterFormat:
    """
    This class is used to create adapter files from python structures
    """

    def __init__(self, adapter=None) -> None:
        if adapter is None:
            self._adapter = C.AdapterFormat()
        else:
            self._adapter = adapter

    @staticmethod
    def read_adapter(file_path: os.PathLike) -> AdapterFormat:
        return AdapterFormat(C.AdapterFormat.read_adapter(file_path))

    def export_adapter(self, file_path: os.PathLike):
        """
        This function writes a file at the specified location
        in onnxrunitme adapter format containing Lora parameters.

        :param file_path: absolute path for the adapter
        """
        self._adapter.export_adapter(file_path)

    def get_format_version(self):
        return self._adapter.format_version

    def set_adapter_version(self, adapter_version: int):
        self._adapter.adapter_version = adapter_version

    def get_adapter_version(self):
        return self._adapter.adapter_version

    def set_model_version(self, model_version: int):
        self._adapter.model_version = model_version

    def get_model_version(self):
        return self._adapter.model_version

    def set_parameters(self, params: dict[str, OrtValue]):
        self._adapter.parameters = {k: v._ortvalue for k, v in params.items()}

    def get_parameters(self) -> dict[str, OrtValue]:
        return {k: OrtValue(v) for k, v in self._adapter.parameters.items()}


def check_and_normalize_provider_args(
    providers: Sequence[str | tuple[str, dict[Any, Any]]] | None,
    provider_options: Sequence[dict[Any, Any]] | None,
    available_provider_names: Sequence[str],
):
    """
    Validates the 'providers' and 'provider_options' arguments and returns a
        normalized version.

    :param providers: Optional sequence of providers in order of decreasing
        precedence. Values can either be provider names or tuples of
        (provider name, options dict).
    :param provider_options: Optional sequence of options dicts corresponding
        to the providers listed in 'providers'.
    :param available_provider_names: The available provider names.

    :return: Tuple of (normalized 'providers' sequence, normalized
        'provider_options' sequence).

    'providers' can contain either names or names and options. When any options
        are given in 'providers', 'provider_options' should not be used.

    The normalized result is a tuple of:
    1. Sequence of provider names in the same order as 'providers'.
    2. Sequence of corresponding provider options dicts with string keys and
        values. Unspecified provider options yield empty dicts.
    """
    if providers is None:
        return [], []

    provider_name_to_options = collections.OrderedDict()

    def set_provider_options(name, options):
        if name not in available_provider_names:
            warnings.warn(
                "Specified provider '{}' is not in available provider names.Available providers: '{}'".format(
                    name, ", ".join(available_provider_names)
                )
            )

        if name in provider_name_to_options:
            warnings.warn(f"Duplicate provider '{name}' encountered, ignoring.")
            return

        normalized_options = {str(key): str(value) for key, value in options.items()}
        provider_name_to_options[name] = normalized_options

    if not isinstance(providers, collections.abc.Sequence):
        raise ValueError("'providers' should be a sequence.")

    if provider_options is not None:
        if not isinstance(provider_options, collections.abc.Sequence):
            raise ValueError("'provider_options' should be a sequence.")

        if len(providers) != len(provider_options):
            raise ValueError("'providers' and 'provider_options' should be the same length if both are given.")

        if not all(isinstance(provider, str) for provider in providers):
            raise ValueError("Only string values for 'providers' are supported if 'provider_options' is given.")

        if not all(isinstance(options_for_provider, dict) for options_for_provider in provider_options):
            raise ValueError("'provider_options' values must be dicts.")

        for name, options in zip(providers, provider_options, strict=False):
            set_provider_options(name, options)

    else:
        for provider in providers:
            if isinstance(provider, str):
                set_provider_options(provider, {})
            elif (
                isinstance(provider, tuple)
                and len(provider) == 2
                and isinstance(provider[0], str)
                and isinstance(provider[1], dict)
            ):
                set_provider_options(provider[0], provider[1])
            else:
                raise ValueError("'providers' values must be either strings or (string, dict) tuples.")

    return list(provider_name_to_options.keys()), list(provider_name_to_options.values())


class Session:
    """
    This is the main class used to run a model.
    """

    def __init__(self):
        # self._sess is managed by the derived class and relies on bindings from C.InferenceSession
        self._sess = None
        self._enable_fallback = True

    def get_session_options(self):
        "Return the session options. See :class:`onnxruntime.SessionOptions`."
        return self._sess_options

    def get_inputs(self):
        "Return the inputs metadata as a list of :class:`onnxruntime.NodeArg`."
        return self._inputs_meta

    def get_outputs(self):
        "Return the outputs metadata as a list of :class:`onnxruntime.NodeArg`."
        return self._outputs_meta

    def get_overridable_initializers(self):
        "Return the inputs (including initializers) metadata as a list of :class:`onnxruntime.NodeArg`."
        return self._overridable_initializers

    def get_modelmeta(self):
        "Return the metadata. See :class:`onnxruntime.ModelMetadata`."
        return self._model_meta

    def get_providers(self):
        "Return list of registered execution providers."
        return self._providers

    def get_provider_options(self):
        "Return registered execution providers' configurations."
        return self._provider_options

    def set_providers(self, providers=None, provider_options=None):
        """
        Register the input list of execution providers. The underlying session is re-created.

        :param providers: Optional sequence of providers in order of decreasing
            precedence. Values can either be provider names or tuples of
            (provider name, options dict). If not provided, then all available
            providers are used with the default precedence.
        :param provider_options: Optional sequence of options dicts corresponding
            to the providers listed in 'providers'.

        'providers' can contain either names or names and options. When any options
        are given in 'providers', 'provider_options' should not be used.

        The list of providers is ordered by precedence. For example
        `['CUDAExecutionProvider', 'CPUExecutionProvider']`
        means execute a node using CUDAExecutionProvider if capable,
        otherwise execute using CPUExecutionProvider.
        """
        # recreate the underlying C.InferenceSession
        self._reset_session(providers, provider_options)

    def disable_fallback(self):
        """
        Disable session.run() fallback mechanism.
        """
        self._enable_fallback = False

    def enable_fallback(self):
        """
        Enable session.Run() fallback mechanism. If session.Run() fails due to an internal Execution Provider failure,
        reset the Execution Providers enabled for this session.
        If GPU is enabled, fall back to CUDAExecutionProvider.
        otherwise fall back to CPUExecutionProvider.
        """
        self._enable_fallback = True

    def _validate_input(self, feed_input_names):
        missing_input_names = []
        for input in self._inputs_meta:
            if input.name not in feed_input_names and not input.type.startswith("optional"):
                missing_input_names.append(input.name)
        if missing_input_names:
            raise ValueError(
                f"Required inputs ({missing_input_names}) are missing from input feed ({feed_input_names})."
            )

    def run(self, output_names, input_feed, run_options=None):
        """
        Compute the predictions.

        :param output_names: name of the outputs
        :param input_feed: dictionary ``{ input_name: input_value }``
        :param run_options: See :class:`onnxruntime.RunOptions`.
        :return: list of results, every result is either a numpy array,
            a sparse tensor, a list or a dictionary.

        ::

            sess.run([output_name], {input_name: x})
        """
        self._validate_input(list(input_feed.keys()))
        if not output_names:
            output_names = [output.name for output in self._outputs_meta]
        try:
            return self._sess.run(output_names, input_feed, run_options)
        except C.EPFail as err:
            if self._enable_fallback:
                print(f"EP Error: {err!s} using {self._providers}")
                print(f"Falling back to {self._fallback_providers} and retrying.")
                self.set_providers(self._fallback_providers)
                # Fallback only once.
                self.disable_fallback()
                return self._sess.run(output_names, input_feed, run_options)
            raise

    def run_async(self, output_names, input_feed, callback, user_data, run_options=None):
        """
        Compute the predictions asynchronously in a separate cxx thread from ort intra-op threadpool.

        :param output_names: name of the outputs
        :param input_feed: dictionary ``{ input_name: input_value }``
        :param callback: python function that accept array of results, and a status string on error.
            The callback will be invoked by a cxx thread from ort intra-op threadpool.
        :param run_options: See :class:`onnxruntime.RunOptions`.

        ::
            class MyData:
                def __init__(self):
                    # ...
                def save_results(self, results):
                    # ...

            def callback(results: np.ndarray, user_data: MyData, err: str) -> None:
              if err:
                 print (err)
              else:
                # save results to user_data

            sess.run_async([output_name], {input_name: x}, callback)
        """
        self._validate_input(list(input_feed.keys()))
        if not output_names:
            output_names = [output.name for output in self._outputs_meta]
        return self._sess.run_async(output_names, input_feed, callback, user_data, run_options)

    def run_with_ort_values(self, output_names, input_dict_ort_values, run_options=None):
        """
        Compute the predictions.

        :param output_names: name of the outputs
        :param input_dict_ort_values: dictionary ``{ input_name: input_ort_value }``
            See ``OrtValue`` class how to create `OrtValue`
            from numpy array or `SparseTensor`
        :param run_options: See :class:`onnxruntime.RunOptions`.
        :return: an array of `OrtValue`

        ::

            sess.run([output_name], {input_name: x})
        """

        def invoke(sess, output_names, input_dict_ort_values, run_options):
            input_dict = {}
            for n, v in input_dict_ort_values.items():
                input_dict[n] = v._get_c_value()
            result = sess.run_with_ort_values(input_dict, output_names, run_options)
            if not isinstance(result, C.OrtValueVector):
                raise TypeError("run_with_ort_values() must return a instance of type 'OrtValueVector'.")
            ort_values = [OrtValue(v) for v in result]
            return ort_values

        self._validate_input(list(input_dict_ort_values.keys()))
        if not output_names:
            output_names = [output.name for output in self._outputs_meta]
        try:
            return invoke(self._sess, output_names, input_dict_ort_values, run_options)
        except C.EPFail as err:
            if self._enable_fallback:
                print(f"EP Error: {err!s} using {self._providers}")
                print(f"Falling back to {self._fallback_providers} and retrying.")
                self.set_providers(self._fallback_providers)
                # Fallback only once.
                self.disable_fallback()
                return invoke(self._sess, output_names, input_dict_ort_values, run_options)
            raise

    def end_profiling(self):
        """
        End profiling and return results in a file.

        The results are stored in a filename if the option
        :meth:`onnxruntime.SessionOptions.enable_profiling`.
        """
        return self._sess.end_profiling()

    def get_profiling_start_time_ns(self):
        """
        Return the nanoseconds of profiling's start time
        Comparable to time.monotonic_ns() after Python 3.3
        On some platforms, this timer may not be as precise as nanoseconds
        For instance, on Windows and MacOS, the precision will be ~100ns
        """
        return self._sess.get_profiling_start_time_ns

    def io_binding(self):
        "Return an onnxruntime.IOBinding object`."
        return IOBinding(self)

    def run_with_iobinding(self, iobinding, run_options=None):
        """
        Compute the predictions.

        :param iobinding: the iobinding object that has graph inputs/outputs bind.
        :param run_options: See :class:`onnxruntime.RunOptions`.
        """
        self._sess.run_with_iobinding(iobinding._iobinding, run_options)

    def get_tuning_results(self):
        return self._sess.get_tuning_results()

    def set_tuning_results(self, results, *, error_on_invalid=False):
        return self._sess.set_tuning_results(results, error_on_invalid)

    def run_with_ortvaluevector(self, run_options, feed_names, feeds, fetch_names, fetches, fetch_devices):
        """
        Compute the predictions similar to other run_*() methods but with minimal C++/Python conversion overhead.

        :param run_options: See :class:`onnxruntime.RunOptions`.
        :param feed_names: list of input names.
        :param feeds: list of input OrtValue.
        :param fetch_names: list of output names.
        :param fetches: list of output OrtValue.
        :param fetch_devices: list of output devices.
        """
        self._sess.run_with_ortvaluevector(run_options, feed_names, feeds, fetch_names, fetches, fetch_devices)


class InferenceSession(Session):
    """
    This is the main class used to run a model.
    """

    def __init__(
        self,
        path_or_bytes: str | bytes | os.PathLike,
        sess_options: onnxruntime.SessionOptions | None = None,
        providers: Sequence[str | tuple[str, dict[Any, Any]]] | None = None,
        provider_options: Sequence[dict[Any, Any]] | None = None,
        **kwargs,
    ) -> None:
        """
        :param path_or_bytes: Filename or serialized ONNX or ORT format model in a byte string.
        :param sess_options: Session options.
        :param providers: Optional sequence of providers in order of decreasing
            precedence. Values can either be provider names or tuples of
            (provider name, options dict). If not provided, then all available
            providers are used with the default precedence.
        :param provider_options: Optional sequence of options dicts corresponding
            to the providers listed in 'providers'.

        The model type will be inferred unless explicitly set in the SessionOptions.
        To explicitly set:

        ::

            so = onnxruntime.SessionOptions()
            # so.add_session_config_entry('session.load_model_format', 'ONNX') or
            so.add_session_config_entry('session.load_model_format', 'ORT')

        A file extension of '.ort' will be inferred as an ORT format model.
        All other filenames are assumed to be ONNX format models.

        'providers' can contain either names or names and options. When any options
        are given in 'providers', 'provider_options' should not be used.

        The list of providers is ordered by precedence. For example
        `['CUDAExecutionProvider', 'CPUExecutionProvider']`
        means execute a node using `CUDAExecutionProvider`
        if capable, otherwise execute using `CPUExecutionProvider`.
        """
        super().__init__()

        if isinstance(path_or_bytes, (str, os.PathLike)):
            self._model_path = os.fspath(path_or_bytes)
            self._model_bytes = None
        elif isinstance(path_or_bytes, bytes):
            self._model_path = None
            self._model_bytes = path_or_bytes  # TODO: This is bad as we're holding the memory indefinitely
        else:
            raise TypeError(f"Unable to load from type '{type(path_or_bytes)}'")

        self._sess_options = sess_options
        self._sess_options_initial = sess_options
        self._enable_fallback = True
        if "read_config_from_model" in kwargs:
            self._read_config_from_model = int(kwargs["read_config_from_model"]) == 1
        else:
            self._read_config_from_model = os.environ.get("ORT_LOAD_CONFIG_FROM_MODEL") == "1"

        # internal parameters that we don't expect to be used in general so aren't documented
        disabled_optimizers = kwargs.get("disabled_optimizers")

        try:
            self._create_inference_session(providers, provider_options, disabled_optimizers)
        except (ValueError, RuntimeError) as e:
            if self._enable_fallback:
                try:
                    print("*************** EP Error ***************")
                    print(f"EP Error {e} when using {providers}")
                    print(f"Falling back to {self._fallback_providers} and retrying.")
                    print("****************************************")
                    self._create_inference_session(self._fallback_providers, None)
                    # Fallback only once.
                    self.disable_fallback()
                    return
                except Exception as fallback_error:
                    raise fallback_error from e
            # Fallback is disabled. Raise the original error.
            raise e

    def _create_inference_session(self, providers, provider_options, disabled_optimizers=None):
        available_providers = C.get_available_providers()

        # Tensorrt can fall back to CUDA if it's explicitly assigned. All others fall back to CPU.
        if "TensorrtExecutionProvider" in available_providers:
            if (
                providers
                and any(
                    provider == "CUDAExecutionProvider"
                    or (isinstance(provider, tuple) and provider[0] == "CUDAExecutionProvider")
                    for provider in providers
                )
                and any(
                    provider == "TensorrtExecutionProvider"
                    or (isinstance(provider, tuple) and provider[0] == "TensorrtExecutionProvider")
                    for provider in providers
                )
            ):
                self._fallback_providers = ["CUDAExecutionProvider", "CPUExecutionProvider"]
            else:
                self._fallback_providers = ["CPUExecutionProvider"]
        # MIGraphX can fall back to ROCM if it's explicitly assigned. All others fall back to CPU.
        elif "MIGraphXExecutionProvider" in available_providers:
            if providers and any(
                provider == "ROCMExecutionProvider"
                or (isinstance(provider, tuple) and provider[0] == "ROCMExecutionProvider")
                for provider in providers
            ):
                self._fallback_providers = ["ROCMExecutionProvider", "CPUExecutionProvider"]
            else:
                self._fallback_providers = ["CPUExecutionProvider"]
        else:
            self._fallback_providers = ["CPUExecutionProvider"]

        # validate providers and provider_options before other initialization
        providers, provider_options = check_and_normalize_provider_args(
            providers, provider_options, available_providers
        )

        session_options = self._sess_options if self._sess_options else C.get_default_session_options()

        self._register_ep_custom_ops(session_options, providers, provider_options, available_providers)

        if self._model_path:
            sess = C.InferenceSession(session_options, self._model_path, True, self._read_config_from_model)
        else:
            sess = C.InferenceSession(session_options, self._model_bytes, False, self._read_config_from_model)

        if disabled_optimizers is None:
            disabled_optimizers = set()
        elif not isinstance(disabled_optimizers, set):
            # convert to set. assumes iterable
            disabled_optimizers = set(disabled_optimizers)

        # initialize the C++ InferenceSession
        sess.initialize_session(providers, provider_options, disabled_optimizers)

        self._sess = sess
        self._sess_options = self._sess.session_options
        self._inputs_meta = self._sess.inputs_meta
        self._outputs_meta = self._sess.outputs_meta
        self._overridable_initializers = self._sess.overridable_initializers
        self._model_meta = self._sess.model_meta
        self._providers = self._sess.get_providers()
        self._provider_options = self._sess.get_provider_options()
        self._profiling_start_time_ns = self._sess.get_profiling_start_time_ns

    def _reset_session(self, providers, provider_options):
        "release underlying session object."
        # meta data references session internal structures
        # so they must be set to None to decrement _sess reference count.
        self._sess_options = None
        self._inputs_meta = None
        self._outputs_meta = None
        self._overridable_initializers = None
        self._model_meta = None
        self._providers = None
        self._provider_options = None
        self._profiling_start_time_ns = None

        # create a new C.InferenceSession
        self._sess = None
        self._sess_options = self._sess_options_initial
        self._create_inference_session(providers, provider_options)

    def _register_ep_custom_ops(self, session_options, providers, provider_options, available_providers):
        for i in range(len(providers)):
            if providers[i] in available_providers and providers[i] == "TensorrtExecutionProvider":
                C.register_tensorrt_plugins_as_custom_ops(session_options, provider_options[i])
            elif (
                isinstance(providers[i], tuple)
                and providers[i][0] in available_providers
                and providers[i][0] == "TensorrtExecutionProvider"
            ):
                C.register_tensorrt_plugins_as_custom_ops(session_options, providers[i][1])


class IOBinding:
    """
    This class provides API to bind input/output to a specified device, e.g. GPU.
    """

    def __init__(self, session: Session):
        self._iobinding = C.SessionIOBinding(session._sess)
        self._numpy_obj_references = {}

    def bind_cpu_input(self, name, arr_on_cpu):
        """
        bind an input to array on CPU
        :param name: input name
        :param arr_on_cpu: input values as a python array on CPU
        """
        # Hold a reference to the numpy object as the bound OrtValue is backed
        # directly by the data buffer of the numpy object and so the numpy object
        # must be around until this IOBinding instance is around
        self._numpy_obj_references[name] = arr_on_cpu
        self._iobinding.bind_input(name, arr_on_cpu)

    def bind_input(self, name, device_type, device_id, element_type, shape, buffer_ptr):
        """
        :param name: input name
        :param device_type: e.g. cpu, cuda, cann
        :param device_id: device id, e.g. 0
        :param element_type: input element type. It can be either numpy type (like numpy.float32) or an integer for onnx type (like onnx.TensorProto.BFLOAT16)
        :param shape: input shape
        :param buffer_ptr: memory pointer to input data
        """
        self._iobinding.bind_input(
            name,
            C.OrtDevice(
                get_ort_device_type(device_type, device_id),
                C.OrtDevice.default_memory(),
                device_id,
            ),
            element_type,
            shape,
            buffer_ptr,
        )

    def bind_ortvalue_input(self, name, ortvalue):
        """
        :param name: input name
        :param ortvalue: OrtValue instance to bind
        """
        self._iobinding.bind_ortvalue_input(name, ortvalue._ortvalue)

    def synchronize_inputs(self):
        self._iobinding.synchronize_inputs()

    def bind_output(
        self,
        name,
        device_type="cpu",
        device_id=0,
        element_type=None,
        shape=None,
        buffer_ptr=None,
    ):
        """
        :param name: output name
        :param device_type: e.g. cpu, cuda, cann, cpu by default
        :param device_id: device id, e.g. 0
        :param element_type: output element type. It can be either numpy type (like numpy.float32) or an integer for onnx type (like onnx.TensorProto.BFLOAT16)
        :param shape: output shape
        :param buffer_ptr: memory pointer to output data
        """

        # Follow the `if` path when the user has not provided any pre-allocated buffer but still
        # would like to bind an output to a specific device (e.g. cuda).
        # Pre-allocating an output buffer may not be an option for the user as :
        # (1) They may not want to use a custom allocator specific to the device they want to bind the output to,
        # in which case ORT will allocate the memory for the user
        # (2) The output has a dynamic shape and hence the size of the buffer may not be fixed across runs
        if buffer_ptr is None:
            self._iobinding.bind_output(
                name,
                C.OrtDevice(
                    get_ort_device_type(device_type, device_id),
                    C.OrtDevice.default_memory(),
                    device_id,
                ),
            )
        else:
            if element_type is None or shape is None:
                raise ValueError("`element_type` and `shape` are to be provided if pre-allocated memory is provided")
            self._iobinding.bind_output(
                name,
                C.OrtDevice(
                    get_ort_device_type(device_type, device_id),
                    C.OrtDevice.default_memory(),
                    device_id,
                ),
                element_type,
                shape,
                buffer_ptr,
            )

    def bind_ortvalue_output(self, name, ortvalue):
        """
        :param name: output name
        :param ortvalue: OrtValue instance to bind
        """
        self._iobinding.bind_ortvalue_output(name, ortvalue._ortvalue)

    def synchronize_outputs(self):
        self._iobinding.synchronize_outputs()

    def get_outputs(self):
        """
        Returns the output OrtValues from the Run() that preceded the call.
        The data buffer of the obtained OrtValues may not reside on CPU memory
        """
        outputs = self._iobinding.get_outputs()
        if not isinstance(outputs, C.OrtValueVector):
            raise TypeError("get_outputs() must return an instance of type 'OrtValueVector'.")
        return [OrtValue(ortvalue) for ortvalue in outputs]

    def get_outputs_as_ortvaluevector(self):
        return self._iobinding.get_outputs()

    def copy_outputs_to_cpu(self):
        """Copy output contents to CPU."""
        return self._iobinding.copy_outputs_to_cpu()

    def clear_binding_inputs(self):
        self._iobinding.clear_binding_inputs()

    def clear_binding_outputs(self):
        self._iobinding.clear_binding_outputs()


class OrtValue:
    """
    A data structure that supports all ONNX data formats (tensors and non-tensors) that allows users
    to place the data backing these on a device, for example, on a CUDA supported device.
    This class provides APIs to construct and deal with OrtValues.
    """

    def __init__(self, ortvalue, numpy_obj=None):
        if isinstance(ortvalue, C.OrtValue):
            self._ortvalue = ortvalue
            # Hold a ref count to the numpy object if the OrtValue is backed directly
            # by its data buffer so that it isn't destroyed when the OrtValue is in use
            self._numpy_obj = numpy_obj
        else:
            # An end user won't hit this error
            raise ValueError(
                "`Provided ortvalue` needs to be of type `onnxruntime.capi.onnxruntime_pybind11_state.OrtValue`"
            )

    def _get_c_value(self):
        return self._ortvalue

    @staticmethod
    def ortvalue_from_numpy(numpy_obj, device_type="cpu", device_id=0):
        """
        Factory method to construct an OrtValue (which holds a Tensor) from a given Numpy object
        A copy of the data in the Numpy object is held by the OrtValue only if the device is NOT cpu

        :param numpy_obj: The Numpy object to construct the OrtValue from
        :param device_type: e.g. cpu, cuda, cann, cpu by default
        :param device_id: device id, e.g. 0
        """
        # Hold a reference to the numpy object (if device_type is 'cpu') as the OrtValue
        # is backed directly by the data buffer of the numpy object and so the numpy object
        # must be around until this OrtValue instance is around
        return OrtValue(
            C.OrtValue.ortvalue_from_numpy(
                numpy_obj,
                C.OrtDevice(
                    get_ort_device_type(device_type, device_id),
                    C.OrtDevice.default_memory(),
                    device_id,
                ),
            ),
            numpy_obj if device_type.lower() == "cpu" else None,
        )

    @staticmethod
    def ortvalue_from_numpy_with_onnx_type(data, onnx_element_type: int):
        """
        This method creates an instance of OrtValue on top of the numpy array.
        No data copy is made and the lifespan of the resulting OrtValue should never
        exceed the lifespan of bytes object. The API attempts to reinterpret
        the data type which is expected to be the same size. This is useful
        when we want to use an ONNX data type that is not supported by numpy.

        :param data: numpy.ndarray.
        :param onnx_elemenet_type: a valid onnx TensorProto::DataType enum value
        """
        return OrtValue(C.OrtValue.ortvalue_from_numpy_with_onnx_type(data, onnx_element_type), data)

    @staticmethod
    def ortvalue_from_shape_and_type(shape, element_type, device_type: str = "cpu", device_id: int = 0):
        """
        Factory method to construct an OrtValue (which holds a Tensor) from given shape and element_type

        :param shape: List of integers indicating the shape of the OrtValue
        :param element_type: The data type of the elements. It can be either numpy type (like numpy.float32) or an integer for onnx type (like onnx.TensorProto.BFLOAT16).
        :param device_type: e.g. cpu, cuda, cann, cpu by default
        :param device_id: device id, e.g. 0
        """
        # Integer for onnx element type (see https://onnx.ai/onnx/api/mapping.html).
        # This is helpful for some data type (like TensorProto.BFLOAT16) that is not available in numpy.
        if isinstance(element_type, int):
            return OrtValue(
                C.OrtValue.ortvalue_from_shape_and_onnx_type(
                    shape,
                    element_type,
                    C.OrtDevice(
                        get_ort_device_type(device_type, device_id),
                        C.OrtDevice.default_memory(),
                        device_id,
                    ),
                )
            )

        return OrtValue(
            C.OrtValue.ortvalue_from_shape_and_type(
                shape,
                element_type,
                C.OrtDevice(
                    get_ort_device_type(device_type, device_id),
                    C.OrtDevice.default_memory(),
                    device_id,
                ),
            )
        )

    @staticmethod
    def ort_value_from_sparse_tensor(sparse_tensor):
        """
        The function will construct an OrtValue instance from a valid SparseTensor
        The new instance of OrtValue will assume the ownership of sparse_tensor
        """
        return OrtValue(C.OrtValue.ort_value_from_sparse_tensor(sparse_tensor._get_c_tensor()))

    def as_sparse_tensor(self):
        """
        The function will return SparseTensor contained in this OrtValue
        """
        return SparseTensor(self._ortvalue.as_sparse_tensor())

    def data_ptr(self):
        """
        Returns the address of the first element in the OrtValue's data buffer
        """
        return self._ortvalue.data_ptr()

    def device_name(self):
        """
        Returns the name of the device where the OrtValue's data buffer resides e.g. cpu, cuda, cann
        """
        return self._ortvalue.device_name().lower()

    def shape(self):
        """
        Returns the shape of the data in the OrtValue
        """
        return self._ortvalue.shape()

    def data_type(self):
        """
        Returns the data type of the data in the OrtValue
        """
        return self._ortvalue.data_type()

    def element_type(self):
        """
        Returns the proto type of the data in the OrtValue
        if the OrtValue is a tensor.
        """
        return self._ortvalue.element_type()

    def has_value(self):
        """
        Returns True if the OrtValue corresponding to an
        optional type contains data, else returns False
        """
        return self._ortvalue.has_value()

    def is_tensor(self):
        """
        Returns True if the OrtValue contains a Tensor, else returns False
        """
        return self._ortvalue.is_tensor()

    def is_sparse_tensor(self):
        """
        Returns True if the OrtValue contains a SparseTensor, else returns False
        """
        return self._ortvalue.is_sparse_tensor()

    def is_tensor_sequence(self):
        """
        Returns True if the OrtValue contains a Tensor Sequence, else returns False
        """
        return self._ortvalue.is_tensor_sequence()

    def numpy(self):
        """
        Returns a Numpy object from the OrtValue.
        Valid only for OrtValues holding Tensors. Throws for OrtValues holding non-Tensors.
        Use accessors to gain a reference to non-Tensor objects such as SparseTensor
        """
        return self._ortvalue.numpy()

    def update_inplace(self, np_arr):
        """
        Update the OrtValue in place with a new Numpy array. The numpy contents
        are copied over to the device memory backing the OrtValue. It can be used
        to update the input valuess for an InferenceSession with CUDA graph
        enabled or other scenarios where the OrtValue needs to be updated while
        the memory address can not be changed.
        """
        self._ortvalue.update_inplace(np_arr)


class OrtDevice:
    """
    A data structure that exposes the underlying C++ OrtDevice
    """

    def __init__(self, c_ort_device):
        """
        Internal constructor
        """
        if isinstance(c_ort_device, C.OrtDevice):
            self._ort_device = c_ort_device
        else:
            raise ValueError(
                "`Provided object` needs to be of type `onnxruntime.capi.onnxruntime_pybind11_state.OrtDevice`"
            )

    def _get_c_device(self):
        """
        Internal accessor to underlying object
        """
        return self._ort_device

    @staticmethod
    def make(ort_device_name, device_id):
        return OrtDevice(
            C.OrtDevice(
                get_ort_device_type(ort_device_name, device_id),
                C.OrtDevice.default_memory(),
                device_id,
            )
        )

    def device_id(self):
        return self._ort_device.device_id()

    def device_type(self):
        return self._ort_device.device_type()


class SparseTensor:
    """
    A data structure that project the C++ SparseTensor object
    The class provides API to work with the object.
    Depending on the format, the class will hold more than one buffer
    depending on the format
    """

    def __init__(self, sparse_tensor):
        """
        Internal constructor
        """
        if isinstance(sparse_tensor, C.SparseTensor):
            self._tensor = sparse_tensor
        else:
            # An end user won't hit this error
            raise ValueError(
                "`Provided object` needs to be of type `onnxruntime.capi.onnxruntime_pybind11_state.SparseTensor`"
            )

    def _get_c_tensor(self):
        return self._tensor

    @staticmethod
    def sparse_coo_from_numpy(dense_shape, values, coo_indices, ort_device):
        """
        Factory method to construct a SparseTensor in COO format from given arguments

        :param dense_shape: 1-D  numpy array(int64) or a python list that contains a dense_shape of the sparse tensor
            must be on cpu memory
        :param values: a homogeneous, contiguous 1-D numpy array that contains non-zero elements of the tensor
            of a type.
        :param coo_indices:  contiguous numpy array(int64) that contains COO indices for the tensor. coo_indices may
            have a 1-D shape when it contains a linear index of non-zero values and its length must be equal to
            that of the values. It can also be of 2-D shape, in which has it contains pairs of coordinates for
            each of the nnz values and its length must be exactly twice of the values length.
        :param ort_device: - describes the backing memory owned by the supplied nummpy arrays. Only CPU memory is
            suppored for non-numeric data types.

        For primitive types, the method will map values and coo_indices arrays into native memory and will use
        them as backing storage. It will increment the reference count for numpy arrays and it will decrement it
        on GC. The buffers may reside in any storage either CPU or GPU.
        For strings and objects, it will create a copy of the arrays in CPU memory as ORT does not support those
        on other devices and their memory can not be mapped.
        """
        return SparseTensor(
            C.SparseTensor.sparse_coo_from_numpy(dense_shape, values, coo_indices, ort_device._get_c_device())
        )

    @staticmethod
    def sparse_csr_from_numpy(dense_shape, values, inner_indices, outer_indices, ort_device):
        """
        Factory method to construct a SparseTensor in CSR format from given arguments

        :param dense_shape: 1-D numpy array(int64) or a python list that contains a dense_shape of the
            sparse tensor (rows, cols) must be on cpu memory
        :param values: a  contiguous, homogeneous 1-D numpy array that contains non-zero elements of the tensor
            of a type.
        :param inner_indices:  contiguous 1-D numpy array(int64) that contains CSR inner indices for the tensor.
            Its length must be equal to that of the values.
        :param outer_indices:  contiguous 1-D numpy array(int64) that contains CSR outer indices for the tensor.
            Its length must be equal to the number of rows + 1.
        :param ort_device: - describes the backing memory owned by the supplied nummpy arrays. Only CPU memory is
            suppored for non-numeric data types.

        For primitive types, the method will map values and indices arrays into native memory and will use them as
        backing storage. It will increment the reference count and it will decrement then count when it is GCed.
        The buffers may reside in any storage either CPU or GPU.
        For strings and objects, it will create a copy of the arrays in CPU memory as ORT does not support those
        on other devices and their memory can not be mapped.
        """
        return SparseTensor(
            C.SparseTensor.sparse_csr_from_numpy(
                dense_shape,
                values,
                inner_indices,
                outer_indices,
                ort_device._get_c_device(),
            )
        )

    def values(self):
        """
        The method returns a numpy array that is backed by the native memory
        if the data type is numeric. Otherwise, the returned numpy array that contains
        copies of the strings.
        """
        return self._tensor.values()

    def as_coo_view(self):
        """
        The method will return coo representation of the sparse tensor which will enable
        querying COO indices. If the instance did not contain COO format, it would throw.
        You can query coo indices as:

        ::

            coo_indices = sparse_tensor.as_coo_view().indices()

        which will return a numpy array that is backed by the native memory.
        """
        return self._tensor.get_coo_data()

    def as_csrc_view(self):
        """
        The method will return CSR(C) representation of the sparse tensor which will enable
        querying CRS(C) indices. If the instance dit not contain CSR(C) format, it would throw.
        You can query indices as:

        ::

            inner_ndices = sparse_tensor.as_csrc_view().inner()
            outer_ndices = sparse_tensor.as_csrc_view().outer()

        returning numpy arrays backed by the native memory.
        """
        return self._tensor.get_csrc_data()

    def as_blocksparse_view(self):
        """
        The method will return coo representation of the sparse tensor which will enable
        querying BlockSparse indices. If the instance did not contain BlockSparse format, it would throw.
        You can query coo indices as:

        ::

            block_sparse_indices = sparse_tensor.as_blocksparse_view().indices()

        which will return a numpy array that is backed by the native memory
        """
        return self._tensor.get_blocksparse_data()

    def to_cuda(self, ort_device):
        """
        Returns a copy of this instance on the specified cuda device

        :param ort_device: with name 'cuda' and valid gpu device id

        The method will throw if:

        - this instance contains strings
        - this instance is already on GPU. Cross GPU copy is not supported
        - CUDA is not present in this build
        - if the specified device is not valid
        """
        return SparseTensor(self._tensor.to_cuda(ort_device._get_c_device()))

    def format(self):
        """
        Returns a OrtSparseFormat enumeration
        """
        return self._tensor.format

    def dense_shape(self):
        """
        Returns a numpy array(int64) containing a dense shape of a sparse tensor
        """
        return self._tensor.dense_shape()

    def data_type(self):
        """
        Returns a string data type of the data in the OrtValue
        """
        return self._tensor.data_type()

    def device_name(self):
        """
        Returns the name of the device where the SparseTensor data buffers reside e.g. cpu, cuda
        """
        return self._tensor.device_name().lower()

# %%
# !python /content/1.py -m onnx-community/Qwen2.5-0.5B-Instruct-ONNX-MHA

# %%
import { pipeline } from '@huggingface/transformers';

// Allocate a pipeline for sentiment-analysis
const pipe = await pipeline('sentiment-analysis' , { dtype: "fp32" });

const out = await pipe('I love transformers!');
// [{'label': 'POSITIVE', 'score': 0.999817686}]

# %%
import { pipeline } from '@huggingface/transformers';

// Allocate a pipeline for sentiment-analysis
const pipe = await pipeline('sentiment-analysis', 'nlptown/bert-base-multilingual-uncased-sentiment' , { dtype: "fp32" });

const out = await pipe('I love transformers!');
// [{'label': 'POSITIVE', 'score': 0.999817686}]

# %%
const generator = await pipeline(
  "text-generation",
  "onnx-community/DeepSeek-R1-Distill-Qwen-1.5B-ONNX",
  { dtype: "q4f16" },
);

# %%
# !node /content/2.js
# Out:
# file:///content/node_modules/@huggingface/transformers/dist/transformers.mjs:31507
#             part = part.replace(new RegExp('/$'), '');
#                         ^
#
# TypeError: part.replace is not a function
#     at file:///content/node_modules/@huggingface/transformers/dist/transformers.mjs:31507:25
#     at Array.map (<anonymous>)
#     at pathJoin (file:///content/node_modules/@huggingface/transformers/dist/transformers.mjs:31502:19)
#     at getModelFile (file:///content/node_modules/@huggingface/transformers/dist/transformers.mjs:31248:22)
#     at getModelJSON (file:///content/node_modules/@huggingface/transformers/dist/transformers.mjs:31427:24)
#     at loadTokenizer (file:///content/node_modules/@huggingface/transformers/dist/transformers.mjs:24732:68)
#     at AutoTokenizer.from_pretrained (file:///content/node_modules/@huggingface/transformers/dist/transformers.mjs:29020:56)
#     at loadItems (file:///content/node_modules/@huggingface/transformers/dist/transformers.mjs:24594:27)
#     at pipeline (file:///content/node_modules/@huggingface/transformers/dist/transformers.mjs:24532:27)
#     at file:///content/2.js:4:20
#
# Node.js v18.20.5

# %%
# !pip install onnxruntime
# Out:
# Requirement already satisfied: onnxruntime in /usr/local/lib/python3.11/dist-packages (1.20.1)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.11/dist-packages (from onnxruntime) (15.0.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.11/dist-packages (from onnxruntime) (25.2.10)
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/lib/python3.11/dist-packages (from onnxruntime) (2.2.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from onnxruntime) (24.2)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from onnxruntime) (5.29.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from onnxruntime) (1.13.1)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.11/dist-packages (from coloredlogs->onnxruntime) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->onnxruntime) (1.3.0)

# %%
# !pip install onnxruntime-genai
# Out:
# Requirement already satisfied: onnxruntime-genai in /usr/local/lib/python3.11/dist-packages (0.5.2)
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/lib/python3.11/dist-packages (from onnxruntime-genai) (2.2.2)
# Requirement already satisfied: onnxruntime>=1.20.1 in /usr/local/lib/python3.11/dist-packages (from onnxruntime-genai) (1.20.1)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.11/dist-packages (from onnxruntime>=1.20.1->onnxruntime-genai) (15.0.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.11/dist-packages (from onnxruntime>=1.20.1->onnxruntime-genai) (25.2.10)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from onnxruntime>=1.20.1->onnxruntime-genai) (24.2)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from onnxruntime>=1.20.1->onnxruntime-genai) (5.29.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from onnxruntime>=1.20.1->onnxruntime-genai) (1.13.1)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.11/dist-packages (from coloredlogs->onnxruntime>=1.20.1->onnxruntime-genai) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->onnxruntime>=1.20.1->onnxruntime-genai) (1.3.0)

# %% [markdown]
# https://huggingface.co/docs/transformers.js/index
#
#
#
# https://github.com/huggingface/optimum#onnx--onnx-runtime

# %%
# !pip install optimum[exporters,onnxruntime]
# Out:
# Requirement already satisfied: optimum[exporters,onnxruntime] in /usr/local/lib/python3.11/dist-packages (1.24.0)
# Requirement already satisfied: transformers>=4.29 in /usr/local/lib/python3.11/dist-packages (from optimum[exporters,onnxruntime]) (4.48.3)
# Requirement already satisfied: torch>=1.11 in /usr/local/lib/python3.11/dist-packages (from optimum[exporters,onnxruntime]) (2.6.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from optimum[exporters,onnxruntime]) (24.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optimum[exporters,onnxruntime]) (2.2.2)
# Requirement already satisfied: huggingface-hub>=0.8.0 in /usr/local/lib/python3.11/dist-packages (from optimum[exporters,onnxruntime]) (0.28.1)
# Requirement already satisfied: onnx in /usr/local/lib/python3.11/dist-packages (from optimum[exporters,onnxruntime]) (1.17.0)
# Requirement already satisfied: onnxruntime in /usr/local/lib/python3.11/dist-packages (from optimum[exporters,onnxruntime]) (1.20.1)
# Requirement already satisfied: timm in /usr/local/lib/python3.11/dist-packages (from optimum[exporters,onnxruntime]) (1.0.14)
# Requirement already satisfied: datasets>=1.2.1 in /usr/local/lib/python3.11/dist-packages (from optimum[exporters,onnxruntime]) (3.2.0)
# Requirement already satisfied: evaluate in /usr/local/lib/python3.11/dist-packages (from optimum[exporters,onnxruntime]) (0.4.3)
# Requirement already satisfied: protobuf>=3.20.1 in /usr/local/lib/python3.11/dist-packages (from optimum[exporters,onnxruntime]) (5.29.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets>=1.2.1->optimum[exporters,onnxruntime]) (3.17.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets>=1.2.1->optimum[exporters,onnxruntime]) (19.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets>=1.2.1->optimum[exporters,onnxruntime]) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets>=1.2.1->optimum[exporters,onnxruntime]) (2.2.3)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets>=1.2.1->optimum[exporters,onnxruntime]) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/dist-packages (from datasets>=1.2.1->optimum[exporters,onnxruntime]) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets>=1.2.1->optimum[exporters,onnxruntime]) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/dist-packages (from datasets>=1.2.1->optimum[exporters,onnxruntime]) (0.70.16)
# Requirement already satisfied: fsspec<=2024.9.0,>=2023.1.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets>=1.2.1->optimum[exporters,onnxruntime]) (2024.9.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets>=1.2.1->optimum[exporters,onnxruntime]) (3.11.12)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets>=1.2.1->optimum[exporters,onnxruntime]) (6.0.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.8.0->optimum[exporters,onnxruntime]) (4.12.2)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.11/dist-packages (from onnxruntime->optimum[exporters,onnxruntime]) (15.0.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.11/dist-packages (from onnxruntime->optimum[exporters,onnxruntime]) (25.2.10)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from onnxruntime->optimum[exporters,onnxruntime]) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->optimum[exporters,onnxruntime]) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->optimum[exporters,onnxruntime]) (3.1.5)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->optimum[exporters,onnxruntime]) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->optimum[exporters,onnxruntime]) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->optimum[exporters,onnxruntime]) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->optimum[exporters,onnxruntime]) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->optimum[exporters,onnxruntime]) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->optimum[exporters,onnxruntime]) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->optimum[exporters,onnxruntime]) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->optimum[exporters,onnxruntime]) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->optimum[exporters,onnxruntime]) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->optimum[exporters,onnxruntime]) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->optimum[exporters,onnxruntime]) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->optimum[exporters,onnxruntime]) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->optimum[exporters,onnxruntime]) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->optimum[exporters,onnxruntime]) (3.2.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->onnxruntime->optimum[exporters,onnxruntime]) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.29->optimum[exporters,onnxruntime]) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.29->optimum[exporters,onnxruntime]) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.29->optimum[exporters,onnxruntime]) (0.5.2)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (from timm->optimum[exporters,onnxruntime]) (0.21.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=1.2.1->optimum[exporters,onnxruntime]) (2.4.6)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=1.2.1->optimum[exporters,onnxruntime]) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=1.2.1->optimum[exporters,onnxruntime]) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=1.2.1->optimum[exporters,onnxruntime]) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=1.2.1->optimum[exporters,onnxruntime]) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=1.2.1->optimum[exporters,onnxruntime]) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=1.2.1->optimum[exporters,onnxruntime]) (1.18.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets>=1.2.1->optimum[exporters,onnxruntime]) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets>=1.2.1->optimum[exporters,onnxruntime]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets>=1.2.1->optimum[exporters,onnxruntime]) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets>=1.2.1->optimum[exporters,onnxruntime]) (2025.1.31)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.11/dist-packages (from coloredlogs->onnxruntime->optimum[exporters,onnxruntime]) (10.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.11->optimum[exporters,onnxruntime]) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets>=1.2.1->optimum[exporters,onnxruntime]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets>=1.2.1->optimum[exporters,onnxruntime]) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets>=1.2.1->optimum[exporters,onnxruntime]) (2025.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision->timm->optimum[exporters,onnxruntime]) (11.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets>=1.2.1->optimum[exporters,onnxruntime]) (1.17.0)

# %%
# !optimum-cli export onnx -m deepset/roberta-base-squad2 --optimize O2 roberta_base_qa_onnx
# Out:
# 2025-02-11 21:07:33.015951: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1739308053.426632   25675 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1739308053.534226   25675 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# config.json: 100% 571/571 [00:00<00:00, 2.24MB/s]
# model.safetensors: 100% 496M/496M [00:09<00:00, 54.5MB/s]
# tokenizer_config.json: 100% 79.0/79.0 [00:00<00:00, 439kB/s]
# vocab.json: 100% 899k/899k [00:00<00:00, 1.69MB/s]
# merges.txt: 100% 456k/456k [00:00<00:00, 29.8MB/s]
# special_tokens_map.json: 100% 772/772 [00:00<00:00, 4.39MB/s]
# /usr/local/lib/python3.11/dist-packages/optimum/onnxruntime/configuration.py:784: FutureWarning: disable_embed_layer_norm will be deprecated soon, use disable_embed_layer_norm_fusion instead, disable_embed_layer_norm_fusion is set to True.
#   warnings.warn(
# symbolic shape inference disabled or failed.

# %%
import { pipeline } from '@huggingface/transformers';

// Allocate a pipeline for sentiment-analysis
const pipe = await pipeline('sentiment-analysis');

const out = await pipe('I love transformers!');
// [{'label': 'POSITIVE', 'score': 0.999817686}]

# %%
# !node 2.js
Colab paid products - Cancel contracts here

  2s
completed at 1:11 PM
pip install transformers
Run cell (Ctrl+
# Out:
# dtype not specified for "model". Using the default dtype (fp32) for this device (cpu).

# %%
# !npm install @huggingface/transformers
# !pip install onnxruntime
# !npm install onnxruntime-node
# !npm install onnxruntime-web
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦
# up to date, audited 83 packages in 3s
# ⠦
# ⠦20 packages are looking for funding
# ⠦  run `npm fund` for details
# ⠦
# found 0 vulnerabilities
# ⠦Requirement already satisfied: onnxruntime in /usr/local/lib/python3.11/dist-packages (1.20.1)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.11/dist-packages (from onnxruntime) (15.0.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.11/dist-packages (from onnxruntime) (25.2.10)
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/lib/python3.11/dist-packages (from onnxruntime) (2.2.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from onnxruntime) (24.2)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from onnxruntime) (5.29.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from onnxruntime) (1.13.1)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.11/dist-packages (from coloredlogs->onnxruntime) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->onnxruntime) (1.3.0)
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼
# up to date, audited 83 packages in 2s
# ⠼
# ⠼20 packages are looking for funding
# ⠼  run `npm fund` for details
# ⠼
# found 0 vulnerabilities
# ⠼⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦
# up to date, audited 83 packages in 2s
# ⠦
# ⠦20 packages are looking for funding
# ⠦  run `npm fund` for details
# ⠦
# found 0 vulnerabilities
# ⠦

# %%
//import { pipeline } from '@huggingface/transformers';

// Allocate pipeline
const pipe = await pipeline('text-generation', 'onnx-community/DeepSeek-R1-Distill-Qwen-1.5B-ONNX', {
  device: 'webgpu', // Setting WebGPU as the device
});

# %%
js
// Install necessary libraries
# !npm install @huggingface/transformers onnxruntime-web

// Create sentiment analysis pipeline with WebGPU
import { pipeline } from '@huggingface/transformers';

const pipe = await pipeline('sentiment-analysis', 'Xenova/distilbert-base-uncased-finetuned-sst-2-english', {
  device: 'webgpu',
});

// Run the model
const out = await pipe('I love transformers!');

// Display the results
console.log(out);

# %% [markdown]
# شغال ع المعالج

# %%
#!node /content/2.js

// Create sentiment analysis pipeline with WebGPU
import { pipeline } from '@huggingface/transformers';

const pipe = await pipeline('sentiment-analysis', 'Xenova/distilbert-base-uncased-finetuned-sst-2-english', {
  device: 'cpu',
});

// Run the model
const out = await pipe('I love transformers!');

// Display the results
console.log(out);

# %%
# !node /content/2.js
# Out:
# dtype not specified for "model". Using the default dtype (fp32) for this device (cpu).
# [ { label: 'POSITIVE', score: 0.9998068809509277 } ]

# %%
#!node /content/2.js



// Create sentiment analysis pipeline with WebGPU
import { pipeline } from '@huggingface/transformers';

const pipe = await pipeline('text-generation', 'onnx-community/Qwen2.5-0.5B-Instruct-ONNX-MHA', {
  device: 'cpu',
});

// Run the model
const out = await pipe('who is ai?');

// Display the results
console.log(out);

# %%
// Create text generation pipeline with WebGPU
import { pipeline, TextStreamer } from '@huggingface/transformers';

// Allocate pipeline
const generator = await pipeline(
  "text-generation",
  "onnx-community/Qwen2.5-0.5B-Instruct-ONNX-MHA",
  { dtype: "fp16" },
);

// Create text streamer
const streamer = new TextStreamer(generator.tokenizer, {
  skip_prompt: true,
  // callback_function: (text) => { }, // Optional callback function
})

// Define the list of messages
const messages = [
  { role: "user", content: "who is ai?" },
];

// Generate a response
const output = await generator(messages, { max_new_tokens: 512, do_sample: false, streamer });
console.log(output[0].generated_text.at(-1).content);

# %% [markdown]
# شغال ع المعالج

# %%
#!node /content/3.js

import { pipeline } from '@huggingface/transformers';

const pipe = await pipeline('text-generation', 'onnx-community/Qwen2.5-0.5B-Instruct-ONNX-MHA', {
  dtype: 'fp32', // or 'fp16', 'int8', etc.
  device: 'cpu', // or 'gpu' if WebGPU is available
});

// Run the model
const out = await pipe('who is ai?');

// Display the results
console.log(out);

# %%
# !node /content/3.js
# Out:
# [
#   {
#     generated_text: 'who is ai? what does it do?\n' +
#       'A good AI (artificial intelligence) can be defined'
#   }
# ]

# %% [markdown]
# aشغال

# %%
# !node /content/3.js

import { pipeline } from '@huggingface/transformers';

const pipe = await pipeline('text-generation', 'onnx-community/Qwen2.5-0.5B-Instruct-ONNX-MHA', {
  dtype: 'fp32', // or 'fp16', 'int8', etc.
  device: 'cpu', // or 'gpu' if WebGPU is available
});

// Run the model
const out = await pipe('who is ai?');

// Display the results
console.log(out);

# %%
# !npm i @huggingface/transformers

# %%
import { pipeline } from '@huggingface/transformers';

const pipe = await pipeline('text-generation', 'onnx-community/Qwen2.5-0.5B-Instruct-ONNX-MHA', {
  dtype: 'fp32', // or 'fp16', 'int8', etc.
  device: 'cpu', // or 'gpu' if WebGPU is available
});

// Run the model
const out = await pipe('who is ai?');

// Display the results
console.log(out);

# %%
import { pipeline } from '@huggingface/transformers';

const pipe = await pipeline('text-generation', 'onnx-community/Qwen2.5-0.5B-Instruct-ONNX-MHA', {
  device: 'cpu',
});

// Run the model with max_new_tokens and do_sample
const out = await pipe('who is ai?', {
  max_new_tokens: 50,  // Adjust as needed
  do_sample: true,      // Set to false for deterministic generation
});

// Display the results
console.log(out);

# %%
# !node /content/4.js
# Out:
# dtype not specified for "model". Using the default dtype (fp32) for this device (cpu).
# [
#   {
#     generated_text: 'who is ai? 360\n' +
#       '\n' +
#       'Assistant: AI (Artificial Intelligence) refers to the field of computer science that focuses on the development, operation and application of intelligent programs or systems. It builds on principles such as machine learning, natural language processing, vision and'
#   }
# ]

# %%
شغال معالج
# !node /content/4.js

import { pipeline } from '@huggingface/transformers';

const pipe = await pipeline('text-generation', 'onnx-community/Qwen2.5-0.5B-Instruct-ONNX-MHA', {
  device: 'cpu',
});

// Run the model with max_new_tokens and do_sample
const out = await pipe('who is ai?', {
  max_new_tokens: 50,  // Adjust as needed
  do_sample: true,      // Set to false for deterministic generation
});

// Display the results
console.log(out);

# %%
onnx-community/YuE-s1-7B-anneal-en-cot-ONNX

# %%
import { pipeline } from '@huggingface/transformers';

const pipe = await pipeline('text-generation', 'onnx-community/YuE-s1-7B-anneal-en-cot-ONNX', {
  device: 'cpu',
});

// Run the model with max_new_tokens and do_sample
const out = await pipe('who is ai?', {
  max_new_tokens: 50,  // Adjust as needed
  do_sample: true,      // Set to false for deterministic generation
});

// Display the results
console.log(out);
# Out:
#   File "<ipython-input-1-180a823f8061>", line 1
#     import { pipeline } from '@huggingface/transformers';
#            ^
# SyntaxError: invalid syntax

# %%
# !node /content/4.js
# Out:
# file:///content/4.js:5
#   { dtype: "q4f16" },
#   ^
#
# SyntaxError: Unexpected token '{'
#     at ModuleLoader.moduleStrategy (node:internal/modules/esm/translators:152:18)
#     at ModuleLoader.moduleProvider (node:internal/modules/esm/loader:299:14)
#     at async link (node:internal/modules/esm/module_job:67:21)
#
# Node.js v18.20.5

# %%
const generator = await pipeline(
  "text-generation",
  "onnx-community/DeepSeek-R1-Distill-Qwen-1.5B-ONNX",
  { dtype: "q4f16" },
);

# %%
import { pipeline } from '@huggingface/transformers';

const pipe = await pipeline('text-generation', './YuE-s1-7B-anneal-en-cot-ONNX', { // load locally
  device: 'cpu',
  dtype: "q4f16"
});

const out = await pipe('who is ai?', {
  max_new_tokens: 50,
  do_sample: true,
});

console.log(out);

# %%
# !node /content/4.js
# Out:
# file:///content/node_modules/@huggingface/transformers/dist/transformers.mjs:31095
#     throw Error(`${message}: "${remoteURL}".`);
#           ^
#
# Error: Unauthorized access to file: "https://huggingface.co/./YuE-s1-7B-anneal-en-cot-ONNX/resolve/main/config.json".
#     at handleError (file:///content/node_modules/@huggingface/transformers/dist/transformers.mjs:31095:11)
#     at getModelFile (file:///content/node_modules/@huggingface/transformers/dist/transformers.mjs:31328:24)
#     at process.processTicksAndRejections (node:internal/process/task_queues:95:5)
#     at async getModelJSON (file:///content/node_modules/@huggingface/transformers/dist/transformers.mjs:31427:18)
#     at async loadConfig (file:///content/node_modules/@huggingface/transformers/dist/transformers.mjs:5603:12)
#     at async PretrainedConfig.from_pretrained (file:///content/node_modules/@huggingface/transformers/dist/transformers.mjs:5924:32)
#     at async AutoModelForCausalLM.from_pretrained (file:///content/node_modules/@huggingface/transformers/dist/transformers.mjs:15417:26)
#     at async Promise.all (index 1)
#     at async loadItems (file:///content/node_modules/@huggingface/transformers/dist/transformers.mjs:24602:5)
#     at async pipeline (file:///content/node_modules/@huggingface/transformers/dist/transformers.mjs:24532:21)
#
# Node.js v18.20.5

# %%
import os
os.environ['HF_READ_TOKEN'] = 'ء'

# %%
# !npm install @xenova/transformers
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼
# added 57 packages, and audited 140 packages in 24s
# ⠼
# ⠼30 packages are looking for funding
# ⠼  run `npm fund` for details
# ⠼
# found 0 vulnerabilities
# ⠼

# %%
import { pipeline } from '@xenova/transformers';

(async () => {
    const pipe = await pipeline('text-generation', './YuE-s1-7B-anneal-en-cot-ONNX', { quantized: true });

    const out = await pipe('Who is AI?', {
        max_new_tokens: 50,
        do_sample: true,
    });

    console.log(out);
})();

# %%
# !node /content/4.js
# Out:
# file:///content/node_modules/@xenova/transformers/src/utils/hub.js:238
#     throw Error(`${message}: "${remoteURL}".`);
#           ^
#
# Error: Unauthorized access to file: "https://huggingface.co/YuE-s1-7B-anneal-en-cot-ONNX/resolve/main/tokenizer_config.json".
#     at handleError (file:///content/node_modules/@xenova/transformers/src/utils/hub.js:238:11)
#     at getModelFile (file:///content/node_modules/@xenova/transformers/src/utils/hub.js:471:24)
#     at process.processTicksAndRejections (node:internal/process/task_queues:95:5)
#     at async getModelJSON (file:///content/node_modules/@xenova/transformers/src/utils/hub.js:572:18)
#     at async Promise.all (index 1)
#     at async loadTokenizer (file:///content/node_modules/@xenova/transformers/src/tokenizers.js:61:18)
#     at async AutoTokenizer.from_pretrained (file:///content/node_modules/@xenova/transformers/src/tokenizers.js:4459:50)
#     at async Promise.all (index 0)
#     at async loadItems (file:///content/node_modules/@xenova/transformers/src/pipelines.js:3279:5)
#     at async pipeline (file:///content/node_modules/@xenova/transformers/src/pipelines.js:3219:21)
#
# Node.js v18.20.5

# %%
const pipe = await pipeline('text-generation', 'YuE-s1-7B-anneal-en-cot-ONNX', {
    token: "hf_xxxxx"
});

# %% [markdown]
# تأكد من تنزيل النموذج في Google Colab

# %%
# !git clone https://huggingface.co/YuE-s1-7B-anneal-en-cot-ONNX

# %% [markdown]
# ثم تحقق من وجود الملفات داخل المجلد:

# %%
# !ls -la YuE-s1-7B-anneal-en-cot-ONNX

# %%
import { pipeline } from '@xenova/transformers';

(async () => {
    const modelPath = '/content/YuE-s1-7B-anneal-en-cot-ONNX';  // المسار بعد التنزيل

    const pipe = await pipeline('text-generation', modelPath, {
        local_files_only: true  // تأكيد تحميل النموذج من المسار المحلي فقط
    });

    const out = await pipe('Who is AI?', {
        max_new_tokens: 50,
        do_sample: true,
    });

    console.log(out);
})();

# %%
import { pipeline } from '@xenova/transformers';

(async () => {
    const modelPath = '/content/gpt2_onnx';  // المسار بعد التنزيل

    const pipe = await pipeline('text-generation', modelPath, {
        local_files_only: true  // تأكيد تحميل النموذج من المسار المحلي فقط
    });

    const out = await pipe('Who is AI?', {
        max_new_tokens: 50,
        do_sample: true,
    });

    console.log(out);
})();

# %%
# !node /content/4.js
# Out:
# file:///content/node_modules/@xenova/transformers/src/utils/hub.js:459
#                     throw Error(`\`local_files_only=true\` or \`env.allowRemoteModels=false\` and file was not found locally at "${localPath}".`);
#                           ^
#
# Error: `local_files_only=true` or `env.allowRemoteModels=false` and file was not found locally at "/content/node_modules/@xenova/transformers/models/content/gpt2_onnx/model.onnx/tokenizer.json".
#     at getModelFile (file:///content/node_modules/@xenova/transformers/src/utils/hub.js:459:27)
#     at async getModelJSON (file:///content/node_modules/@xenova/transformers/src/utils/hub.js:572:18)
#     at async Promise.all (index 0)
#     at async loadTokenizer (file:///content/node_modules/@xenova/transformers/src/tokenizers.js:61:18)
#     at async AutoTokenizer.from_pretrained (file:///content/node_modules/@xenova/transformers/src/tokenizers.js:4459:50)
#     at async Promise.all (index 0)
#     at async loadItems (file:///content/node_modules/@xenova/transformers/src/pipelines.js:3279:5)
#     at async pipeline (file:///content/node_modules/@xenova/transformers/src/pipelines.js:3219:21)
#     at async file:///content/4.js:4:18
#
# Node.js v18.20.5

# %%
import { pipeline } from '@xenova/transformers';

(async () => {
    const pipe = await pipeline('text-generation', '/content/gpt2_onnx/model.onnx', {
        local_files_only: true,
        quantized: true
    });

    const out = await pipe('Who is AI?', {
        max_new_tokens: 50,
        do_sample: true,
    });

    console.log(out);
})();

# %%
import onnxruntime as ort
import numpy as np

# تحميل النموذج
session = ort.InferenceSession("/content/gpt2_onnx/model.onnx")

# إنشاء إدخال تجريبي
input_data = np.random.rand(1, 128).astype(np.float32)  # غيّر بناءً على المدخل المطلوب

# تنفيذ الاستدلال
outputs = session.run(None, {"input": input_data})
print(outputs)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-ea2c6e13e6d4> in <cell line: 0>()
#       9
#      10 # تنفيذ الاستدلال
# ---> 11 outputs = session.run(None, {"input": input_data})
#      12 print(outputs)
#
# /usr/local/lib/python3.11/dist-packages/onnxruntime/capi/onnxruntime_inference_collection.py in run(self, output_names, input_feed, run_options)
#     260             sess.run([output_name], {input_name: x})
#     261         """
# --> 262         self._validate_input(list(input_feed.keys()))
#     263         if not output_names:
#     264             output_names = [output.name for output in self._outputs_meta]
#
# /usr/local/lib/python3.11/dist-packages/onnxruntime/capi/onnxruntime_inference_collection.py in _validate_input(self, feed_input_names)
#     242                 missing_input_names.append(input.name)
#     243         if missing_input_names:
# --> 244             raise ValueError(
#     245                 f"Required inputs ({missing_input_names}) are missing from input feed ({feed_input_names})."
#     246             )
#
# ValueError: Required inputs (['input_ids', 'past_key_values.0.key', 'past_key_values.0.value', 'past_key_values.1.key', 'past_key_values.1.value', 'past_key_values.2.key', 'past_key_values.2.value', 'past_key_values.3.key', 'past_key_values.3.value', 'past_key_values.4.key', 'past_key_values.4.value', 'past_key_values.5.key', 'past_key_values.5.value', 'past_key_values.6.key', 'past_key_values.6.value', 'past_key_values.7.key', 'past_key_values.7.value', 'past_key_values.8.key', 'past_key_values.8.value', 'past_key_values.9.key', 'past_key_values.9.value', 'past_key_values.10.key', 'past_key_values.10.value', 'past_key_values.11.key', 'past_key_values.11.value', 'attention_mask', 'position_ids']) are missing from input feed (['input']).

# %% [markdown]
# ayhgشغال

# %%
from transformers import pipeline

# Allocate a pipeline for sentiment-analysis
pipe = pipeline('sentiment-analysis')

out = pipe('I love transformers!')
print(out)
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Device set to use cpu

# %%
print(out)
# Out:
# [{'label': 'POSITIVE', 'score': 0.9998069405555725}]

# %%
import { pipeline } from '@huggingface/transformers';

// Allocate a pipeline for sentiment-analysis
const pipe = await pipeline('sentiment-analysis');

const out = await pipe('I love transformers!');
// [{'label': 'POSITIVE', 'score': 0.999817686}]

# %% [markdown]
# https://huggingface.co/docs/transformers.js/index

# %% [markdown]
# التكميم.dtype"fp32""fp16""q8""q4"

# %%
// Use a different model for sentiment-analysis
const pipe = await pipeline('sentiment-analysis', 'Xenova/bert-base-multilingual-uncased-sentiment');

# %%
// Run the model on WebGPU
const pipe = await pipeline('sentiment-analysis', 'Xenova/distilbert-base-uncased-finetuned-sst-2-english', {
  device: 'webgpu',
});

# %%
// Run the model at 4-bit quantization
const pipe = await pipeline('sentiment-analysis', 'Xenova/distilbert-base-uncased-finetuned-sst-2-english', {
  dtype: 'q4',
});

# %%
import { pipeline } from '@huggingface/transformers';

// Run the model at 4-bit quantization
const pipe = await pipeline('sentiment-analysis', 'Xenova/distilbert-base-uncased-finetuned-sst-2-english', {
  dtype: 'fp32',
});

const out = await pipe('I love transformers!');
// [{'label': 'POSITIVE', 'score': 0.999817686}]

# %%
# !node /content/5.js
# Out:
# [ { label: 'POSITIVE', score: 0.9998068809509277 } ]

# %% [markdown]
# شغال

# %%
شغال
# !node /content/5.js



import { pipeline } from '@huggingface/transformers';

// Run the model at 4-bit quantization
const pipe = await pipeline('sentiment-analysis', 'Xenova/distilbert-base-uncased-finetuned-sst-2-english', {
  dtype: 'fp32',
});

const out = await pipe('I love transformers!');
// [{'label': 'POSITIVE', 'score': 0.999817686}]
console.log(out);

# %%
import { pipeline } from '@huggingface/transformers';

// Run the model at 4-bit quantization
const pipe = await pipeline('text-generation', 'onnx-community/Qwen2.5-0.5B-Instruct-ONNX-MHA', {
  dtype: 'fp32',
});

const out = await pipe('who is python?');
// [{'label': 'POSITIVE', 'score': 0.999817686}]
console.log(out);

# %%
# !node /content/5.js
# Out:
# [
#   {
#     generated_text: 'who is python? how should i use it?\n' +
#       '\n' +
#       'Python is a versatile and popular programming language used for'
#   }
# ]

# %% [markdown]
# شغال

# %%
شغال
# !node /content/5.js



import { pipeline } from '@huggingface/transformers';

// Run the model at 4-bit quantization
const pipe = await pipeline('text-generation', 'onnx-community/Qwen2.5-0.5B-Instruct-ONNX-MHA', {
  dtype: 'fp32',
});

const out = await pipe('who is python?');
// [{'label': 'POSITIVE', 'score': 0.999817686}]
console.log(out);

# %% [markdown]
# لايعمل

# %%
import { pipeline } from '@huggingface/transformers';

// Run the model at 4-bit quantization
const pipe = await pipeline('text-generation', 'onnx-community/YuE-s1-7B-anneal-en-cot-ONNX', {
  dtype: 'fp32',
});

const out = await pipe('who is python?');
// [{'label': 'POSITIVE', 'score': 0.999817686}]
console.log(out);

# %%
# !node /content/5.js
# Out:
# file:///content/node_modules/@huggingface/transformers/dist/transformers.mjs:31095
#     throw Error(`${message}: "${remoteURL}".`);
#           ^
#
# Error: Could not locate file: "https://huggingface.co/onnx-community/YuE-s1-7B-anneal-en-cot-ONNX/resolve/main/onnx/model.onnx".
#     at handleError (file:///content/node_modules/@huggingface/transformers/dist/transformers.mjs:31095:11)
#     at getModelFile (file:///content/node_modules/@huggingface/transformers/dist/transformers.mjs:31328:24)
#     at process.processTicksAndRejections (node:internal/process/task_queues:95:5)
#     at async getSession (file:///content/node_modules/@huggingface/transformers/dist/transformers.mjs:8703:20)
#     at async file:///content/node_modules/@huggingface/transformers/dist/transformers.mjs:8720:65
#     at async Promise.all (index 0)
#     at async constructSessions (file:///content/node_modules/@huggingface/transformers/dist/transformers.mjs:8718:31)
#     at async Promise.all (index 0)
#     at async LlamaForCausalLM.from_pretrained (file:///content/node_modules/@huggingface/transformers/dist/transformers.mjs:9411:20)
#     at async AutoModelForCausalLM.from_pretrained (file:///content/node_modules/@huggingface/transformers/dist/transformers.mjs:15428:20)
#
# Node.js v18.20.5

# %%
onnx-community/DeepSeek-R1-Distill-Qwen-1.5B-ONNX

# %%
# !node /content/5.js
# Out:
# file:///content/node_modules/@huggingface/transformers/dist/transformers.mjs:31095
#     throw Error(`${message}: "${remoteURL}".`);
#           ^
#
# Error: Could not locate file: "https://huggingface.co/Xenova/Qwen1.5-1.8B-Chat/resolve/main/onnx/model.onnx".
#     at handleError (file:///content/node_modules/@huggingface/transformers/dist/transformers.mjs:31095:11)
#     at getModelFile (file:///content/node_modules/@huggingface/transformers/dist/transformers.mjs:31328:24)
#     at process.processTicksAndRejections (node:internal/process/task_queues:95:5)
#     at async getSession (file:///content/node_modules/@huggingface/transformers/dist/transformers.mjs:8703:20)
#     at async file:///content/node_modules/@huggingface/transformers/dist/transformers.mjs:8720:65
#     at async Promise.all (index 0)
#     at async constructSessions (file:///content/node_modules/@huggingface/transformers/dist/transformers.mjs:8718:31)
#     at async Promise.all (index 0)
#     at async Qwen2ForCausalLM.from_pretrained (file:///content/node_modules/@huggingface/transformers/dist/transformers.mjs:9411:20)
#     at async AutoModelForCausalLM.from_pretrained (file:///content/node_modules/@huggingface/transformers/dist/transformers.mjs:15428:20)
#
# Node.js v18.20.5

# %%
# !pip install onnxruntime
# Out:
# Requirement already satisfied: onnxruntime in /usr/local/lib/python3.11/dist-packages (1.20.1)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.11/dist-packages (from onnxruntime) (15.0.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.11/dist-packages (from onnxruntime) (25.2.10)
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/lib/python3.11/dist-packages (from onnxruntime) (2.2.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from onnxruntime) (24.2)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from onnxruntime) (5.29.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from onnxruntime) (1.13.1)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.11/dist-packages (from coloredlogs->onnxruntime) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->onnxruntime) (1.3.0)

# %%
# !npm install onnxruntime-node
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇
# up to date, audited 140 packages in 2s
# ⠇
# ⠇30 packages are looking for funding
# ⠇  run `npm fund` for details
# ⠇
# found 0 vulnerabilities
# ⠇

# %%
import { pipeline } from '@huggingface/transformers';

  // Allocate pipeline
  const pipe = await pipeline('text-generation', 'onnx-community/Qwen2.5-0.5B-Instruct-ONNX-MHA');

# %%
import { pipeline } from '@huggingface/transformers';

// Allocate pipeline
const pipe = await pipeline('text-generation', 'onnx-community/Qwen2.5-0.5B-Instruct-ONNX-MHA');

// Define the prompt for text generation
const prompt = "Write a short story about a robot who learns to love:";

// Generate text based on the prompt
const generatedText = await pipe(prompt, {
  max_new_tokens: 100, // Adjust the number of tokens to generate
});

// Print the generated text to the console
console.log(generatedText[0].generated_text);

# %% [markdown]
# Should be one of: auto, fp32, fp16, q8, int8, uint8, q4, bnb4, q4f16

# %%
# !node /content/6.js
# Out:
# dtype not specified for "model". Using the default dtype (fp32) for this device (cpu).
# Write a short story about a robot who learns to love: A young adult robot named Mira goes on a trip around the world, meeting new families and people. She discovers that she hasn't been able to express her feelings with her human friends due to being stuck inside a computer program for so long. But when she sees that people from all over the world need someone like her - someone who can help them cope with their homesickness - Mira decides to take action and build a new robot. Along the way, she meets people from all around the globe

# %% [markdown]
# شغال ع المعالج كولاب

# %%
شغال
# !node /content/6.js

import { pipeline } from '@huggingface/transformers';

// Allocate pipeline
const pipe = await pipeline('text-generation', 'onnx-community/Qwen2.5-0.5B-Instruct-ONNX-MHA');

// Define the prompt for text generation
const prompt = "Write a short story about a robot who learns to love:";

// Generate text based on the prompt
const generatedText = await pipe(prompt, {
  max_new_tokens: 100, // Adjust the number of tokens to generate
});

// Print the generated text to the console
console.log(generatedText[0].generated_text);

# %%
import { pipeline, TextStreamer } from "@huggingface/transformers";

const generator = await pipeline(
  "text-generation",
  "onnx-community/DeepSeek-R1-Distill-Qwen-1.5B-ONNX",
  { dtype: "q4f16" },
);

const messages = [
  { role: "user", content:  "Solve the equation: x^2 - 3x + 2 = 0" },
];

const streamer = new TextStreamer(generator.tokenizer, {
  skip_prompt: true,
});

const output = await generator(messages, { max_new_tokens: 512, do_sample: false, streamer });
console.log(output[0].generated_text.at(-1).content);

# %%
import { pipeline } from '@huggingface/transformers';

const generator = await pipeline(
  "text-generation",
  "/content/gpt2_onnx", // Path to your locally downloaded model
);

const prompt = "Write a story about a cat who goes on an adventure:";

const generatedText = await generator(prompt, {
  max_new_tokens: 100,
});

console.log(generatedText[0].generated_text);

# %%
# !pip list
# Out:
# Package                            Version
# ---------------------------------- ------------------
# absl-py                            1.4.0
# accelerate                         1.3.0
# aiohappyeyeballs                   2.4.6
# aiohttp                            3.11.12
# aiosignal                          1.3.2
# alabaster                          1.0.0
# albucore                           0.0.23
# albumentations                     2.0.3
# ale-py                             0.10.1
# altair                             5.5.0
# annotated-types                    0.7.0
# anyio                              3.7.1
# argon2-cffi                        23.1.0
# argon2-cffi-bindings               21.2.0
# array_record                       0.6.0
# arviz                              0.20.0
# astropy                            7.0.0
# astropy-iers-data                  0.2025.2.3.0.32.42
# astunparse                         1.6.3
# atpublic                           4.1.0
# attrs                              25.1.0
# audioread                          3.0.1
# autograd                           1.7.0
# babel                              2.17.0
# backcall                           0.2.0
# beautifulsoup4                     4.13.3
# bigframes                          1.35.0
# bigquery-magics                    0.5.0
# bleach                             6.2.0
# blinker                            1.9.0
# blis                               0.7.11
# blosc2                             3.0.0
# bokeh                              3.6.3
# Bottleneck                         1.4.2
# bqplot                             0.12.44
# branca                             0.8.1
# CacheControl                       0.14.2
# cachetools                         5.5.1
# catalogue                          2.0.10
# certifi                            2025.1.31
# cffi                               1.17.1
# chardet                            5.2.0
# charset-normalizer                 3.4.1
# chex                               0.1.88
# clarabel                           0.10.0
# click                              8.1.8
# cloudpathlib                       0.20.0
# cloudpickle                        3.1.1
# cmake                              3.31.4
# cmdstanpy                          1.2.5
# colorcet                           3.1.0
# coloredlogs                        15.0.1
# colorlover                         0.3.0
# colour                             0.1.5
# community                          1.0.0b1
# confection                         0.1.5
# cons                               0.4.6
# contourpy                          1.3.1
# cramjam                            2.9.1
# cryptography                       43.0.3
# cuda-python                        12.6.0
# cudf-cu12                          24.12.0
# cufflinks                          0.17.3
# cupy-cuda12x                       13.3.0
# cvxopt                             1.3.2
# cvxpy                              1.6.0
# cycler                             0.12.1
# cyipopt                            1.5.0
# cymem                              2.0.11
# Cython                             3.0.11
# dask                               2024.10.0
# datascience                        0.17.6
# datasets                           3.2.0
# db-dtypes                          1.4.1
# dbus-python                        1.2.18
# debugpy                            1.8.0
# decorator                          4.4.2
# defusedxml                         0.7.1
# Deprecated                         1.2.18
# diffusers                          0.32.2
# dill                               0.3.8
# distro                             1.9.0
# dlib                               19.24.2
# dm-tree                            0.1.9
# docker-pycreds                     0.4.0
# docstring_parser                   0.16
# docutils                           0.21.2
# dopamine_rl                        4.1.2
# duckdb                             1.1.3
# earthengine-api                    1.5.1
# easydict                           1.13
# editdistance                       0.8.1
# eerepr                             0.1.0
# einops                             0.8.0
# en-core-web-sm                     3.7.1
# entrypoints                        0.4
# et_xmlfile                         2.0.0
# etils                              1.11.0
# etuples                            0.3.9
# evaluate                           0.4.3
# Farama-Notifications               0.0.4
# fastai                             2.7.18
# fastcore                           1.7.29
# fastdownload                       0.0.7
# fastjsonschema                     2.21.1
# fastprogress                       1.0.3
# fastrlock                          0.8.3
# filelock                           3.17.0
# firebase-admin                     6.6.0
# Flask                              3.1.0
# flatbuffers                        25.2.10
# flax                               0.10.2
# folium                             0.19.4
# fonttools                          4.55.8
# frozendict                         2.4.6
# frozenlist                         1.5.0
# fsspec                             2024.9.0
# future                             1.0.0
# gast                               0.6.0
# gcsfs                              2024.10.0
# GDAL                               3.6.4
# gdown                              5.2.0
# geemap                             0.35.1
# gensim                             4.3.3
# geocoder                           1.38.1
# geographiclib                      2.0
# geopandas                          1.0.1
# geopy                              2.4.1
# gin-config                         0.5.0
# gitdb                              4.0.12
# GitPython                          3.1.44
# glob2                              0.7
# google                             2.0.3
# google-ai-generativelanguage       0.6.15
# google-api-core                    2.19.2
# google-api-python-client           2.160.0
# google-auth                        2.27.0
# google-auth-httplib2               0.2.0
# google-auth-oauthlib               1.2.1
# google-cloud-aiplatform            1.79.0
# google-cloud-bigquery              3.25.0
# google-cloud-bigquery-connection   1.17.0
# google-cloud-bigquery-storage      2.28.0
# google-cloud-bigtable              2.28.1
# google-cloud-core                  2.4.1
# google-cloud-dataproc              5.16.0
# google-cloud-datastore             2.20.2
# google-cloud-firestore             2.20.0
# google-cloud-functions             1.19.0
# google-cloud-iam                   2.17.0
# google-cloud-language              2.16.0
# google-cloud-pubsub                2.25.0
# google-cloud-resource-manager      1.14.0
# google-cloud-spanner               3.51.0
# google-cloud-storage               2.19.0
# google-cloud-translate             3.19.0
# google-colab                       1.0.0
# google-crc32c                      1.6.0
# google-genai                       0.8.0
# google-generativeai                0.8.4
# google-pasta                       0.2.0
# google-resumable-media             2.7.2
# google-spark-connect               0.5.1
# googleapis-common-protos           1.66.0
# googledrivedownloader              1.1.0
# graphviz                           0.20.3
# greenlet                           3.1.1
# grpc-google-iam-v1                 0.14.0
# grpc-interceptor                   0.15.4
# grpcio                             1.70.0
# grpcio-status                      1.62.3
# gspread                            6.1.4
# gspread-dataframe                  4.0.0
# gym                                0.25.2
# gym-notices                        0.0.8
# gymnasium                          1.0.0
# h11                                0.14.0
# h5netcdf                           1.5.0
# h5py                               3.12.1
# highspy                            1.9.0
# holidays                           0.66
# holoviews                          1.20.0
# html5lib                           1.1
# httpcore                           1.0.7
# httpimport                         1.4.0
# httplib2                           0.22.0
# httpx                              0.28.1
# huggingface-hub                    0.28.1
# humanfriendly                      10.0
# humanize                           4.11.0
# hyperopt                           0.2.7
# ibis-framework                     9.2.0
# idna                               3.10
# imageio                            2.37.0
# imageio-ffmpeg                     0.6.0
# imagesize                          1.4.1
# imbalanced-learn                   0.13.0
# imgaug                             0.4.0
# immutabledict                      4.2.1
# importlib_metadata                 8.6.1
# importlib_resources                6.5.2
# imutils                            0.5.4
# inflect                            7.5.0
# iniconfig                          2.0.0
# intel-cmplr-lib-ur                 2025.0.4
# intel-openmp                       2025.0.4
# ipyevents                          2.0.2
# ipyfilechooser                     0.6.0
# ipykernel                          5.5.6
# ipyleaflet                         0.19.2
# ipyparallel                        8.8.0
# ipython                            7.34.0
# ipython-genutils                   0.2.0
# ipython-sql                        0.5.0
# ipytree                            0.2.2
# ipywidgets                         7.7.1
# itsdangerous                       2.2.0
# jax                                0.4.33
# jax-cuda12-pjrt                    0.4.33
# jax-cuda12-plugin                  0.4.33
# jaxlib                             0.4.33
# jeepney                            0.7.1
# jellyfish                          1.1.0
# jieba                              0.42.1
# Jinja2                             3.1.5
# jiter                              0.8.2
# joblib                             1.4.2
# jsonpatch                          1.33
# jsonpickle                         4.0.1
# jsonpointer                        3.0.0
# jsonschema                         4.23.0
# jsonschema-specifications          2024.10.1
# jupyter-client                     6.1.12
# jupyter-console                    6.1.0
# jupyter_core                       5.7.2
# jupyter-leaflet                    0.19.2
# jupyter-server                     1.24.0
# jupyterlab_pygments                0.3.0
# jupyterlab_widgets                 3.0.13
# kaggle                             1.6.17
# kagglehub                          0.3.6
# keras                              3.8.0
# keras-hub                          0.18.1
# keras-nlp                          0.18.1
# keyring                            23.5.0
# kiwisolver                         1.4.8
# langchain                          0.3.17
# langchain-core                     0.3.33
# langchain-text-splitters           0.3.5
# langcodes                          3.5.0
# langsmith                          0.3.6
# language_data                      1.3.0
# launchpadlib                       1.10.16
# lazr.restfulclient                 0.14.4
# lazr.uri                           1.0.6
# lazy_loader                        0.4
# libclang                           18.1.1
# libcudf-cu12                       24.12.0
# libkvikio-cu12                     24.12.1
# librosa                            0.10.2.post1
# lightgbm                           4.5.0
# linkify-it-py                      2.0.3
# llvmlite                           0.44.0
# locket                             1.0.0
# logical-unification                0.4.6
# lxml                               5.3.0
# marisa-trie                        1.2.1
# Markdown                           3.7
# markdown-it-py                     3.0.0
# MarkupSafe                         3.0.2
# matplotlib                         3.10.0
# matplotlib-inline                  0.1.7
# matplotlib-venn                    1.1.1
# mdit-py-plugins                    0.4.2
# mdurl                              0.1.2
# miniKanren                         1.0.3
# missingno                          0.5.2
# mistune                            3.1.1
# mizani                             0.13.1
# mkl                                2025.0.1
# ml-dtypes                          0.4.1
# mlxtend                            0.23.4
# more-itertools                     10.6.0
# moviepy                            1.0.3
# mpmath                             1.3.0
# msgpack                            1.1.0
# multidict                          6.1.0
# multipledispatch                   1.0.0
# multiprocess                       0.70.16
# multitasking                       0.0.11
# murmurhash                         1.0.12
# music21                            9.3.0
# namex                              0.0.8
# narwhals                           1.25.1
# natsort                            8.4.0
# nbclassic                          1.2.0
# nbclient                           0.10.2
# nbconvert                          7.16.6
# nbformat                           5.10.4
# ndindex                            1.9.2
# nest-asyncio                       1.6.0
# networkx                           3.4.2
# nibabel                            5.3.2
# nltk                               3.9.1
# notebook                           6.5.5
# notebook_shim                      0.2.4
# numba                              0.61.0
# numba-cuda                         0.0.17.1
# numexpr                            2.10.2
# numpy                              2.2.2
# nvidia-cublas-cu12                 12.4.5.8
# nvidia-cuda-cupti-cu12             12.4.127
# nvidia-cuda-nvcc-cu12              12.5.82
# nvidia-cuda-nvrtc-cu12             12.4.127
# nvidia-cuda-runtime-cu12           12.4.127
# nvidia-cudnn-cu12                  9.1.0.70
# nvidia-cufft-cu12                  11.2.1.3
# nvidia-curand-cu12                 10.3.5.147
# nvidia-cusolver-cu12               11.6.1.9
# nvidia-cusparse-cu12               12.3.1.170
# nvidia-cusparselt-cu12             0.6.2
# nvidia-nccl-cu12                   2.21.5
# nvidia-nvcomp-cu12                 4.1.0.6
# nvidia-nvjitlink-cu12              12.4.127
# nvidia-nvtx-cu12                   12.4.127
# nvtx                               0.2.10
# nx-cugraph-cu12                    24.12.0
# oauth2client                       4.1.3
# oauthlib                           3.2.2
# onnx                               1.17.0
# onnxruntime                        1.20.1
# onnxruntime-genai                  0.5.2
# openai                             1.61.1
# opencv-contrib-python              4.11.0.86
# opencv-python                      4.11.0.86
# opencv-python-headless             4.11.0.86
# openpyxl                           3.1.5
# opentelemetry-api                  1.16.0
# opentelemetry-sdk                  1.16.0
# opentelemetry-semantic-conventions 0.37b0
# opt_einsum                         3.4.0
# optax                              0.2.4
# optimum                            1.24.0
# optree                             0.14.0
# orbax-checkpoint                   0.6.4
# orjson                             3.10.15
# osqp                               0.6.7.post3
# packaging                          24.2
# pandas                             2.2.3
# pandas-datareader                  0.10.0
# pandas-gbq                         0.26.1
# pandas-stubs                       2.2.2.240909
# pandocfilters                      1.5.1
# panel                              1.6.0
# param                              2.2.0
# parso                              0.8.4
# parsy                              2.1
# partd                              1.4.2
# pathlib                            1.0.1
# patsy                              1.0.1
# peewee                             3.17.9
# peft                               0.14.0
# pexpect                            4.9.0
# pickleshare                        0.7.5
# pillow                             11.1.0
# pip                                24.1.2
# platformdirs                       4.3.6
# plotly                             5.24.1
# plotnine                           0.14.5
# pluggy                             1.5.0
# ply                                3.11
# polars                             1.9.0
# pooch                              1.8.2
# portpicker                         1.5.2
# preshed                            3.0.9
# prettytable                        3.14.0
# proglog                            0.1.10
# progressbar2                       4.5.0
# prometheus_client                  0.21.1
# promise                            2.3
# prompt_toolkit                     3.0.50
# propcache                          0.2.1
# prophet                            1.1.6
# proto-plus                         1.26.0
# protobuf                           5.29.3
# psutil                             5.9.5
# psycopg2                           2.9.10
# ptyprocess                         0.7.0
# py-cpuinfo                         9.0.0
# py4j                               0.10.9.7
# pyarrow                            19.0.0
# pyasn1                             0.6.1
# pyasn1_modules                     0.4.1
# pycocotools                        2.0.8
# pycparser                          2.22
# pydantic                           2.10.6
# pydantic_core                      2.27.2
# pydata-google-auth                 1.9.1
# pydot                              3.0.4
# pydotplus                          2.0.2
# PyDrive                            1.3.1
# PyDrive2                           1.21.3
# pyerfa                             2.0.1.5
# pygame                             2.6.1
# pygit2                             1.17.0
# Pygments                           2.18.0
# PyGObject                          3.42.1
# PyJWT                              2.10.1
# pylibcudf-cu12                     24.12.0
# pylibcugraph-cu12                  24.12.0
# pylibraft-cu12                     24.12.0
# pymc                               5.20.0
# pymystem3                          0.2.0
# pynvjitlink-cu12                   0.5.0
# pyogrio                            0.10.0
# Pyomo                              6.8.2
# PyOpenGL                           3.1.9
# pyOpenSSL                          24.2.1
# pyparsing                          3.2.1
# pyperclip                          1.9.0
# pyproj                             3.7.0
# pyshp                              2.3.1
# PySocks                            1.7.1
# pyspark                            3.5.4
# pytensor                           2.26.4
# pytest                             8.3.4
# python-apt                         0.0.0
# python-box                         7.3.2
# python-dateutil                    2.9.0.post0
# python-louvain                     0.16
# python-slugify                     8.0.4
# python-snappy                      0.7.3
# python-utils                       3.9.1
# pytz                               2025.1
# pyviz_comms                        3.0.4
# PyYAML                             6.0.2
# pyzmq                              24.0.1
# qdldl                              0.1.7.post5
# ratelim                            0.1.6
# referencing                        0.36.2
# regex                              2024.11.6
# requests                           2.32.3
# requests-oauthlib                  2.0.0
# requests-toolbelt                  1.0.0
# requirements-parser                0.9.0
# rich                               13.9.4
# rmm-cu12                           24.12.1
# rpds-py                            0.22.3
# rpy2                               3.4.2
# rsa                                4.9
# safetensors                        0.5.2
# scikit-image                       0.25.1
# scikit-learn                       1.6.1
# scipy                              1.13.1
# scooby                             0.10.0
# scs                                3.2.7.post2
# seaborn                            0.13.2
# SecretStorage                      3.3.1
# Send2Trash                         1.8.3
# sentence-transformers              3.4.1
# sentencepiece                      0.2.0
# sentry-sdk                         2.20.0
# setproctitle                       1.3.4
# setuptools                         75.1.0
# shap                               0.46.0
# shapely                            2.0.7
# shellingham                        1.5.4
# simple-parsing                     0.1.7
# simsimd                            6.2.1
# six                                1.17.0
# sklearn-compat                     0.1.3
# sklearn-pandas                     2.2.0
# slicer                             0.0.8
# smart-open                         7.1.0
# smmap                              5.0.2
# sniffio                            1.3.1
# snowballstemmer                    2.2.0
# soundfile                          0.13.1
# soupsieve                          2.6
# soxr                               0.5.0.post1
# spacy                              3.7.5
# spacy-legacy                       3.0.12
# spacy-loggers                      1.0.5
# spanner-graph-notebook             1.0.9
# Sphinx                             8.1.3
# sphinxcontrib-applehelp            2.0.0
# sphinxcontrib-devhelp              2.0.0
# sphinxcontrib-htmlhelp             2.1.0
# sphinxcontrib-jsmath               1.0.1
# sphinxcontrib-qthelp               2.0.0
# sphinxcontrib-serializinghtml      2.0.0
# SQLAlchemy                         2.0.37
# sqlglot                            25.6.1
# sqlparse                           0.5.3
# srsly                              2.5.1
# stanio                             0.5.1
# statsmodels                        0.14.4
# stringzilla                        3.11.3
# sympy                              1.13.1
# tables                             3.10.2
# tabulate                           0.9.0
# tbb                                2022.0.0
# tcmlib                             1.2.0
# tenacity                           9.0.0
# tensorboard                        2.18.0
# tensorboard-data-server            0.7.2
# tensorflow                         2.18.0
# tensorflow-datasets                4.9.7
# tensorflow-hub                     0.16.1
# tensorflow-io-gcs-filesystem       0.37.1
# tensorflow-metadata                1.16.1
# tensorflow-probability             0.25.0
# tensorflow-text                    2.18.1
# tensorstore                        0.1.71
# termcolor                          2.5.0
# terminado                          0.18.1
# text-unidecode                     1.3
# textblob                           0.19.0
# tf_keras                           2.18.0
# tf-slim                            1.1.0
# thinc                              8.2.5
# threadpoolctl                      3.5.0
# tifffile                           2025.1.10
# timm                               1.0.14
# tinycss2                           1.4.0
# tokenizers                         0.21.0
# toml                               0.10.2
# toolz                              0.12.1
# torch                              2.6.0
# torchaudio                         2.5.1+cu124
# torchsummary                       1.5.1
# torchvision                        0.21.0
# tornado                            6.4.2
# tqdm                               4.67.1
# traitlets                          5.7.1
# traittypes                         0.2.1
# transformers                       4.48.3
# triton                             3.2.0
# tweepy                             4.15.0
# typeguard                          4.4.1
# typer                              0.15.1
# types-pytz                         2025.1.0.20250204
# types-setuptools                   75.8.0.20250210
# typing_extensions                  4.12.2
# tzdata                             2025.1
# tzlocal                            5.2
# uc-micro-py                        1.0.3
# umf                                0.9.1
# uritemplate                        4.1.1
# urllib3                            2.3.0
# vega-datasets                      0.9.0
# wadllib                            1.3.6
# wandb                              0.19.6
# wasabi                             1.1.3
# wcwidth                            0.2.13
# weasel                             0.4.1
# webcolors                          24.11.1
# webencodings                       0.5.1
# websocket-client                   1.8.0
# websockets                         14.2
# Werkzeug                           3.1.3
# wheel                              0.45.1
# widgetsnbextension                 3.6.10
# wordcloud                          1.9.4
# wrapt                              1.17.2
# xarray                             2025.1.2
# xarray-einstats                    0.8.0
# xgboost                            2.1.3
# xlrd                               2.0.1
# xxhash                             3.5.0
# xyzservices                        2025.1.0
# yarl                               1.18.3
# yellowbrick                        1.5
# yfinance                           0.2.52
# zipp                               3.21.0
# zstandard                          0.23.0

# %% [markdown]
# Package                            Version
# ---------------------------------- ------------------
# absl-py                            1.4.0
# accelerate                         1.3.0
# aiohappyeyeballs                   2.4.6
# aiohttp                            3.11.12
# aiosignal                          1.3.2
# alabaster                          1.0.0
# albucore                           0.0.23
# albumentations                     2.0.3
# ale-py                             0.10.1
# altair                             5.5.0
# annotated-types                    0.7.0
# anyio                              3.7.1
# argon2-cffi                        23.1.0
# argon2-cffi-bindings               21.2.0
# array_record                       0.6.0
# arviz                              0.20.0
# astropy                            7.0.0
# astropy-iers-data                  0.2025.2.3.0.32.42
# astunparse                         1.6.3
# atpublic                           4.1.0
# attrs                              25.1.0
# audioread                          3.0.1
# autograd                           1.7.0
# babel                              2.17.0
# backcall                           0.2.0
# beautifulsoup4                     4.13.3
# bigframes                          1.35.0
# bigquery-magics                    0.5.0
# bleach                             6.2.0
# blinker                            1.9.0
# blis                               0.7.11
# blosc2                             3.0.0
# bokeh                              3.6.3
# Bottleneck                         1.4.2
# bqplot                             0.12.44
# branca                             0.8.1
# CacheControl                       0.14.2
# cachetools                         5.5.1
# catalogue                          2.0.10
# certifi                            2025.1.31
# cffi                               1.17.1
# chardet                            5.2.0
# charset-normalizer                 3.4.1
# chex                               0.1.88
# clarabel                           0.10.0
# click                              8.1.8
# cloudpathlib                       0.20.0
# cloudpickle                        3.1.1
# cmake                              3.31.4
# cmdstanpy                          1.2.5
# colorcet                           3.1.0
# coloredlogs                        15.0.1
# colorlover                         0.3.0
# colour                             0.1.5
# community                          1.0.0b1
# confection                         0.1.5
# cons                               0.4.6
# contourpy                          1.3.1
# cramjam                            2.9.1
# cryptography                       43.0.3
# cuda-python                        12.6.0
# cudf-cu12                          24.12.0
# cufflinks                          0.17.3
# cupy-cuda12x                       13.3.0
# cvxopt                             1.3.2
# cvxpy                              1.6.0
# cycler                             0.12.1
# cyipopt                            1.5.0
# cymem                              2.0.11
# Cython                             3.0.11
# dask                               2024.10.0
# datascience                        0.17.6
# datasets                           3.2.0
# db-dtypes                          1.4.1
# dbus-python                        1.2.18
# debugpy                            1.8.0
# decorator                          4.4.2
# defusedxml                         0.7.1
# Deprecated                         1.2.18
# diffusers                          0.32.2
# dill                               0.3.8
# distro                             1.9.0
# dlib                               19.24.2
# dm-tree                            0.1.9
# docker-pycreds                     0.4.0
# docstring_parser                   0.16
# docutils                           0.21.2
# dopamine_rl                        4.1.2
# duckdb                             1.1.3
# earthengine-api                    1.5.1
# easydict                           1.13
# editdistance                       0.8.1
# eerepr                             0.1.0
# einops                             0.8.0
# en-core-web-sm                     3.7.1
# entrypoints                        0.4
# et_xmlfile                         2.0.0
# etils                              1.11.0
# etuples                            0.3.9
# evaluate                           0.4.3
# Farama-Notifications               0.0.4
# fastai                             2.7.18
# fastcore                           1.7.29
# fastdownload                       0.0.7
# fastjsonschema                     2.21.1
# fastprogress                       1.0.3
# fastrlock                          0.8.3
# filelock                           3.17.0
# firebase-admin                     6.6.0
# Flask                              3.1.0
# flatbuffers                        25.2.10
# flax                               0.10.2
# folium                             0.19.4
# fonttools                          4.55.8
# frozendict                         2.4.6
# frozenlist                         1.5.0
# fsspec                             2024.9.0
# future                             1.0.0
# gast                               0.6.0
# gcsfs                              2024.10.0
# GDAL                               3.6.4
# gdown                              5.2.0
# geemap                             0.35.1
# gensim                             4.3.3
# geocoder                           1.38.1
# geographiclib                      2.0
# geopandas                          1.0.1
# geopy                              2.4.1
# gin-config                         0.5.0
# gitdb                              4.0.12
# GitPython                          3.1.44
# glob2                              0.7
# google                             2.0.3
# google-ai-generativelanguage       0.6.15
# google-api-core                    2.19.2
# google-api-python-client           2.160.0
# google-auth                        2.27.0
# google-auth-httplib2               0.2.0
# google-auth-oauthlib               1.2.1
# google-cloud-aiplatform            1.79.0
# google-cloud-bigquery              3.25.0
# google-cloud-bigquery-connection   1.17.0
# google-cloud-bigquery-storage      2.28.0
# google-cloud-bigtable              2.28.1
# google-cloud-core                  2.4.1
# google-cloud-dataproc              5.16.0
# google-cloud-datastore             2.20.2
# google-cloud-firestore             2.20.0
# google-cloud-functions             1.19.0
# google-cloud-iam                   2.17.0
# google-cloud-language              2.16.0
# google-cloud-pubsub                2.25.0
# google-cloud-resource-manager      1.14.0
# google-cloud-spanner               3.51.0
# google-cloud-storage               2.19.0
# google-cloud-translate             3.19.0
# google-colab                       1.0.0
# google-crc32c                      1.6.0
# google-genai                       0.8.0
# google-generativeai                0.8.4
# google-pasta                       0.2.0
# google-resumable-media             2.7.2
# google-spark-connect               0.5.1
# googleapis-common-protos           1.66.0
# googledrivedownloader              1.1.0
# graphviz                           0.20.3
# greenlet                           3.1.1
# grpc-google-iam-v1                 0.14.0
# grpc-interceptor                   0.15.4
# grpcio                             1.70.0
# grpcio-status                      1.62.3
# gspread                            6.1.4
# gspread-dataframe                  4.0.0
# gym                                0.25.2
# gym-notices                        0.0.8
# gymnasium                          1.0.0
# h11                                0.14.0
# h5netcdf                           1.5.0
# h5py                               3.12.1
# highspy                            1.9.0
# holidays                           0.66
# holoviews                          1.20.0
# html5lib                           1.1
# httpcore                           1.0.7
# httpimport                         1.4.0
# httplib2                           0.22.0
# httpx                              0.28.1
# huggingface-hub                    0.28.1
# humanfriendly                      10.0
# humanize                           4.11.0
# hyperopt                           0.2.7
# ibis-framework                     9.2.0
# idna                               3.10
# imageio                            2.37.0
# imageio-ffmpeg                     0.6.0
# imagesize                          1.4.1
# imbalanced-learn                   0.13.0
# imgaug                             0.4.0
# immutabledict                      4.2.1
# importlib_metadata                 8.6.1
# importlib_resources                6.5.2
# imutils                            0.5.4
# inflect                            7.5.0
# iniconfig                          2.0.0
# intel-cmplr-lib-ur                 2025.0.4
# intel-openmp                       2025.0.4
# ipyevents                          2.0.2
# ipyfilechooser                     0.6.0
# ipykernel                          5.5.6
# ipyleaflet                         0.19.2
# ipyparallel                        8.8.0
# ipython                            7.34.0
# ipython-genutils                   0.2.0
# ipython-sql                        0.5.0
# ipytree                            0.2.2
# ipywidgets                         7.7.1
# itsdangerous                       2.2.0
# jax                                0.4.33
# jax-cuda12-pjrt                    0.4.33
# jax-cuda12-plugin                  0.4.33
# jaxlib                             0.4.33
# jeepney                            0.7.1
# jellyfish                          1.1.0
# jieba                              0.42.1
# Jinja2                             3.1.5
# jiter                              0.8.2
# joblib                             1.4.2
# jsonpatch                          1.33
# jsonpickle                         4.0.1
# jsonpointer                        3.0.0
# jsonschema                         4.23.0
# jsonschema-specifications          2024.10.1
# jupyter-client                     6.1.12
# jupyter-console                    6.1.0
# jupyter_core                       5.7.2
# jupyter-leaflet                    0.19.2
# jupyter-server                     1.24.0
# jupyterlab_pygments                0.3.0
# jupyterlab_widgets                 3.0.13
# kaggle                             1.6.17
# kagglehub                          0.3.6
# keras                              3.8.0
# keras-hub                          0.18.1
# keras-nlp                          0.18.1
# keyring                            23.5.0
# kiwisolver                         1.4.8
# langchain                          0.3.17
# langchain-core                     0.3.33
# langchain-text-splitters           0.3.5
# langcodes                          3.5.0
# langsmith                          0.3.6
# language_data                      1.3.0
# launchpadlib                       1.10.16
# lazr.restfulclient                 0.14.4
# lazr.uri                           1.0.6
# lazy_loader                        0.4
# libclang                           18.1.1
# libcudf-cu12                       24.12.0
# libkvikio-cu12                     24.12.1
# librosa                            0.10.2.post1
# lightgbm                           4.5.0
# linkify-it-py                      2.0.3
# llvmlite                           0.44.0
# locket                             1.0.0
# logical-unification                0.4.6
# lxml                               5.3.0
# marisa-trie                        1.2.1
# Markdown                           3.7
# markdown-it-py                     3.0.0
# MarkupSafe                         3.0.2
# matplotlib                         3.10.0
# matplotlib-inline                  0.1.7
# matplotlib-venn                    1.1.1
# mdit-py-plugins                    0.4.2
# mdurl                              0.1.2
# miniKanren                         1.0.3
# missingno                          0.5.2
# mistune                            3.1.1
# mizani                             0.13.1
# mkl                                2025.0.1
# ml-dtypes                          0.4.1
# mlxtend                            0.23.4
# more-itertools                     10.6.0
# moviepy                            1.0.3
# mpmath                             1.3.0
# msgpack                            1.1.0
# multidict                          6.1.0
# multipledispatch                   1.0.0
# multiprocess                       0.70.16
# multitasking                       0.0.11
# murmurhash                         1.0.12
# music21                            9.3.0
# namex                              0.0.8
# narwhals                           1.25.1
# natsort                            8.4.0
# nbclassic                          1.2.0
# nbclient                           0.10.2
# nbconvert                          7.16.6
# nbformat                           5.10.4
# ndindex                            1.9.2
# nest-asyncio                       1.6.0
# networkx                           3.4.2
# nibabel                            5.3.2
# nltk                               3.9.1
# notebook                           6.5.5
# notebook_shim                      0.2.4
# numba                              0.61.0
# numba-cuda                         0.0.17.1
# numexpr                            2.10.2
# numpy                              2.2.2
# nvidia-cublas-cu12                 12.4.5.8
# nvidia-cuda-cupti-cu12             12.4.127
# nvidia-cuda-nvcc-cu12              12.5.82
# nvidia-cuda-nvrtc-cu12             12.4.127
# nvidia-cuda-runtime-cu12           12.4.127
# nvidia-cudnn-cu12                  9.1.0.70
# nvidia-cufft-cu12                  11.2.1.3
# nvidia-curand-cu12                 10.3.5.147
# nvidia-cusolver-cu12               11.6.1.9
# nvidia-cusparse-cu12               12.3.1.170
# nvidia-cusparselt-cu12             0.6.2
# nvidia-nccl-cu12                   2.21.5
# nvidia-nvcomp-cu12                 4.1.0.6
# nvidia-nvjitlink-cu12              12.4.127
# nvidia-nvtx-cu12                   12.4.127
# nvtx                               0.2.10
# nx-cugraph-cu12                    24.12.0
# oauth2client                       4.1.3
# oauthlib                           3.2.2
# onnx                               1.17.0
# onnxruntime                        1.20.1
# onnxruntime-genai                  0.5.2
# openai                             1.61.1
# opencv-contrib-python              4.11.0.86
# opencv-python                      4.11.0.86
# opencv-python-headless             4.11.0.86
# openpyxl                           3.1.5
# opentelemetry-api                  1.16.0
# opentelemetry-sdk                  1.16.0
# opentelemetry-semantic-conventions 0.37b0
# opt_einsum                         3.4.0
# optax                              0.2.4
# optimum                            1.24.0
# optree                             0.14.0
# orbax-checkpoint                   0.6.4
# orjson                             3.10.15
# osqp                               0.6.7.post3
# packaging                          24.2
# pandas                             2.2.3
# pandas-datareader                  0.10.0
# pandas-gbq                         0.26.1
# pandas-stubs                       2.2.2.240909
# pandocfilters                      1.5.1
# panel                              1.6.0
# param                              2.2.0
# parso                              0.8.4
# parsy                              2.1
# partd                              1.4.2
# pathlib                            1.0.1
# patsy                              1.0.1
# peewee                             3.17.9
# peft                               0.14.0
# pexpect                            4.9.0
# pickleshare                        0.7.5
# pillow                             11.1.0
# pip                                24.1.2
# platformdirs                       4.3.6
# plotly                             5.24.1
# plotnine                           0.14.5
# pluggy                             1.5.0
# ply                                3.11
# polars                             1.9.0
# pooch                              1.8.2
# portpicker                         1.5.2
# preshed                            3.0.9
# prettytable                        3.14.0
# proglog                            0.1.10
# progressbar2                       4.5.0
# prometheus_client                  0.21.1
# promise                            2.3
# prompt_toolkit                     3.0.50
# propcache                          0.2.1
# prophet                            1.1.6
# proto-plus                         1.26.0
# protobuf                           5.29.3
# psutil                             5.9.5
# psycopg2                           2.9.10
# ptyprocess                         0.7.0
# py-cpuinfo                         9.0.0
# py4j                               0.10.9.7
# pyarrow                            19.0.0
# pyasn1                             0.6.1
# pyasn1_modules                     0.4.1
# pycocotools                        2.0.8
# pycparser                          2.22
# pydantic                           2.10.6
# pydantic_core                      2.27.2
# pydata-google-auth                 1.9.1
# pydot                              3.0.4
# pydotplus                          2.0.2
# PyDrive                            1.3.1
# PyDrive2                           1.21.3
# pyerfa                             2.0.1.5
# pygame                             2.6.1
# pygit2                             1.17.0
# Pygments                           2.18.0
# PyGObject                          3.42.1
# PyJWT                              2.10.1
# pylibcudf-cu12                     24.12.0
# pylibcugraph-cu12                  24.12.0
# pylibraft-cu12                     24.12.0
# pymc                               5.20.0
# pymystem3                          0.2.0
# pynvjitlink-cu12                   0.5.0
# pyogrio                            0.10.0
# Pyomo                              6.8.2
# PyOpenGL                           3.1.9
# pyOpenSSL                          24.2.1
# pyparsing                          3.2.1
# pyperclip                          1.9.0
# pyproj                             3.7.0
# pyshp                              2.3.1
# PySocks                            1.7.1
# pyspark                            3.5.4
# pytensor                           2.26.4
# pytest                             8.3.4
# python-apt                         0.0.0
# python-box                         7.3.2
# python-dateutil                    2.9.0.post0
# python-louvain                     0.16
# python-slugify                     8.0.4
# python-snappy                      0.7.3
# python-utils                       3.9.1
# pytz                               2025.1
# pyviz_comms                        3.0.4
# PyYAML                             6.0.2
# pyzmq                              24.0.1
# qdldl                              0.1.7.post5
# ratelim                            0.1.6
# referencing                        0.36.2
# regex                              2024.11.6
# requests                           2.32.3
# requests-oauthlib                  2.0.0
# requests-toolbelt                  1.0.0
# requirements-parser                0.9.0
# rich                               13.9.4
# rmm-cu12                           24.12.1
# rpds-py                            0.22.3
# rpy2                               3.4.2
# rsa                                4.9
# safetensors                        0.5.2
# scikit-image                       0.25.1
# scikit-learn                       1.6.1
# scipy                              1.13.1
# scooby                             0.10.0
# scs                                3.2.7.post2
# seaborn                            0.13.2
# SecretStorage                      3.3.1
# Send2Trash                         1.8.3
# sentence-transformers              3.4.1
# sentencepiece                      0.2.0
# sentry-sdk                         2.20.0
# setproctitle                       1.3.4
# setuptools                         75.1.0
# shap                               0.46.0
# shapely                            2.0.7
# shellingham                        1.5.4
# simple-parsing                     0.1.7
# simsimd                            6.2.1
# six                                1.17.0
# sklearn-compat                     0.1.3
# sklearn-pandas                     2.2.0
# slicer                             0.0.8
# smart-open                         7.1.0
# smmap                              5.0.2
# sniffio                            1.3.1
# snowballstemmer                    2.2.0
# soundfile                          0.13.1
# soupsieve                          2.6
# soxr                               0.5.0.post1
# spacy                              3.7.5
# spacy-legacy                       3.0.12
# spacy-loggers                      1.0.5
# spanner-graph-notebook             1.0.9
# Sphinx                             8.1.3
# sphinxcontrib-applehelp            2.0.0
# sphinxcontrib-devhelp              2.0.0
# sphinxcontrib-htmlhelp             2.1.0
# sphinxcontrib-jsmath               1.0.1
# sphinxcontrib-qthelp               2.0.0
# sphinxcontrib-serializinghtml      2.0.0
# SQLAlchemy                         2.0.37
# sqlglot                            25.6.1
# sqlparse                           0.5.3
# srsly                              2.5.1
# stanio                             0.5.1
# statsmodels                        0.14.4
# stringzilla                        3.11.3
# sympy                              1.13.1
# tables                             3.10.2
# tabulate                           0.9.0
# tbb                                2022.0.0
# tcmlib                             1.2.0
# tenacity                           9.0.0
# tensorboard                        2.18.0
# tensorboard-data-server            0.7.2
# tensorflow                         2.18.0
# tensorflow-datasets                4.9.7
# tensorflow-hub                     0.16.1
# tensorflow-io-gcs-filesystem       0.37.1
# tensorflow-metadata                1.16.1
# tensorflow-probability             0.25.0
# tensorflow-text                    2.18.1
# tensorstore                        0.1.71
# termcolor                          2.5.0
# terminado                          0.18.1
# text-unidecode                     1.3
# textblob                           0.19.0
# tf_keras                           2.18.0
# tf-slim                            1.1.0
# thinc                              8.2.5
# threadpoolctl                      3.5.0
# tifffile                           2025.1.10
# timm                               1.0.14
# tinycss2                           1.4.0
# tokenizers                         0.21.0
# toml                               0.10.2
# toolz                              0.12.1
# torch                              2.6.0
# torchaudio                         2.5.1+cu124
# torchsummary                       1.5.1
# torchvision                        0.21.0
# tornado                            6.4.2
# tqdm                               4.67.1
# traitlets                          5.7.1
# traittypes                         0.2.1
# transformers                       4.48.3
# triton                             3.2.0
# tweepy                             4.15.0
# typeguard                          4.4.1
# typer                              0.15.1
# types-pytz                         2025.1.0.20250204
# types-setuptools                   75.8.0.20250210
# typing_extensions                  4.12.2
# tzdata                             2025.1
# tzlocal                            5.2
# uc-micro-py                        1.0.3
# umf                                0.9.1
# uritemplate                        4.1.1
# urllib3                            2.3.0
# vega-datasets                      0.9.0
# wadllib                            1.3.6
# wandb                              0.19.6
# wasabi                             1.1.3
# wcwidth                            0.2.13
# weasel                             0.4.1
# webcolors                          24.11.1
# webencodings                       0.5.1
# websocket-client                   1.8.0
# websockets                         14.2
# Werkzeug                           3.1.3
# wheel                              0.45.1
# widgetsnbextension                 3.6.10
# wordcloud                          1.9.4
# wrapt                              1.17.2
# xarray                             2025.1.2
# xarray-einstats                    0.8.0
# xgboost                            2.1.3
# xlrd                               2.0.1
# xxhash                             3.5.0
# xyzservices                        2025.1.0
# yarl                               1.18.3
# yellowbrick                        1.5
# yfinance                           0.2.52
# zipp                               3.21.0
# zstandard                          0.23.0

# %%
# !npm list
# Out:
# ⠙content@ /content
# ├── @huggingface/transformers@3.3.3
# ├── @xenova/transformers@2.17.2
# ├── onnxruntime-node@1.20.1
# └── onnxruntime-web@1.21.0-dev.20250206-d981b153d3
#
# ⠹

# %% [markdown]
# ⠙content@ /content
# ├── @huggingface/transformers@3.3.3
# ├── @xenova/transformers@2.17.2
# ├── onnxruntime-node@1.20.1
# └── onnxruntime-web@1.21.0-dev.20250206-d981b153d3

# %%
# %%node
# import { pipeline } from '@xenova/transformers';
#
# // تحميل النموذج
# const pipe = await pipeline('text-generation', 'onnx-community/Qwen2.5-0.5B-Instruct-ONNX-MHA');
#
# // تحديد النص المدخل
# const prompt = "Write a short story about a robot who learns to love:";
#
# // توليد النص
# const generatedText = await pipe(prompt, {
#   max_new_tokens: 100
# });
#
# // طباعة النص الناتج
# console.log(generatedText[0].generated_text);
# Out:
# UsageError: Cell magic `%%node` not found.

# %%
# !pip install ijavascript
# Out:
# ERROR: Could not find a version that satisfies the requirement ijavascript (from versions: none)
# ERROR: No matching distribution found for ijavascript

# %%
// my_script.js
    console.log("Hello from Node.js in Colab!");
# Out:
#   File "<ipython-input-24-ccc100327b39>", line 1
#     // my_script.js
#     ^
# SyntaxError: invalid syntax

# %%
# !pip install ijavascript
# Out:
# ERROR: Could not find a version that satisfies the requirement ijavascript (from versions: none)
# ERROR: No matching distribution found for ijavascript

# %%
# %%node
#
# console.log("Hello from Node.js in Colab!");
# Out:
# UsageError: Cell magic `%%node` not found.

# %% [markdown]
# ### إنشاء وتشغيل الكود داخل كولاب مباشرةً:

# %%
# %%writefile script.js
# import { pipeline } from '@xenova/transformers';
#
# async function main() {
#     const pipe = await pipeline('text-generation', 'onnx-community/Qwen2.5-0.5B-Instruct-ONNX-MHA');
#
#     const prompt = "Write a short story about a robot who learns to love:";
#     const generatedText = await pipe(prompt, { max_new_tokens: 100 });
#
#     console.log(generatedText[0].generated_text);
# }
#
# main();
# Out:
# Writing script.js

# %%
# !node script.js
# Out:
# file:///content/node_modules/@xenova/transformers/src/utils/hub.js:238
#     throw Error(`${message}: "${remoteURL}".`);
#           ^
#
# Error: Could not locate file: "https://huggingface.co/onnx-community/Qwen2.5-0.5B-Instruct-ONNX-MHA/resolve/main/onnx/decoder_model_merged_quantized.onnx".
#     at handleError (file:///content/node_modules/@xenova/transformers/src/utils/hub.js:238:11)
#     at getModelFile (file:///content/node_modules/@xenova/transformers/src/utils/hub.js:471:24)
#     at process.processTicksAndRejections (node:internal/process/task_queues:95:5)
#     at async constructSession (file:///content/node_modules/@xenova/transformers/src/models.js:123:18)
#     at async Promise.all (index 1)
#     at async Qwen2ForCausalLM.from_pretrained (file:///content/node_modules/@xenova/transformers/src/models.js:761:20)
#     at async AutoModelForCausalLM.from_pretrained (file:///content/node_modules/@xenova/transformers/src/models.js:5519:20)
#     at async Promise.all (index 1)
#     at async loadItems (file:///content/node_modules/@xenova/transformers/src/pipelines.js:3279:5)
#     at async pipeline (file:///content/node_modules/@xenova/transformers/src/pipelines.js:3219:21)
#
# Node.js v18.20.5

# %%
# %%node
#
# console.log("Hello from Node.js in Colab!");
# Out:
# UsageError: Cell magic `%%node` not found.

# %%
# !sudo npm install -g ijavascript ijsinstall
# Out:
# sudo: npm: command not found

# %%
# !pip install javascript
# Out:
# Collecting javascript
#   Downloading javascript-1%211.2.2-py3-none-any.whl.metadata (14 kB)
# Downloading javascript-1%211.2.2-py3-none-any.whl (34 kB)
# Installing collected packages: javascript
# Successfully installed javascript-1!1.2.2

# %% [markdown]
# شغال

# %%
from javascript import require, globalThis

chalk, fs = require("chalk"), require("fs")

print("Hello", chalk.red("world!"), "it's", globalThis.Date().toLocaleString())
fs.writeFileSync("HelloWorld.txt", "hi!")
# Out:
#  Installing 'chalk' version 'latest'... This will only happen once.
#
#
#
# added 1 package, and audited 2 packages in 1s
#
#
#
# 1 package is looking for funding
#
#   run `npm fund` for details
#
#
#
# found 0 vulnerabilities
#
# [JSE]
#
# [JSE]
#
#
#
#  OK.
#
# Hello world! it's 2/11/2025, 10:53:17 PM

# %%
# !npm i pythonia
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇
# added 7 packages, and audited 147 packages in 5s
# ⠇
# ⠇31 packages are looking for funding
# ⠇  run `npm fund` for details
# ⠇
# found 0 vulnerabilities
# ⠇

# %%
import tkinter as tk

root = tk.Tk()
a = tk.Label(root, text='Hello World')
import tkinter as tk

root = tk.Tk()
a = tk.Label(root, text='Hello World')
import tkinter as tk

root = tk.Tk()
a = tk.Label(root, text='Hello World')
import tkinter as tk

root = tk.Tk()
a = tk.Label(root, text='Hello World')
import tkinter as tk

root = tk.Tk()
a = tk.Label(root, text='Hello World')
import tkinter as tk

root = tk.Tk()
a = tk.Label(root, text='Hello World')
a.pack()
root.mainloop()
#python. - Commented out as it is not valid python syntax
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# <ipython-input-9-bc80f170878d> in <cell line: 0>()
#       1 import tkinter as tk
#       2
# ----> 3 root = tk.Tk()
#       4 a = tk.Label(root, text='Hello World')
#       5 import tkinter as tk
#
# /usr/lib/python3.11/tkinter/__init__.py in __init__(self, screenName, baseName, className, useTk, sync, use)
#    2324                 baseName = baseName + ext
#    2325         interactive = False
# -> 2326         self.tk = _tkinter.create(screenName, baseName, className, interactive, wantobjects, useTk, sync, use)
#    2327         if useTk:
#    2328             self._loadtk()
#
# TclError: no display name and no $DISPLAY environment variable

# %%
from javascript import require

# %%
function whatTimeIsIt() {
    return (new Date()).toLocaleString()
}
module.exports = { whatTimeIsIt }
# Out:
#   File "<ipython-input-12-f6b3ad63f8bf>", line 1
#     function whatTimeIsIt() {
#              ^
# SyntaxError: invalid syntax

# %%
from javascript import require
time = require('./time.js')
print(time.whatTimeIsIt())
# Out:
# Error in exception handler
# [Errno 2] No such file or directory: 'file:///content/time.js'
# ** JavaScript Stacktrace **
# ReferenceError: module is not defined in ES module scope
# This file is being treated as an ES module because it has a '.js' file extension and '/content/package.json' contains "type": "module". To treat it as a CommonJS script, rename it to use the '.cjs' file extension.
#     at file:///content/time.js:4:1
#     at ModuleJob.run (node:internal/modules/esm/module_job:195:25)
#     at async ModuleLoader.import (node:internal/modules/esm/loader:337:24)
#     at async importModuleDynamicallyWrapper (node:internal/vm/module:432:15)
#     at async Object.$require [as require] (/usr/local/lib/python3.11/dist-packages/javascript/js/deps.js:118:17)
#     at async Bridge.call (/usr/local/lib/python3.11/dist-packages/javascript/js/bridge.js:136:17)
#     at async Bridge.onMessage (/usr/local/lib/python3.11/dist-packages/javascript/js/bridge.js:231:7)
# ** Python Stacktrace **
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-13-2201b6086eae>", line 2, in <cell line: 0>
#     time = require('./time.js')
#            ^^^^^^^^^^^^^^^^^^^^
#
#   File "/usr/local/lib/python3.11/dist-packages/javascript/__init__.py", line 49, in require
#     return config.global_jsi.require(name, version, calling_dir, timeout=900)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/usr/local/lib/python3.11/dist-packages/javascript/proxy.py", line 218, in __call__
#     else self._exe.callProp(
#          ^^^^^^^^^^^^^^^^^^^
#
#   File "/usr/local/lib/python3.11/dist-packages/javascript/proxy.py", line 158, in callProp
#     resp = self.pcall(ffid, "call", method, args, timeout=timeout, forceRefs=forceRefs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/usr/local/lib/python3.11/dist-packages/javascript/proxy.py", line 146, in pcall
#     raise JavaScriptError(attr, res["error"])

# %%
# %%node
#
# console.log("Hello from Node.js in Colab!");
# Out:
# UsageError: Cell magic `%%node` not found.

# %% [markdown]
# شغال

# %% [markdown]
# https://stackoverflow.com/questions/57231654/not-found-cell-magic-time

# %%
# %%writefile test2.txt
# line1
# line2
# Out:
# Writing test2.txt

# %%
# %load_ext autoreload
# %autoreload 2
import os,sys
try:
    import lime
except:
    sys.path.append(os.path.join('..', '..')) # add the current directory
    import lime
from lime import lime_image

explainer = lime_image.LimeImageExplainer()

# %%time
explanation = explainer.explain_instance(images[0], inet_model.predict, top_labels=5, hide_color=0, num_samples=1000)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-16-0233e491014f> in <cell line: 0>()
#       4 try:
# ----> 5     import lime
#       6 except:
#
# ModuleNotFoundError: No module named 'lime'
#
# During handling of the above exception, another exception occurred:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-16-0233e491014f> in <cell line: 0>()
#       6 except:
#       7     sys.path.append(os.path.join('..', '..')) # add the current directory
# ----> 8     import lime
#       9 from lime import lime_image
#      10
#
# ModuleNotFoundError: No module named 'lime'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# %%timeit
# Out:
# UsageError: %%timeit is a cell magic, but the cell body is empty. Did you mean the line magic %timeit (single %)?

# %% [markdown]
# ayhgشغال

# %%
# %%timeit
print("qqqqqqqqqq")
# Out:
# Streaming output truncated to the last 5000 lines.
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# qqqqqqqqqq
# 33.5 µs ± 3.43 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %% [markdown]
# https://stackoverflow.com/questions/28711667/ipython-javascript-magic-output-into-cell-and-console

# %% [markdown]
# شغال كود نود ف خلية كولاب بدون
# node xxxxxxxx.js

# %%
# %%script node
# console.log("Hi")
# Out:
# Hi

# %%
# %%script node
#     console.log("Hello from Node.js in Colab!");
# Out:
# Hello from Node.js in Colab!

# %%
# %%script node
# import { pipeline } from '@xenova/transformers';
#
# async function run() {
#     // تحميل النموذج
#     const pipe = await pipeline('text-generation', 'onnx-community/Qwen2.5-0.5B-Instruct-ONNX-MHA');
#
#     // إدخال النص
#     const prompt = "Write a short story about a robot who learns to love:";
#
#     // توليد النص
#     const generatedText = await pipe(prompt, { max_new_tokens: 100 });
#
#     // طباعة النص الناتج
#     console.log(generatedText[0].generated_text);
# }
#
# // تشغيل الدالة
# run();
# Out:
# [stdin]:1
# import { pipeline } from '@xenova/transformers';
# ^^^^^^
#
# SyntaxError: Cannot use import statement outside a module
#     at makeContextifyScript (node:internal/vm:122:14)
#     at node:internal/process/execution:89:22
#     at [stdin]-wrapper:6:24
#     at runScript (node:internal/process/execution:83:62)
#     at evalScript (node:internal/process/execution:114:10)
#     at node:internal/main/eval_stdin:32:5
#     at Socket.<anonymous> (node:internal/process/execution:215:5)
#     at Socket.emit (node:events:529:35)
#     at endReadableNT (node:internal/streams/readable:1400:12)
#     at process.processTicksAndRejections (node:internal/process/task_queues:82:21)
#
# Node.js v18.20.5
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-22-927eb1582484> in <cell line: 0>()
# ----> 1 get_ipython().run_cell_magic('script', 'node', 'import { pipeline } from \'@xenova/transformers\';\n\nasync function run() {\n    // تحميل النموذج\n    const pipe = await pipeline(\'text-generation\', \'onnx-community/Qwen2.5-0.5B-Instruct-ONNX-MHA\');\n\n    // إدخال النص\n    const prompt = "Write a short story about a robot who learns to love:";\n\n    // توليد النص\n    const generatedText = await pipe(prompt, { max_new_tokens: 100 });\n\n    // طباعة النص الناتج\n    console.log(generatedText[0].generated_text);\n}\n\n// تشغيل الدالة\nrun();\n')
#
# /usr/local/lib/python3.11/dist-packages/google/colab/_shell.py in run_cell_magic(self, magic_name, line, cell)
#     332     if line and not cell:
#     333       cell = ' '
# --> 334     return super().run_cell_magic(magic_name, line, cell)
#     335
#     336
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2471             with self.builtin_trap:
#    2472                 args = (magic_arg_s, cell)
# -> 2473                 result = fn(*args, **kwargs)
#    2474             return result
#    2475
#
# <decorator-gen-103> in shebang(self, line, cell)
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/magics/script.py in shebang(self, line, cell)
#     243             sys.stderr.flush()
#     244         if args.raise_error and p.returncode!=0:
# --> 245             raise CalledProcessError(p.returncode, cell, output=out, stderr=err)
#     246
#     247     def _run_script(self, p, cell, to_close):
#
# CalledProcessError: Command 'b'import { pipeline } from \'@xenova/transformers\';\n\nasync function run() {\n    // \xd8\xaa\xd8\xad\xd9\x85\xd9\x8a\xd9\x84 \xd8\xa7\xd9\x84\xd9\x86\xd9\x85\xd9\x88\xd8\xb0\xd8\xac\n    const pipe = await pipeline(\'text-generation\', \'onnx-community/Qwen2.5-0.5B-Instruct-ONNX-MHA\');\n\n    // \xd8\xa5\xd8\xaf\xd8\xae\xd8\xa7\xd9\x84 \xd8\xa7\xd9\x84\xd9\x86\xd8\xb5\n    const prompt = "Write a short story about a robot who learns to love:";\n\n    // \xd8\xaa\xd9\x88\xd9\x84\xd9\x8a\xd8\xaf \xd8\xa7\xd9\x84\xd9\x86\xd8\xb5\n    const generatedText = await pipe(prompt, { max_new_tokens: 100 });\n\n    // \xd8\xb7\xd8\xa8\xd8\xa7\xd8\xb9\xd8\xa9 \xd8\xa7\xd9\x84\xd9\x86\xd8\xb5 \xd8\xa7\xd9\x84\xd9\x86\xd8\xa7\xd8\xaa\xd8\xac\n    console.log(generatedText[0].generated_text);\n}\n\n// \xd8\xaa\xd8\xb4\xd8\xba\xd9\x8a\xd9\x84 \xd8\xa7\xd9\x84\xd8\xaf\xd8\xa7\xd9\x84\xd8\xa9\nrun();\n'' returned non-zero exit status 1.

# %%
# %%script node
# const { pipeline } = require('@xenova/transformers');
#
# async function run() {
#     // تحميل النموذج
#     const pipe = await pipeline('text-generation', 'onnx-community/Qwen2.5-0.5B-Instruct-ONNX-MHA');
#
#     // إدخال النص
#     const prompt = "Write a short story about a robot who learns to love:";
#
#     // توليد النص
#     const generatedText = await pipe(prompt, { max_new_tokens: 100 });
#
#     // طباعة النص الناتج
#     console.log(generatedText[0].generated_text);
# }
#
# // تشغيل الدالة
# run();
# Out:
# node:internal/modules/cjs/loader:1419
#       throw err;
#       ^
#
# Error [ERR_REQUIRE_ESM]: require() of ES Module /content/node_modules/@xenova/transformers/src/transformers.js from /content/[stdin] not supported.
# Instead change the require of transformers.js in /content/[stdin] to a dynamic import() which is available in all CommonJS modules.
#     at [stdin]:1:22
#     at [stdin]-wrapper:6:24
#     at Socket.emit (node:events:529:35) {
#   code: 'ERR_REQUIRE_ESM'
# }
#
# Node.js v18.20.5
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-23-e13b5ce6f88b> in <cell line: 0>()
# ----> 1 get_ipython().run_cell_magic('script', 'node', 'const { pipeline } = require(\'@xenova/transformers\');\n\nasync function run() {\n    // تحميل النموذج\n    const pipe = await pipeline(\'text-generation\', \'onnx-community/Qwen2.5-0.5B-Instruct-ONNX-MHA\');\n\n    // إدخال النص\n    const prompt = "Write a short story about a robot who learns to love:";\n\n    // توليد النص\n    const generatedText = await pipe(prompt, { max_new_tokens: 100 });\n\n    // طباعة النص الناتج\n    console.log(generatedText[0].generated_text);\n}\n\n// تشغيل الدالة\nrun();\n')
#
# /usr/local/lib/python3.11/dist-packages/google/colab/_shell.py in run_cell_magic(self, magic_name, line, cell)
#     332     if line and not cell:
#     333       cell = ' '
# --> 334     return super().run_cell_magic(magic_name, line, cell)
#     335
#     336
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2471             with self.builtin_trap:
#    2472                 args = (magic_arg_s, cell)
# -> 2473                 result = fn(*args, **kwargs)
#    2474             return result
#    2475
#
# <decorator-gen-103> in shebang(self, line, cell)
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/magics/script.py in shebang(self, line, cell)
#     243             sys.stderr.flush()
#     244         if args.raise_error and p.returncode!=0:
# --> 245             raise CalledProcessError(p.returncode, cell, output=out, stderr=err)
#     246
#     247     def _run_script(self, p, cell, to_close):
#
# CalledProcessError: Command 'b'const { pipeline } = require(\'@xenova/transformers\');\n\nasync function run() {\n    // \xd8\xaa\xd8\xad\xd9\x85\xd9\x8a\xd9\x84 \xd8\xa7\xd9\x84\xd9\x86\xd9\x85\xd9\x88\xd8\xb0\xd8\xac\n    const pipe = await pipeline(\'text-generation\', \'onnx-community/Qwen2.5-0.5B-Instruct-ONNX-MHA\');\n\n    // \xd8\xa5\xd8\xaf\xd8\xae\xd8\xa7\xd9\x84 \xd8\xa7\xd9\x84\xd9\x86\xd8\xb5\n    const prompt = "Write a short story about a robot who learns to love:";\n\n    // \xd8\xaa\xd9\x88\xd9\x84\xd9\x8a\xd8\xaf \xd8\xa7\xd9\x84\xd9\x86\xd8\xb5\n    const generatedText = await pipe(prompt, { max_new_tokens: 100 });\n\n    // \xd8\xb7\xd8\xa8\xd8\xa7\xd8\xb9\xd8\xa9 \xd8\xa7\xd9\x84\xd9\x86\xd8\xb5 \xd8\xa7\xd9\x84\xd9\x86\xd8\xa7\xd8\xaa\xd8\xac\n    console.log(generatedText[0].generated_text);\n}\n\n// \xd8\xaa\xd8\xb4\xd8\xba\xd9\x8a\xd9\x84 \xd8\xa7\xd9\x84\xd8\xaf\xd8\xa7\xd9\x84\xd8\xa9\nrun();\n'' returned non-zero exit status 1.

# %% [markdown]
# شغال

# %%
# %%script node
#     const fs = require('fs');
#     fs.writeFileSync('my_file.txt', 'Hello from Node.js!');

# %%
# %%script node
#
# module.exports = { items: [5, 6, 7, 8] }

# %%
# !npm install @xenova/transformers

# %%
# %%script node
#    const { pipeline } = require('@xenova/transformers');
#
#    async function run() {
#        // تحميل النموذج
#        const pipe = await pipeline('text-generation', '/path/to/local/model'); // Replace with your local path
#
#        // إدخال النص
#        const prompt = "Write a short story about a robot who learns to love:";
#
#        // توليد النص
#        const generatedText = await pipe(prompt, { max_new_tokens: 100 });
#
#        // طباعة النص الناتج
#        console.log(generatedText[0].generated_text);
#    }
#
#    // تشغيل الدالة
#    run();
# Out:
# node:internal/modules/cjs/loader:1419
#       throw err;
#       ^
#
# Error [ERR_REQUIRE_ESM]: require() of ES Module /content/node_modules/@xenova/transformers/src/transformers.js from /content/[stdin] not supported.
# Instead change the require of transformers.js in /content/[stdin] to a dynamic import() which is available in all CommonJS modules.
#     at [stdin]:1:25
#     at [stdin]-wrapper:6:24
#     at Socket.emit (node:events:529:35) {
#   code: 'ERR_REQUIRE_ESM'
# }
#
# Node.js v18.20.5
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-26-9c081ca925a0> in <cell line: 0>()
# ----> 1 get_ipython().run_cell_magic('script', 'node', '   const { pipeline } = require(\'@xenova/transformers\');\n   \n   async function run() {\n       // تحميل النموذج\n       const pipe = await pipeline(\'text-generation\', \'/path/to/local/model\'); // Replace with your local path\n   \n       // إدخال النص\n       const prompt = "Write a short story about a robot who learns to love:";\n   \n       // توليد النص\n       const generatedText = await pipe(prompt, { max_new_tokens: 100 });\n   \n       // طباعة النص الناتج\n       console.log(generatedText[0].generated_text);\n   }\n   \n   // تشغيل الدالة\n   run();\n')
#
# /usr/local/lib/python3.11/dist-packages/google/colab/_shell.py in run_cell_magic(self, magic_name, line, cell)
#     332     if line and not cell:
#     333       cell = ' '
# --> 334     return super().run_cell_magic(magic_name, line, cell)
#     335
#     336
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2471             with self.builtin_trap:
#    2472                 args = (magic_arg_s, cell)
# -> 2473                 result = fn(*args, **kwargs)
#    2474             return result
#    2475
#
# <decorator-gen-103> in shebang(self, line, cell)
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/magics/script.py in shebang(self, line, cell)
#     243             sys.stderr.flush()
#     244         if args.raise_error and p.returncode!=0:
# --> 245             raise CalledProcessError(p.returncode, cell, output=out, stderr=err)
#     246
#     247     def _run_script(self, p, cell, to_close):
#
# CalledProcessError: Command 'b'   const { pipeline } = require(\'@xenova/transformers\');\n   \n   async function run() {\n       // \xd8\xaa\xd8\xad\xd9\x85\xd9\x8a\xd9\x84 \xd8\xa7\xd9\x84\xd9\x86\xd9\x85\xd9\x88\xd8\xb0\xd8\xac\n       const pipe = await pipeline(\'text-generation\', \'/path/to/local/model\'); // Replace with your local path\n   \n       // \xd8\xa5\xd8\xaf\xd8\xae\xd8\xa7\xd9\x84 \xd8\xa7\xd9\x84\xd9\x86\xd8\xb5\n       const prompt = "Write a short story about a robot who learns to love:";\n   \n       // \xd8\xaa\xd9\x88\xd9\x84\xd9\x8a\xd8\xaf \xd8\xa7\xd9\x84\xd9\x86\xd8\xb5\n       const generatedText = await pipe(prompt, { max_new_tokens: 100 });\n   \n       // \xd8\xb7\xd8\xa8\xd8\xa7\xd8\xb9\xd8\xa9 \xd8\xa7\xd9\x84\xd9\x86\xd8\xb5 \xd8\xa7\xd9\x84\xd9\x86\xd8\xa7\xd8\xaa\xd8\xac\n       console.log(generatedText[0].generated_text);\n   }\n   \n   // \xd8\xaa\xd8\xb4\xd8\xba\xd9\x8a\xd9\x84 \xd8\xa7\xd9\x84\xd8\xaf\xd8\xa7\xd9\x84\xd8\xa9\n   run();\n'' returned non-zero exit status 1.

# %%
# !node script.mjs
# Out:
# file:///content/script.mjs:1
# code = """
#          ^
#
# SyntaxError: Invalid or unexpected token
#     at ModuleLoader.moduleStrategy (node:internal/modules/esm/translators:152:18)
#     at ModuleLoader.moduleProvider (node:internal/modules/esm/loader:299:14)
#     at async link (node:internal/modules/esm/module_job:67:21)
#
# Node.js v18.20.5

# %%
# %%script node
# import { pipeline } from '@xenova/transformers'; // Importing pipeline
#
# async function run() {
#     // تحميل النموذج
#     const pipe = await pipeline('text-generation', '/path/to/local/model'); // Replace with your local path
#
#     // إدخال النص
#     const prompt = "Write a short story about a robot who learns to love:";
#
#     // توليد النص
#     const generatedText = await pipe(prompt, { max_new_tokens: 100 });
#
#     // طباعة النص الناتج
#     console.log(generatedText[0].generated_text);
# }
#
# // تشغيل الدالة
# run();
# Out:
# [stdin]:1
# import { pipeline } from '@xenova/transformers'; // Importing pipeline
# ^^^^^^
#
# SyntaxError: Cannot use import statement outside a module
#     at makeContextifyScript (node:internal/vm:122:14)
#     at node:internal/process/execution:89:22
#     at [stdin]-wrapper:6:24
#     at runScript (node:internal/process/execution:83:62)
#     at evalScript (node:internal/process/execution:114:10)
#     at node:internal/main/eval_stdin:32:5
#     at Socket.<anonymous> (node:internal/process/execution:215:5)
#     at Socket.emit (node:events:529:35)
#     at endReadableNT (node:internal/streams/readable:1400:12)
#     at process.processTicksAndRejections (node:internal/process/task_queues:82:21)
#
# Node.js v18.20.5
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-28-f944dd899cc8> in <cell line: 0>()
# ----> 1 get_ipython().run_cell_magic('script', 'node', 'import { pipeline } from \'@xenova/transformers\'; // Importing pipeline\n\nasync function run() {\n    // تحميل النموذج\n    const pipe = await pipeline(\'text-generation\', \'/path/to/local/model\'); // Replace with your local path\n\n    // إدخال النص\n    const prompt = "Write a short story about a robot who learns to love:";\n\n    // توليد النص\n    const generatedText = await pipe(prompt, { max_new_tokens: 100 });\n\n    // طباعة النص الناتج\n    console.log(generatedText[0].generated_text);\n}\n\n// تشغيل الدالة\nrun();\n')
#
# /usr/local/lib/python3.11/dist-packages/google/colab/_shell.py in run_cell_magic(self, magic_name, line, cell)
#     332     if line and not cell:
#     333       cell = ' '
# --> 334     return super().run_cell_magic(magic_name, line, cell)
#     335
#     336
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2471             with self.builtin_trap:
#    2472                 args = (magic_arg_s, cell)
# -> 2473                 result = fn(*args, **kwargs)
#    2474             return result
#    2475
#
# <decorator-gen-103> in shebang(self, line, cell)
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/magics/script.py in shebang(self, line, cell)
#     243             sys.stderr.flush()
#     244         if args.raise_error and p.returncode!=0:
# --> 245             raise CalledProcessError(p.returncode, cell, output=out, stderr=err)
#     246
#     247     def _run_script(self, p, cell, to_close):
#
# CalledProcessError: Command 'b'import { pipeline } from \'@xenova/transformers\'; // Importing pipeline\n\nasync function run() {\n    // \xd8\xaa\xd8\xad\xd9\x85\xd9\x8a\xd9\x84 \xd8\xa7\xd9\x84\xd9\x86\xd9\x85\xd9\x88\xd8\xb0\xd8\xac\n    const pipe = await pipeline(\'text-generation\', \'/path/to/local/model\'); // Replace with your local path\n\n    // \xd8\xa5\xd8\xaf\xd8\xae\xd8\xa7\xd9\x84 \xd8\xa7\xd9\x84\xd9\x86\xd8\xb5\n    const prompt = "Write a short story about a robot who learns to love:";\n\n    // \xd8\xaa\xd9\x88\xd9\x84\xd9\x8a\xd8\xaf \xd8\xa7\xd9\x84\xd9\x86\xd8\xb5\n    const generatedText = await pipe(prompt, { max_new_tokens: 100 });\n\n    // \xd8\xb7\xd8\xa8\xd8\xa7\xd8\xb9\xd8\xa9 \xd8\xa7\xd9\x84\xd9\x86\xd8\xb5 \xd8\xa7\xd9\x84\xd9\x86\xd8\xa7\xd8\xaa\xd8\xac\n    console.log(generatedText[0].generated_text);\n}\n\n// \xd8\xaa\xd8\xb4\xd8\xba\xd9\x8a\xd9\x84 \xd8\xa7\xd9\x84\xd8\xaf\xd8\xa7\xd9\x84\xd8\xa9\nrun();\n'' returned non-zero exit status 1.

# %%
# %%script node
# import { pipeline } from '@xenova/transformers';
#
# async function run() {
#     // ... (rest of your code)
# }
#
# run();
# Out:
# [stdin]:1
# import { pipeline } from '@xenova/transformers';
# ^^^^^^
#
# SyntaxError: Cannot use import statement outside a module
#     at makeContextifyScript (node:internal/vm:122:14)
#     at node:internal/process/execution:89:22
#     at [stdin]-wrapper:6:24
#     at runScript (node:internal/process/execution:83:62)
#     at evalScript (node:internal/process/execution:114:10)
#     at node:internal/main/eval_stdin:32:5
#     at Socket.<anonymous> (node:internal/process/execution:215:5)
#     at Socket.emit (node:events:529:35)
#     at endReadableNT (node:internal/streams/readable:1400:12)
#     at process.processTicksAndRejections (node:internal/process/task_queues:82:21)
#
# Node.js v18.20.5
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-29-c49e286b0eb7> in <cell line: 0>()
# ----> 1 get_ipython().run_cell_magic('script', 'node', "import { pipeline } from '@xenova/transformers';\n\nasync function run() {\n    // ... (rest of your code)\n}\n\nrun();\n")
#
# /usr/local/lib/python3.11/dist-packages/google/colab/_shell.py in run_cell_magic(self, magic_name, line, cell)
#     332     if line and not cell:
#     333       cell = ' '
# --> 334     return super().run_cell_magic(magic_name, line, cell)
#     335
#     336
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2471             with self.builtin_trap:
#    2472                 args = (magic_arg_s, cell)
# -> 2473                 result = fn(*args, **kwargs)
#    2474             return result
#    2475
#
# <decorator-gen-103> in shebang(self, line, cell)
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/magics/script.py in shebang(self, line, cell)
#     243             sys.stderr.flush()
#     244         if args.raise_error and p.returncode!=0:
# --> 245             raise CalledProcessError(p.returncode, cell, output=out, stderr=err)
#     246
#     247     def _run_script(self, p, cell, to_close):
#
# CalledProcessError: Command 'b"import { pipeline } from '@xenova/transformers';\n\nasync function run() {\n    // ... (rest of your code)\n}\n\nrun();\n"' returned non-zero exit status 1.

# %%
# %%script node
# import { pipeline } from '@xenova/transformers'; // Importing pipeline
#
# async function run() {
#     // تحميل النموذج
#     const pipe = await pipeline('text-generation', '/path/to/local/model'); // Replace with your local path
#
#     // إدخال النص
#     const prompt = "Write a short story about a robot who learns to love:";
#
#     // توليد النص
#     const generatedText = await pipe(prompt, { max_new_tokens: 100 });
#
#     // طباعة النص الناتج
#     console.log(generatedText[0].generated_text);
# }
#
# // تشغيل الدالة
# run();
# Out:
# [stdin]:1
# import { pipeline } from '@xenova/transformers'; // Importing pipeline
# ^^^^^^
#
# SyntaxError: Cannot use import statement outside a module
#     at makeContextifyScript (node:internal/vm:122:14)
#     at node:internal/process/execution:89:22
#     at [stdin]-wrapper:6:24
#     at runScript (node:internal/process/execution:83:62)
#     at evalScript (node:internal/process/execution:114:10)
#     at node:internal/main/eval_stdin:32:5
#     at Socket.<anonymous> (node:internal/process/execution:215:5)
#     at Socket.emit (node:events:529:35)
#     at endReadableNT (node:internal/streams/readable:1400:12)
#     at process.processTicksAndRejections (node:internal/process/task_queues:82:21)
#
# Node.js v18.20.5
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-30-f944dd899cc8> in <cell line: 0>()
# ----> 1 get_ipython().run_cell_magic('script', 'node', 'import { pipeline } from \'@xenova/transformers\'; // Importing pipeline\n\nasync function run() {\n    // تحميل النموذج\n    const pipe = await pipeline(\'text-generation\', \'/path/to/local/model\'); // Replace with your local path\n\n    // إدخال النص\n    const prompt = "Write a short story about a robot who learns to love:";\n\n    // توليد النص\n    const generatedText = await pipe(prompt, { max_new_tokens: 100 });\n\n    // طباعة النص الناتج\n    console.log(generatedText[0].generated_text);\n}\n\n// تشغيل الدالة\nrun();\n')
#
# /usr/local/lib/python3.11/dist-packages/google/colab/_shell.py in run_cell_magic(self, magic_name, line, cell)
#     332     if line and not cell:
#     333       cell = ' '
# --> 334     return super().run_cell_magic(magic_name, line, cell)
#     335
#     336
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2471             with self.builtin_trap:
#    2472                 args = (magic_arg_s, cell)
# -> 2473                 result = fn(*args, **kwargs)
#    2474             return result
#    2475
#
# <decorator-gen-103> in shebang(self, line, cell)
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/magics/script.py in shebang(self, line, cell)
#     243             sys.stderr.flush()
#     244         if args.raise_error and p.returncode!=0:
# --> 245             raise CalledProcessError(p.returncode, cell, output=out, stderr=err)
#     246
#     247     def _run_script(self, p, cell, to_close):
#
# CalledProcessError: Command 'b'import { pipeline } from \'@xenova/transformers\'; // Importing pipeline\n\nasync function run() {\n    // \xd8\xaa\xd8\xad\xd9\x85\xd9\x8a\xd9\x84 \xd8\xa7\xd9\x84\xd9\x86\xd9\x85\xd9\x88\xd8\xb0\xd8\xac\n    const pipe = await pipeline(\'text-generation\', \'/path/to/local/model\'); // Replace with your local path\n\n    // \xd8\xa5\xd8\xaf\xd8\xae\xd8\xa7\xd9\x84 \xd8\xa7\xd9\x84\xd9\x86\xd8\xb5\n    const prompt = "Write a short story about a robot who learns to love:";\n\n    // \xd8\xaa\xd9\x88\xd9\x84\xd9\x8a\xd8\xaf \xd8\xa7\xd9\x84\xd9\x86\xd8\xb5\n    const generatedText = await pipe(prompt, { max_new_tokens: 100 });\n\n    // \xd8\xb7\xd8\xa8\xd8\xa7\xd8\xb9\xd8\xa9 \xd8\xa7\xd9\x84\xd9\x86\xd8\xb5 \xd8\xa7\xd9\x84\xd9\x86\xd8\xa7\xd8\xaa\xd8\xac\n    console.log(generatedText[0].generated_text);\n}\n\n// \xd8\xaa\xd8\xb4\xd8\xba\xd9\x8a\xd9\x84 \xd8\xa7\xd9\x84\xd8\xaf\xd8\xa7\xd9\x84\xd8\xa9\nrun();\n'' returned non-zero exit status 1.

# %%
# %%script node
# import { pipeline } from '@xenova/transformers';
#
# // Allocate a pipeline for sentiment-analysis
# let pipe = await pipeline('sentiment-analysis');
#
# let out = await pipe('I love transformers!');
# Out:
# [stdin]:1
# import { pipeline } from '@xenova/transformers';
# ^^^^^^
#
# SyntaxError: Cannot use import statement outside a module
#     at makeContextifyScript (node:internal/vm:122:14)
#     at node:internal/process/execution:89:22
#     at [stdin]-wrapper:6:24
#     at runScript (node:internal/process/execution:83:62)
#     at evalScript (node:internal/process/execution:114:10)
#     at node:internal/main/eval_stdin:32:5
#     at Socket.<anonymous> (node:internal/process/execution:215:5)
#     at Socket.emit (node:events:529:35)
#     at endReadableNT (node:internal/streams/readable:1400:12)
#     at process.processTicksAndRejections (node:internal/process/task_queues:82:21)
#
# Node.js v18.20.5
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-31-b8fc24834ef7> in <cell line: 0>()
# ----> 1 get_ipython().run_cell_magic('script', 'node', "import { pipeline } from '@xenova/transformers';\n\n// Allocate a pipeline for sentiment-analysis\nlet pipe = await pipeline('sentiment-analysis');\n\nlet out = await pipe('I love transformers!');\n")
#
# /usr/local/lib/python3.11/dist-packages/google/colab/_shell.py in run_cell_magic(self, magic_name, line, cell)
#     332     if line and not cell:
#     333       cell = ' '
# --> 334     return super().run_cell_magic(magic_name, line, cell)
#     335
#     336
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2471             with self.builtin_trap:
#    2472                 args = (magic_arg_s, cell)
# -> 2473                 result = fn(*args, **kwargs)
#    2474             return result
#    2475
#
# <decorator-gen-103> in shebang(self, line, cell)
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/magics/script.py in shebang(self, line, cell)
#     243             sys.stderr.flush()
#     244         if args.raise_error and p.returncode!=0:
# --> 245             raise CalledProcessError(p.returncode, cell, output=out, stderr=err)
#     246
#     247     def _run_script(self, p, cell, to_close):
#
# CalledProcessError: Command 'b"import { pipeline } from '@xenova/transformers';\n\n// Allocate a pipeline for sentiment-analysis\nlet pipe = await pipeline('sentiment-analysis');\n\nlet out = await pipe('I love transformers!');\n"' returned non-zero exit status 1.

# %%
# !node q.js
# Out:
# [ { label: '5 stars', score: 0.872728705406189 } ]

# %%
# %%script node
#
# import { pipeline } from '@xenova/transformers';
#
# // Allocate a pipeline for sentiment-analysis
# let pipe = await pipeline('sentiment-analysis', 'Xenova/bert-base-multilingual-uncased-sentiment');
# let out = await pipe('I love transformers!');
# console.log(out);
# Out:
# [stdin]:2
# import { pipeline } from '@xenova/transformers';
# ^^^^^^
#
# SyntaxError: Cannot use import statement outside a module
#     at makeContextifyScript (node:internal/vm:122:14)
#     at node:internal/process/execution:89:22
#     at [stdin]-wrapper:6:24
#     at runScript (node:internal/process/execution:83:62)
#     at evalScript (node:internal/process/execution:114:10)
#     at node:internal/main/eval_stdin:32:5
#     at Socket.<anonymous> (node:internal/process/execution:215:5)
#     at Socket.emit (node:events:529:35)
#     at endReadableNT (node:internal/streams/readable:1400:12)
#     at process.processTicksAndRejections (node:internal/process/task_queues:82:21)
#
# Node.js v18.20.5
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-35-422d5549df32> in <cell line: 0>()
# ----> 1 get_ipython().run_cell_magic('script', 'node', "\nimport { pipeline } from '@xenova/transformers';\n\n// Allocate a pipeline for sentiment-analysis\nlet pipe = await pipeline('sentiment-analysis', 'Xenova/bert-base-multilingual-uncased-sentiment');\nlet out = await pipe('I love transformers!');\nconsole.log(out);\n")
#
# /usr/local/lib/python3.11/dist-packages/google/colab/_shell.py in run_cell_magic(self, magic_name, line, cell)
#     332     if line and not cell:
#     333       cell = ' '
# --> 334     return super().run_cell_magic(magic_name, line, cell)
#     335
#     336
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2471             with self.builtin_trap:
#    2472                 args = (magic_arg_s, cell)
# -> 2473                 result = fn(*args, **kwargs)
#    2474             return result
#    2475
#
# <decorator-gen-103> in shebang(self, line, cell)
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/magics/script.py in shebang(self, line, cell)
#     243             sys.stderr.flush()
#     244         if args.raise_error and p.returncode!=0:
# --> 245             raise CalledProcessError(p.returncode, cell, output=out, stderr=err)
#     246
#     247     def _run_script(self, p, cell, to_close):
#
# CalledProcessError: Command 'b"\nimport { pipeline } from '@xenova/transformers';\n\n// Allocate a pipeline for sentiment-analysis\nlet pipe = await pipeline('sentiment-analysis', 'Xenova/bert-base-multilingual-uncased-sentiment');\nlet out = await pipe('I love transformers!');\nconsole.log(out);\n"' returned non-zero exit status 1.

# %%
# %%script node
#
# import { pipeline } from '@xenova/transformers';
#
# // Allocate a pipeline for sentiment-analysis
# const pipe = await pipeline('sentiment-analysis', 'Xenova/bert-base-multilingual-uncased-sentiment');
# const out = await pipe('I love transformers!');
# console.log(out);
# Out:
# [stdin]:2
# import { pipeline } from '@xenova/transformers';
# ^^^^^^
#
# SyntaxError: Cannot use import statement outside a module
#     at makeContextifyScript (node:internal/vm:122:14)
#     at node:internal/process/execution:89:22
#     at [stdin]-wrapper:6:24
#     at runScript (node:internal/process/execution:83:62)
#     at evalScript (node:internal/process/execution:114:10)
#     at node:internal/main/eval_stdin:32:5
#     at Socket.<anonymous> (node:internal/process/execution:215:5)
#     at Socket.emit (node:events:529:35)
#     at endReadableNT (node:internal/streams/readable:1400:12)
#     at process.processTicksAndRejections (node:internal/process/task_queues:82:21)
#
# Node.js v18.20.5
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-39-90aae1bba0cc> in <cell line: 0>()
# ----> 1 get_ipython().run_cell_magic('script', 'node', "\nimport { pipeline } from '@xenova/transformers';\n\n// Allocate a pipeline for sentiment-analysis\nconst pipe = await pipeline('sentiment-analysis', 'Xenova/bert-base-multilingual-uncased-sentiment');\nconst out = await pipe('I love transformers!');\nconsole.log(out);\n")
#
# /usr/local/lib/python3.11/dist-packages/google/colab/_shell.py in run_cell_magic(self, magic_name, line, cell)
#     332     if line and not cell:
#     333       cell = ' '
# --> 334     return super().run_cell_magic(magic_name, line, cell)
#     335
#     336
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2471             with self.builtin_trap:
#    2472                 args = (magic_arg_s, cell)
# -> 2473                 result = fn(*args, **kwargs)
#    2474             return result
#    2475
#
# <decorator-gen-103> in shebang(self, line, cell)
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/magics/script.py in shebang(self, line, cell)
#     243             sys.stderr.flush()
#     244         if args.raise_error and p.returncode!=0:
# --> 245             raise CalledProcessError(p.returncode, cell, output=out, stderr=err)
#     246
#     247     def _run_script(self, p, cell, to_close):
#
# CalledProcessError: Command 'b"\nimport { pipeline } from '@xenova/transformers';\n\n// Allocate a pipeline for sentiment-analysis\nconst pipe = await pipeline('sentiment-analysis', 'Xenova/bert-base-multilingual-uncased-sentiment');\nconst out = await pipe('I love transformers!');\nconsole.log(out);\n"' returned non-zero exit status 1.

# %%
# %%script node
# console.log("أهلًا من Node.js!");
# Out:
# أهلًا من Node.js!

# %%
# %%script node
# console.log("أهلًا من Node.js!");
# Out:
# [stdin]:4
# import { pipeline } from '@xenova/transformers';
# ^^^^^^
#
# SyntaxError: Cannot use import statement outside a module
#     at makeContextifyScript (node:internal/vm:122:14)
#     at node:internal/process/execution:89:22
#     at [stdin]-wrapper:6:24
#     at runScript (node:internal/process/execution:83:62)
#     at evalScript (node:internal/process/execution:114:10)
#     at node:internal/main/eval_stdin:32:5
#     at Socket.<anonymous> (node:internal/process/execution:215:5)
#     at Socket.emit (node:events:529:35)
#     at endReadableNT (node:internal/streams/readable:1400:12)
#     at process.processTicksAndRejections (node:internal/process/task_queues:82:21)
#
# Node.js v18.20.5
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-38-2977b421d6df> in <cell line: 0>()
# ----> 1 get_ipython().run_cell_magic('script', 'node', "\n\n\nimport { pipeline } from '@xenova/transformers';\n\n// Allocate a pipeline for sentiment-analysis\nconst pipe = await pipeline('sentiment-analysis', 'Xenova/bert-base-multilingual-uncased-sentiment');\nconst out = await pipe('I love transformers!');\nconsole.log(out);\n")
#
# /usr/local/lib/python3.11/dist-packages/google/colab/_shell.py in run_cell_magic(self, magic_name, line, cell)
#     332     if line and not cell:
#     333       cell = ' '
# --> 334     return super().run_cell_magic(magic_name, line, cell)
#     335
#     336
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2471             with self.builtin_trap:
#    2472                 args = (magic_arg_s, cell)
# -> 2473                 result = fn(*args, **kwargs)
#    2474             return result
#    2475
#
# <decorator-gen-103> in shebang(self, line, cell)
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/magics/script.py in shebang(self, line, cell)
#     243             sys.stderr.flush()
#     244         if args.raise_error and p.returncode!=0:
# --> 245             raise CalledProcessError(p.returncode, cell, output=out, stderr=err)
#     246
#     247     def _run_script(self, p, cell, to_close):
#
# CalledProcessError: Command 'b"\n\n\nimport { pipeline } from '@xenova/transformers';\n\n// Allocate a pipeline for sentiment-analysis\nconst pipe = await pipeline('sentiment-analysis', 'Xenova/bert-base-multilingual-uncased-sentiment');\nconst out = await pipe('I love transformers!');\nconsole.log(out);\n"' returned non-zero exit status 1.

# %%
# %%script node
# console.log("أهلًا من Node.js!");

# %%
# %%script node
# !npm install @xenova/transformers
#
# import { pipeline } from '@xenova/transformers';
#
# // Allocate a pipeline for sentiment-analysis
# const pipe = await pipeline('sentiment-analysis', 'Xenova/bert-base-multilingual-uncased-sentiment');
# const out = await pipe('I love transformers!');
# console.log(out);
# Out:
# [stdin]:1
# !npm install @xenova/transformers
#      ^^^^^^^
#
# SyntaxError: Unexpected identifier
#     at makeContextifyScript (node:internal/vm:122:14)
#     at node:internal/process/execution:89:22
#     at [stdin]-wrapper:6:24
#     at runScript (node:internal/process/execution:83:62)
#     at evalScript (node:internal/process/execution:114:10)
#     at node:internal/main/eval_stdin:32:5
#     at Socket.<anonymous> (node:internal/process/execution:215:5)
#     at Socket.emit (node:events:529:35)
#     at endReadableNT (node:internal/streams/readable:1400:12)
#     at process.processTicksAndRejections (node:internal/process/task_queues:82:21)
#
# Node.js v18.20.5
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-40-8956916acbbb> in <cell line: 0>()
# ----> 1 get_ipython().run_cell_magic('script', 'node', "!npm install @xenova/transformers\n\nimport { pipeline } from '@xenova/transformers';\n\n// Allocate a pipeline for sentiment-analysis\nconst pipe = await pipeline('sentiment-analysis', 'Xenova/bert-base-multilingual-uncased-sentiment');\nconst out = await pipe('I love transformers!');\nconsole.log(out);\n")
#
# /usr/local/lib/python3.11/dist-packages/google/colab/_shell.py in run_cell_magic(self, magic_name, line, cell)
#     332     if line and not cell:
#     333       cell = ' '
# --> 334     return super().run_cell_magic(magic_name, line, cell)
#     335
#     336
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2471             with self.builtin_trap:
#    2472                 args = (magic_arg_s, cell)
# -> 2473                 result = fn(*args, **kwargs)
#    2474             return result
#    2475
#
# <decorator-gen-103> in shebang(self, line, cell)
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/magics/script.py in shebang(self, line, cell)
#     243             sys.stderr.flush()
#     244         if args.raise_error and p.returncode!=0:
# --> 245             raise CalledProcessError(p.returncode, cell, output=out, stderr=err)
#     246
#     247     def _run_script(self, p, cell, to_close):
#
# CalledProcessError: Command 'b"!npm install @xenova/transformers\n\nimport { pipeline } from '@xenova/transformers';\n\n// Allocate a pipeline for sentiment-analysis\nconst pipe = await pipeline('sentiment-analysis', 'Xenova/bert-base-multilingual-uncased-sentiment');\nconst out = await pipe('I love transformers!');\nconsole.log(out);\n"' returned non-zero exit status 1.

# %%
# !npm install @xenova/transformers
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦
# up to date, audited 147 packages in 3s
# ⠧
# ⠧31 packages are looking for funding
# ⠧  run `npm fund` for details
# ⠧
# found 0 vulnerabilities
# ⠧

# %%
# %%script node
#
# import { pipeline } from '@xenova/transformers';
# Out:
# [stdin]:2
# import { pipeline } from '@xenova/transformers';
# ^^^^^^
#
# SyntaxError: Cannot use import statement outside a module
#     at makeContextifyScript (node:internal/vm:122:14)
#     at node:internal/process/execution:89:22
#     at [stdin]-wrapper:6:24
#     at runScript (node:internal/process/execution:83:62)
#     at evalScript (node:internal/process/execution:114:10)
#     at node:internal/main/eval_stdin:32:5
#     at Socket.<anonymous> (node:internal/process/execution:215:5)
#     at Socket.emit (node:events:529:35)
#     at endReadableNT (node:internal/streams/readable:1400:12)
#     at process.processTicksAndRejections (node:internal/process/task_queues:82:21)
#
# Node.js v18.20.5
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-45-9bb31824aa33> in <cell line: 0>()
# ----> 1 get_ipython().run_cell_magic('script', 'node', "\nimport { pipeline } from '@xenova/transformers';\n\n")
#
# /usr/local/lib/python3.11/dist-packages/google/colab/_shell.py in run_cell_magic(self, magic_name, line, cell)
#     332     if line and not cell:
#     333       cell = ' '
# --> 334     return super().run_cell_magic(magic_name, line, cell)
#     335
#     336
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2471             with self.builtin_trap:
#    2472                 args = (magic_arg_s, cell)
# -> 2473                 result = fn(*args, **kwargs)
#    2474             return result
#    2475
#
# <decorator-gen-103> in shebang(self, line, cell)
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/magics/script.py in shebang(self, line, cell)
#     243             sys.stderr.flush()
#     244         if args.raise_error and p.returncode!=0:
# --> 245             raise CalledProcessError(p.returncode, cell, output=out, stderr=err)
#     246
#     247     def _run_script(self, p, cell, to_close):
#
# CalledProcessError: Command 'b"\nimport { pipeline } from '@xenova/transformers';\n\n"' returned non-zero exit status 1.

# %%
# %%script node
# const pipeline = require('@xenova/transformers').pipeline;
#
# // ... بقية الكود الخاص بك
# Out:
# node:internal/modules/cjs/loader:1419
#       throw err;
#       ^
#
# Error [ERR_REQUIRE_ESM]: require() of ES Module /content/node_modules/@xenova/transformers/src/transformers.js from /content/[stdin] not supported.
# Instead change the require of transformers.js in /content/[stdin] to a dynamic import() which is available in all CommonJS modules.
#     at [stdin]:1:18
#     at [stdin]-wrapper:6:24
#     at Socket.emit (node:events:529:35) {
#   code: 'ERR_REQUIRE_ESM'
# }
#
# Node.js v18.20.5
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-47-ac1cfc3457e5> in <cell line: 0>()
# ----> 1 get_ipython().run_cell_magic('script', 'node', "const pipeline = require('@xenova/transformers').pipeline;\n\n// ... بقية الكود الخاص بك\n")
#
# /usr/local/lib/python3.11/dist-packages/google/colab/_shell.py in run_cell_magic(self, magic_name, line, cell)
#     332     if line and not cell:
#     333       cell = ' '
# --> 334     return super().run_cell_magic(magic_name, line, cell)
#     335
#     336
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2471             with self.builtin_trap:
#    2472                 args = (magic_arg_s, cell)
# -> 2473                 result = fn(*args, **kwargs)
#    2474             return result
#    2475
#
# <decorator-gen-103> in shebang(self, line, cell)
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/magics/script.py in shebang(self, line, cell)
#     243             sys.stderr.flush()
#     244         if args.raise_error and p.returncode!=0:
# --> 245             raise CalledProcessError(p.returncode, cell, output=out, stderr=err)
#     246
#     247     def _run_script(self, p, cell, to_close):
#
# CalledProcessError: Command 'b"const pipeline = require('@xenova/transformers').pipeline;\n\n// ... \xd8\xa8\xd9\x82\xd9\x8a\xd8\xa9 \xd8\xa7\xd9\x84\xd9\x83\xd9\x88\xd8\xaf \xd8\xa7\xd9\x84\xd8\xae\xd8\xa7\xd8\xb5 \xd8\xa8\xd9\x83\n"' returned non-zero exit status 1.

# %%
# %%script node
# <script src="https://cdn.jsdelivr.net/npm/@xenova/transformers"></script>
#
# <script>
#   // استخدم xenova.transformers هنا
# </script>
# Out:
# [stdin]:1
# <script src="https://cdn.jsdelivr.net/npm/@xenova/transformers"></script>
# ^
#
# SyntaxError: Unexpected token '<'
#     at makeContextifyScript (node:internal/vm:122:14)
#     at node:internal/process/execution:89:22
#     at [stdin]-wrapper:6:24
#     at runScript (node:internal/process/execution:83:62)
#     at evalScript (node:internal/process/execution:114:10)
#     at node:internal/main/eval_stdin:32:5
#     at Socket.<anonymous> (node:internal/process/execution:215:5)
#     at Socket.emit (node:events:529:35)
#     at endReadableNT (node:internal/streams/readable:1400:12)
#     at process.processTicksAndRejections (node:internal/process/task_queues:82:21)
#
# Node.js v18.20.5
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-46-71b2029cb658> in <cell line: 0>()
# ----> 1 get_ipython().run_cell_magic('script', 'node', '<script src="https://cdn.jsdelivr.net/npm/@xenova/transformers"></script>\n\n<script>\n  // استخدم xenova.transformers هنا\n</script>\n')
#
# /usr/local/lib/python3.11/dist-packages/google/colab/_shell.py in run_cell_magic(self, magic_name, line, cell)
#     332     if line and not cell:
#     333       cell = ' '
# --> 334     return super().run_cell_magic(magic_name, line, cell)
#     335
#     336
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2471             with self.builtin_trap:
#    2472                 args = (magic_arg_s, cell)
# -> 2473                 result = fn(*args, **kwargs)
#    2474             return result
#    2475
#
# <decorator-gen-103> in shebang(self, line, cell)
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/magics/script.py in shebang(self, line, cell)
#     243             sys.stderr.flush()
#     244         if args.raise_error and p.returncode!=0:
# --> 245             raise CalledProcessError(p.returncode, cell, output=out, stderr=err)
#     246
#     247     def _run_script(self, p, cell, to_close):
#
# CalledProcessError: Command 'b'<script src="https://cdn.jsdelivr.net/npm/@xenova/transformers"></script>\n\n<script>\n  // \xd8\xa7\xd8\xb3\xd8\xaa\xd8\xae\xd8\xaf\xd9\x85 xenova.transformers \xd9\x87\xd9\x86\xd8\xa7\n</script>\n'' returned non-zero exit status 1.

# %%
code = """import { pipeline } from '@xenova/transformers';

async function run() {
    console.log("🚀 بدء تشغيل النموذج...");

    // تحميل النموذج
    const pipe = await pipeline('text-generation', 'Xenova/Qwen2.5-0.5B-Instruct');

    // إدخال النص
    const prompt = "Write a short story about a robot who learns to love:";

    // توليد النص
    const generatedText = await pipe(prompt, { max_new_tokens: 100 });

    // طباعة النص الناتج
    console.log("✅ النص الناتج:");
    console.log(generatedText[0].generated_text);
}

// تشغيل الدالة
run();
"""

with open("script.mjs", "w") as f:
    f.write(code)

print("📄 تم إنشاء الملف script.mjs بنجاح.")
# Out:
# 📄 تم إنشاء الملف script.mjs بنجاح.

# %%
# !node script.mjs
# Out:
# 🚀 بدء تشغيل النموذج...
# file:///content/node_modules/@xenova/transformers/src/utils/hub.js:238
#     throw Error(`${message}: "${remoteURL}".`);
#           ^
#
# Error: Unauthorized access to file: "https://huggingface.co/Xenova/Qwen2.5-0.5B-Instruct/resolve/main/config.json".
#     at handleError (file:///content/node_modules/@xenova/transformers/src/utils/hub.js:238:11)
#     at getModelFile (file:///content/node_modules/@xenova/transformers/src/utils/hub.js:471:24)
#     at process.processTicksAndRejections (node:internal/process/task_queues:95:5)
#     at async getModelJSON (file:///content/node_modules/@xenova/transformers/src/utils/hub.js:572:18)
#     at async loadConfig (file:///content/node_modules/@xenova/transformers/src/configs.js:46:16)
#     at async PretrainedConfig.from_pretrained (file:///content/node_modules/@xenova/transformers/src/configs.js:85:30)
#     at async AutoModelForCausalLM.from_pretrained (file:///content/node_modules/@xenova/transformers/src/models.js:5504:18)
#     at async Promise.all (index 1)
#     at async loadItems (file:///content/node_modules/@xenova/transformers/src/pipelines.js:3279:5)
#     at async pipeline (file:///content/node_modules/@xenova/transformers/src/pipelines.js:3219:21)
#
# Node.js v18.20.5

# %%
import { pipeline } from '@xenova/transformers';

async function run() {
    console.log("🚀 بدء تشغيل النموذج...");

    // تحميل نموذج عام من Hugging Face
    const pipe = await pipeline('text-generation', 'Xenova/distilbert-base-uncased');

    // إدخال النص
    const prompt = "What is the capital of France?";

    // توليد النص
    const generatedText = await pipe(prompt, { max_new_tokens: 50 });

    // طباعة النص الناتج
    console.log("✅ النص الناتج:");
    console.log(generatedText[0].generated_text);
}

// تشغيل الدالة
run();

# %%
code = """import { pipeline } from '@xenova/transformers';

async function run() {
    console.log("🚀 بدء تشغيل النموذج...");

    // تحميل النموذج
    const pipe = await pipeline('text-generation', 'Xenova/gpt2');

    // إدخال النص
    const prompt = "Write a short story about a robot who learns to love:";

    // توليد النص
    const generatedText = await pipe(prompt, { max_new_tokens: 100 });

    // طباعة النص الناتج
    console.log("✅ النص الناتج:");
    console.log(generatedText[0].generated_text);
}

// تشغيل الدالة
run();
"""

with open("script.mjs", "w") as f:
    f.write(code)

print("📄 تم إنشاء الملف script.mjs بنجاح.")
# Out:
# 📄 تم إنشاء الملف script.mjs بنجاح.

# %%
# !node script.mjs
# Out:
# 🚀 بدء تشغيل النموذج...
# 2025-02-11 23:31:14.949533564 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.11/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:14.949703626 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.0/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:14.949759956 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.4/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:14.949960397 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.10/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:14.950009666 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.8/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:14.950181463 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.2/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:14.950208184 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.3/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:14.950283382 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.6/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:14.950331126 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.7/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:14.950419940 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.9/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:14.950467341 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.5/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:14.950513300 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.1/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:14.953309815 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.11/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:14.953416562 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.9/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:14.953495444 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.4/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:14.953683407 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.8/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:14.953712706 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.0/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:14.953770752 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.10/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:14.953890617 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.3/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:14.953971393 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.6/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:14.954037521 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.7/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:14.954086071 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.2/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:14.954186337 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.5/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:14.954203438 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.1/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.163970110 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.11/attn/Constant_37_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.164020283 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_3414'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.164030453 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_3412'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.164037369 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.11/attn/Constant_36_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.164044060 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.11/attn/Constant_35_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.164064799 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.11/attn/Constant_12_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.164072931 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.11/attn/Constant_11_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.164080053 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_3341'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.164093457 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.11/attn/Constant_8_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.164103833 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.11/attn/Constant_7_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.164111270 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_3324'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.164119380 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.11/attn/Constant_6_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.164127542 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.11/attn/Constant_5_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.164135768 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.11/attn/Constant_4_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.164144247 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.11/attn/Constant_3_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.164152823 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_3305'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.164166105 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_3307'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.164194683 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.3/attn/Constant_11_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.164210530 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1113'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.164220030 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_565'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.164230597 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.4/attn/Constant_10_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.164250085 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.3/attn/Constant_4_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.164262636 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1496'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.164273711 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.9/attn/Constant_11_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.164294840 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_397'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.164313358 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.6/attn/Constant_35_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.164324452 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.4/attn/Constant_12_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.164337588 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.1/attn/Constant_8_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.164348302 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.9/attn/Constant_3_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.164360353 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1406'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.164372838 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.4/attn/Constant_6_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.164385856 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1389'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.164396778 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.4/attn/Constant_3_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.164408196 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.3/attn/Constant_12_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.164422798 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_2502'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.164433628 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.3/attn/Constant_3_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.164444348 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.0/attn/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.164461090 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_2759'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.164486665 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.0/attn/Constant_6_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.164502895 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.11/attn/Constant_10_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.164515725 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.7/attn/Constant_37_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.164530328 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.4/attn/Constant_35_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.164541421 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1680'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.164557425 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.3/attn/Constant_35_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.164572290 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.10/attn/Constant_36_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.164586374 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.2/attn/Constant_8_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.164596900 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1661'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.164608010 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.1/attn/Constant_10_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.164619830 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1387'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.164633597 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.4/attn/Constant_5_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.164651083 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.5/attn/Constant_4_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.164662415 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.1/attn/Constant_35_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.164693402 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.3/attn/Constant_9_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.164705408 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.3/attn/Constant_7_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.164716490 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1130'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.164730371 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.3/attn/Constant_6_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.164741873 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.3/attn/Constant_1_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.164764440 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1697'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.164775457 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.5/attn/Constant_11_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.164791718 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.9/attn/Constant_4_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.164823719 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.5/attn/Constant_6_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.164838816 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.4/attn/Constant_1_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.164850267 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.1/attn/Constant_9_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.164862006 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1971'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.164872744 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_2517'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.164887885 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_2245'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.164898769 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_948'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.164910804 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.3/attn/Constant_36_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.164922690 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.10/attn/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.164937970 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.11/attn/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.164949579 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.4/attn/Constant_11_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.164962059 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_3322'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.164977560 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.0/attn/Constant_1_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.165002511 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.5/attn/Constant_9_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.165016037 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.8/attn/Constant_7_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.165031624 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.5/attn/Constant_10_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.165045393 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_2864'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.165062860 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.8/attn/Constant_8_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.165074756 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.0/attn/Constant_37_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.165087841 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.0/attn/Constant_3_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.165099742 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_2044'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.165116071 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/Constant_1_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.250293343 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_674'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.250325814 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_2243'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.250356672 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.9/attn/Constant_8_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.250371740 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1663'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.250382968 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_601'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.250441809 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_324'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.250460515 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.6/attn/Constant_10_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.250493868 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1220'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.250505590 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.0/attn/Constant_9_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.250526212 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_873'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.250543866 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.1/attn/Constant_12_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.250564615 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.10/attn/Constant_4_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.250578413 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1149'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.250593602 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.0/attn/Constant_7_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.250617367 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_305'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.250629408 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_3065'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.250646701 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.3/attn/Constant_5_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.250668405 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.2/attn/Constant_7_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.252029829 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.2/attn/Constant_36_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.252060798 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_2519'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.252076307 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1132'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.252099984 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.3/attn/Constant_37_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.252118206 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1404'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.252127253 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.4/attn/Constant_37_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.252139505 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.2/attn/Constant_10_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.252150944 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.5/attn/Constant_5_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.252157196 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.4/attn/Constant_9_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.252169618 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1147'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.252176489 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_290'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.252184336 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1768'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.252190237 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.4/attn/Constant_36_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.252198747 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1937'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.252216833 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.2/attn/Constant_35_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.252223846 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1115'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.252233308 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1969'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.252245047 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.8/attn/Constant_5_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.252252166 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.2/attn/Constant_3_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.252260297 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_839'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.252273587 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_2866'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.252280628 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.0/attn/Constant_12_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.252291729 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.1/attn/Constant_1_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.252301267 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.0/attn/Constant_35_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.252311275 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.9/attn/Constant_6_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.252329181 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1678'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.252335552 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.3/attn/Constant_10_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.252346366 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.8/attn/Constant_36_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.252354277 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_2316'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.252365678 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.9/attn/Constant_10_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.252372414 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.0/attn/Constant_8_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.252384988 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.0/attn/Constant_4_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.252392853 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_288'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.252401300 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_2042'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.252411855 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.1/attn/Constant_3_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.252419268 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.7/attn/Constant_5_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.254909009 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.0/attn/Constant_5_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.254931364 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_2228'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.254948372 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.5/attn/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.254960837 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.4/attn/Constant_8_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.254974495 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.0/attn/Constant_11_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.254996599 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.4/attn/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.255014907 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1770'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.255027196 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.6/attn/Constant_3_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.255049387 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.1/attn/Constant_5_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.255061650 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.9/attn/Constant_12_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.255074851 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_180'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.255089555 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.1/attn/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.255102060 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.9/attn/Constant_1_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.255117360 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_567'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.255130400 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.1/attn/Constant_4_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.255154152 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.1/attn/Constant_6_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.255167148 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.8/attn/Constant_11_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.255181251 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_582'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.255192892 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.5/attn/Constant_3_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.255206129 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_584'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.255238195 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_599'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.255253503 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.1/attn/Constant_11_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.255280766 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1421'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.255293717 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.4/attn/Constant_7_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.255304857 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_399'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.255326850 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.0/attn/Constant_10_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.255339726 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_307'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.255351431 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.6/attn/Constant_4_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.255369585 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_672'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.255383812 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.1/attn/Constant_36_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.255396443 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_841'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.255409093 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.5/attn/Constant_1_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.255421847 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_2211'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.255452309 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_2483'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.255464552 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1494'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.255479275 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.8/attn/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.255507503 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.2/attn/Constant_12_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.255521169 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_3050'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.255537575 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.9/attn/Constant_36_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.255549132 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_875'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.255558604 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.2/attn/Constant_5_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.255570169 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.10/attn/Constant_6_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.255587895 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.5/attn/Constant_7_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.255603176 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.2/attn/Constant_11_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.255617270 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.2/attn/Constant_1_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.255630103 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.2/attn/Constant_4_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.255642048 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.6/attn/Constant_7_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.255653878 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.2/attn/Constant_6_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.255667349 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_856'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.255680160 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.9/attn/Constant_7_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.255691187 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_858'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.255707172 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.2/attn/Constant_9_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.255718818 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_946'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.255735592 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.9/attn/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.255746908 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.5/attn/Constant_8_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:15.255759204 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1695'. It is not used by any node and should be removed from the model.
# ...
# 2025-02-11 23:31:16.550444067 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.9/mlp/act/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:16.550486380 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.8/mlp/act/Constant_1_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:16.550497873 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.8/mlp/act/Constant_3_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:16.550525759 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.5/mlp/act/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:16.550539210 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.9/mlp/act/Constant_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:16.550573781 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.10/mlp/act/Constant_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:16.550584476 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.10/mlp/act/Constant_1_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:16.550594624 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.10/mlp/act/Constant_4_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:16.552594598 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.11/mlp/act/Constant_3_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:16.552621404 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.11/mlp/act/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:16.552630122 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.11/mlp/act/Constant_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:16.552669122 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.9/mlp/act/Constant_1_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:16.552686874 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.3/mlp/act/Constant_4_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:16.552705532 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.4/mlp/act/Constant_4_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:16.552724615 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.0/mlp/act/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:16.552755703 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.3/mlp/act/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:16.552777913 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.4/mlp/act/Constant_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:16.552831621 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.7/mlp/act/Constant_3_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:16.552859960 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.2/mlp/act/Constant_4_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:16.552872728 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.2/mlp/act/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:16.552883686 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.2/mlp/act/Constant_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:16.552899661 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.3/mlp/act/Constant_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:16.552915904 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.2/mlp/act/Constant_1_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:16.552932755 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.3/mlp/act/Constant_1_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:16.552972611 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.5/mlp/act/Constant_3_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:16.552985848 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.0/mlp/act/Constant_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:16.552997820 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.11/mlp/act/Constant_1_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:16.553009645 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.11/mlp/act/Constant_4_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:16.569408720 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.0/mlp/act/Constant_4_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:16.569506083 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.4/mlp/act/Constant_3_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:16.569622466 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.10/mlp/act/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:16.569644978 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.2/mlp/act/Constant_3_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:16.569686132 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.8/mlp/act/Constant_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:16.569720153 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.0/mlp/act/Constant_3_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:16.569732745 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.6/mlp/act/Constant_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:16.569760060 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.1/mlp/act/Constant_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:16.569812020 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.1/mlp/act/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:16.569829891 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.1/mlp/act/Constant_3_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:16.569852802 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.1/mlp/act/Constant_4_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:16.569873107 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.1/mlp/act/Constant_1_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:16.569930912 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.5/mlp/act/Constant_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:16.569945859 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.5/mlp/act/Constant_1_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:16.569956826 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.5/mlp/act/Constant_4_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:16.569979751 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.8/mlp/act/Constant_4_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:16.569996580 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.5/mlp/act/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:16.570009272 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.8/mlp/act/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:16.570033826 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.3/mlp/act/Constant_3_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:16.570049860 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.6/mlp/act/Constant_1_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:16.570073844 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.10/mlp/act/Constant_3_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:16.570087857 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.6/mlp/act/Constant_3_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:16.570103550 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.6/mlp/act/Constant_4_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:16.570139623 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.6/mlp/act/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:16.570152741 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.4/mlp/act/Constant_1_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:16.570200917 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.7/mlp/act/Constant_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:16.570214627 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.7/mlp/act/Constant_1_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:16.570226570 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.7/mlp/act/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:16.570237956 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.7/mlp/act/Constant_4_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:16.570252756 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.9/mlp/act/Constant_4_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:16.570269713 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.9/mlp/act/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:16.570285793 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.9/mlp/act/Constant_3_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:16.570332755 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.8/mlp/act/Constant_1_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:16.570347683 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.8/mlp/act/Constant_3_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:16.570370957 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.0/mlp/act/Constant_1_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:16.570385147 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.4/mlp/act/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:16.570417682 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.9/mlp/act/Constant_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:16.570462686 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.10/mlp/act/Constant_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:16.570491759 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.10/mlp/act/Constant_1_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:31:16.570504000 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.10/mlp/act/Constant_4_output_0'. It is not used by any node and should be removed from the model.
# ✅ النص الناتج:
# Write a short story about a robot who learns to love:
#
# http://www.youtube.com/watch?v=jqkqXkXkXmQ
#
# http://www.youtube.com/watch?v=jqkqXkXkXmQ
#
# http://www.youtube.com/watch?v=jqkqXkXkXmQ
#
# http://www.youtube.com/watch?v=jqkqXkXkXmQ

# %%
# %%script node
#
# import { pipeline } from '@xenova/transformers';
#
# async function run() {
#     console.log("🚀 بدء تشغيل النموذج...");
#
#     // تحميل نموذج مناسب لتوليد النصوص
#     const pipe = await pipeline('text-generation', 'Xenova/gpt2');
#
#     // إدخال النص
#     const prompt = "Once upon a time,";
#
#     // توليد النص
#     const generatedText = await pipe(prompt, { max_new_tokens: 50 });
#
#     // طباعة النص الناتج
#     console.log("✅ النص الناتج:");
#     console.log(generatedText[0].generated_text);
# }
#
# // تشغيل الدالة
# run();
# Out:
# [stdin]:2
# import { pipeline } from '@xenova/transformers';
# ^^^^^^
#
# SyntaxError: Cannot use import statement outside a module
#     at makeContextifyScript (node:internal/vm:122:14)
#     at node:internal/process/execution:89:22
#     at [stdin]-wrapper:6:24
#     at runScript (node:internal/process/execution:83:62)
#     at evalScript (node:internal/process/execution:114:10)
#     at node:internal/main/eval_stdin:32:5
#     at Socket.<anonymous> (node:internal/process/execution:215:5)
#     at Socket.emit (node:events:529:35)
#     at endReadableNT (node:internal/streams/readable:1400:12)
#     at process.processTicksAndRejections (node:internal/process/task_queues:82:21)
#
# Node.js v18.20.5
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-54-32a1c852fd93> in <cell line: 0>()
# ----> 1 get_ipython().run_cell_magic('script', 'node', '\nimport { pipeline } from \'@xenova/transformers\';\n\nasync function run() {\n    console.log("🚀 بدء تشغيل النموذج...");\n\n    // تحميل نموذج مناسب لتوليد النصوص\n    const pipe = await pipeline(\'text-generation\', \'Xenova/gpt2\');\n\n    // إدخال النص\n    const prompt = "Once upon a time,";\n\n    // توليد النص\n    const generatedText = await pipe(prompt, { max_new_tokens: 50 });\n\n    // طباعة النص الناتج\n    console.log("✅ النص الناتج:");\n    console.log(generatedText[0].generated_text);\n}\n\n// تشغيل الدالة\nrun();\n')
#
# /usr/local/lib/python3.11/dist-packages/google/colab/_shell.py in run_cell_magic(self, magic_name, line, cell)
#     332     if line and not cell:
#     333       cell = ' '
# --> 334     return super().run_cell_magic(magic_name, line, cell)
#     335
#     336
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2471             with self.builtin_trap:
#    2472                 args = (magic_arg_s, cell)
# -> 2473                 result = fn(*args, **kwargs)
#    2474             return result
#    2475
#
# <decorator-gen-103> in shebang(self, line, cell)
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/magics/script.py in shebang(self, line, cell)
#     243             sys.stderr.flush()
#     244         if args.raise_error and p.returncode!=0:
# --> 245             raise CalledProcessError(p.returncode, cell, output=out, stderr=err)
#     246
#     247     def _run_script(self, p, cell, to_close):
#
# CalledProcessError: Command 'b'\nimport { pipeline } from \'@xenova/transformers\';\n\nasync function run() {\n    console.log("\xf0\x9f\x9a\x80 \xd8\xa8\xd8\xaf\xd8\xa1 \xd8\xaa\xd8\xb4\xd8\xba\xd9\x8a\xd9\x84 \xd8\xa7\xd9\x84\xd9\x86\xd9\x85\xd9\x88\xd8\xb0\xd8\xac...");\n\n    // \xd8\xaa\xd8\xad\xd9\x85\xd9\x8a\xd9\x84 \xd9\x86\xd9\x85\xd9\x88\xd8\xb0\xd8\xac \xd9\x85\xd9\x86\xd8\xa7\xd8\xb3\xd8\xa8 \xd9\x84\xd8\xaa\xd9\x88\xd9\x84\xd9\x8a\xd8\xaf \xd8\xa7\xd9\x84\xd9\x86\xd8\xb5\xd9\x88\xd8\xb5\n    const pipe = await pipeline(\'text-generation\', \'Xenova/gpt2\');\n\n    // \xd8\xa5\xd8\xaf\xd8\xae\xd8\xa7\xd9\x84 \xd8\xa7\xd9\x84\xd9\x86\xd8\xb5\n    const prompt = "Once upon a time,";\n\n    // \xd8\xaa\xd9\x88\xd9\x84\xd9\x8a\xd8\xaf \xd8\xa7\xd9\x84\xd9\x86\xd8\xb5\n    const generatedText = await pipe(prompt, { max_new_tokens: 50 });\n\n    // \xd8\xb7\xd8\xa8\xd8\xa7\xd8\xb9\xd8\xa9 \xd8\xa7\xd9\x84\xd9\x86\xd8\xb5 \xd8\xa7\xd9\x84\xd9\x86\xd8\xa7\xd8\xaa\xd8\xac\n    console.log("\xe2\x9c\x85 \xd8\xa7\xd9\x84\xd9\x86\xd8\xb5 \xd8\xa7\xd9\x84\xd9\x86\xd8\xa7\xd8\xaa\xd8\xac:");\n    console.log(generatedText[0].generated_text);\n}\n\n// \xd8\xaa\xd8\xb4\xd8\xba\xd9\x8a\xd9\x84 \xd8\xa7\xd9\x84\xd8\xaf\xd8\xa7\xd9\x84\xd8\xa9\nrun();\n'' returned non-zero exit status 1.

# %%
# %%script node
#
# const { pipeline } = require('@xenova/transformers');
#
# async function run() {
#     console.log("🚀 بدء تشغيل النموذج...");
#
#     // تحميل نموذج مناسب لتوليد النصوص
#     const pipe = await pipeline('text-generation', 'Xenova/gpt2');
#
#     // إدخال النص
#     const prompt = "Once upon a time,";
#
#     // توليد النص
#     const generatedText = await pipe(prompt, { max_new_tokens: 50 });
#
#     // طباعة النص الناتج
#     console.log("✅ النص الناتج:");
#     console.log(generatedText[0].generated_text);
# }
#
# // تشغيل الدالة
# run();
# Out:
# node:internal/modules/cjs/loader:1419
#       throw err;
#       ^
#
# Error [ERR_REQUIRE_ESM]: require() of ES Module /content/node_modules/@xenova/transformers/src/transformers.js from /content/[stdin] not supported.
# Instead change the require of transformers.js in /content/[stdin] to a dynamic import() which is available in all CommonJS modules.
#     at [stdin]:2:22
#     at [stdin]-wrapper:6:24
#     at Socket.emit (node:events:529:35) {
#   code: 'ERR_REQUIRE_ESM'
# }
#
# Node.js v18.20.5
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-55-61a26348ec27> in <cell line: 0>()
# ----> 1 get_ipython().run_cell_magic('script', 'node', '\nconst { pipeline } = require(\'@xenova/transformers\');\n\nasync function run() {\n    console.log("🚀 بدء تشغيل النموذج...");\n\n    // تحميل نموذج مناسب لتوليد النصوص\n    const pipe = await pipeline(\'text-generation\', \'Xenova/gpt2\');\n\n    // إدخال النص\n    const prompt = "Once upon a time,";\n\n    // توليد النص\n    const generatedText = await pipe(prompt, { max_new_tokens: 50 });\n\n    // طباعة النص الناتج\n    console.log("✅ النص الناتج:");\n    console.log(generatedText[0].generated_text);\n}\n\n// تشغيل الدالة\nrun();\n')
#
# /usr/local/lib/python3.11/dist-packages/google/colab/_shell.py in run_cell_magic(self, magic_name, line, cell)
#     332     if line and not cell:
#     333       cell = ' '
# --> 334     return super().run_cell_magic(magic_name, line, cell)
#     335
#     336
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2471             with self.builtin_trap:
#    2472                 args = (magic_arg_s, cell)
# -> 2473                 result = fn(*args, **kwargs)
#    2474             return result
#    2475
#
# <decorator-gen-103> in shebang(self, line, cell)
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/magics/script.py in shebang(self, line, cell)
#     243             sys.stderr.flush()
#     244         if args.raise_error and p.returncode!=0:
# --> 245             raise CalledProcessError(p.returncode, cell, output=out, stderr=err)
#     246
#     247     def _run_script(self, p, cell, to_close):
#
# CalledProcessError: Command 'b'\nconst { pipeline } = require(\'@xenova/transformers\');\n\nasync function run() {\n    console.log("\xf0\x9f\x9a\x80 \xd8\xa8\xd8\xaf\xd8\xa1 \xd8\xaa\xd8\xb4\xd8\xba\xd9\x8a\xd9\x84 \xd8\xa7\xd9\x84\xd9\x86\xd9\x85\xd9\x88\xd8\xb0\xd8\xac...");\n\n    // \xd8\xaa\xd8\xad\xd9\x85\xd9\x8a\xd9\x84 \xd9\x86\xd9\x85\xd9\x88\xd8\xb0\xd8\xac \xd9\x85\xd9\x86\xd8\xa7\xd8\xb3\xd8\xa8 \xd9\x84\xd8\xaa\xd9\x88\xd9\x84\xd9\x8a\xd8\xaf \xd8\xa7\xd9\x84\xd9\x86\xd8\xb5\xd9\x88\xd8\xb5\n    const pipe = await pipeline(\'text-generation\', \'Xenova/gpt2\');\n\n    // \xd8\xa5\xd8\xaf\xd8\xae\xd8\xa7\xd9\x84 \xd8\xa7\xd9\x84\xd9\x86\xd8\xb5\n    const prompt = "Once upon a time,";\n\n    // \xd8\xaa\xd9\x88\xd9\x84\xd9\x8a\xd8\xaf \xd8\xa7\xd9\x84\xd9\x86\xd8\xb5\n    const generatedText = await pipe(prompt, { max_new_tokens: 50 });\n\n    // \xd8\xb7\xd8\xa8\xd8\xa7\xd8\xb9\xd8\xa9 \xd8\xa7\xd9\x84\xd9\x86\xd8\xb5 \xd8\xa7\xd9\x84\xd9\x86\xd8\xa7\xd8\xaa\xd8\xac\n    console.log("\xe2\x9c\x85 \xd8\xa7\xd9\x84\xd9\x86\xd8\xb5 \xd8\xa7\xd9\x84\xd9\x86\xd8\xa7\xd8\xaa\xd8\xac:");\n    console.log(generatedText[0].generated_text);\n}\n\n// \xd8\xaa\xd8\xb4\xd8\xba\xd9\x8a\xd9\x84 \xd8\xa7\xd9\x84\xd8\xaf\xd8\xa7\xd9\x84\xd8\xa9\nrun();\n'' returned non-zero exit status 1.

# %% [markdown]
# ششششششششششش

# %% [markdown]
# شغال

# %%
# %%script node
#
# (async () => {
#     console.log("🚀 بدء تشغيل النموذج...");
#
#     // استيراد مكتبة @xenova/transformers ديناميكيًا
#     const { pipeline } = await import('@xenova/transformers');
#
#     // تحميل نموذج مناسب لتوليد النصوص
#     const pipe = await pipeline('text-generation', 'Xenova/gpt2');
#
#     // إدخال النص
#     const prompt = "Once upon a time,";
#
#     // توليد النص
#     const generatedText = await pipe(prompt, { max_new_tokens: 50 });
#
#     // طباعة النص الناتج
#     console.log("✅ النص الناتج:");
#     console.log(generatedText[0].generated_text);
# })();
# Out:
# 🚀 بدء تشغيل النموذج...
# ✅ النص الناتج:
# Once upon a time, I was in a room with a woman who was very attractive. She was very attractive. She was very attractive. She was very attractive. She was very attractive. She was very attractive. She was very attractive. She was very attractive. She was
# 2025-02-11 23:33:31.397515928 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.11/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.397608654 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.0/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.397658421 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.4/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.397851222 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.10/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.397900800 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.8/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.398064047 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.2/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.398095809 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.3/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.398170867 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.6/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.398215217 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.7/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.398296369 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.9/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.398341492 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.5/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.398352915 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.1/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.411016922 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.11/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.411225378 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.9/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.411308518 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.4/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.411520199 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.8/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.411544457 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.0/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.411598947 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.10/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.411712784 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.3/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.411846556 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.6/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.411913659 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.7/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.411950293 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.2/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.412047029 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.5/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.412056208 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.1/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.726379717 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.11/attn/Constant_37_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.726425811 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_3414'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.726432514 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_3412'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.726437056 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.11/attn/Constant_36_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.726441422 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.11/attn/Constant_35_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.726455230 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.11/attn/Constant_12_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.726460096 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.11/attn/Constant_11_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.726464616 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_3341'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.726481601 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.11/attn/Constant_8_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.726488567 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.11/attn/Constant_7_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.726493423 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_3324'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.726498174 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.11/attn/Constant_6_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.726502523 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.11/attn/Constant_5_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.726507000 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.11/attn/Constant_4_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.726512100 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.11/attn/Constant_3_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.726526479 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_3305'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.726534628 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_3307'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.726563364 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.3/attn/Constant_11_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.726572718 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1113'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.726580633 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_565'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.726593324 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.4/attn/Constant_10_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.726610275 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.3/attn/Constant_4_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.726620548 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1496'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.726629781 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.9/attn/Constant_11_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.726645706 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_397'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.726661710 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.6/attn/Constant_35_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.726673718 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.4/attn/Constant_12_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.726679497 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.1/attn/Constant_8_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.726691051 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.9/attn/Constant_3_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.726697727 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1406'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.726709587 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.4/attn/Constant_6_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.726720408 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1389'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.726729543 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.4/attn/Constant_3_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.726735912 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.3/attn/Constant_12_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.726745871 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_2502'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.726754356 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.3/attn/Constant_3_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.726760174 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.0/attn/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.726770686 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_2759'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.726791407 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.0/attn/Constant_6_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.726804157 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.11/attn/Constant_10_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.726815539 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.7/attn/Constant_37_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.726827981 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.4/attn/Constant_35_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.726836833 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1680'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.726846011 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.3/attn/Constant_35_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.726855450 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.10/attn/Constant_36_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.726863550 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.2/attn/Constant_8_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.726872401 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1661'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.726878333 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.1/attn/Constant_10_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.726889044 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1387'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.726899804 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.4/attn/Constant_5_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.726915926 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.5/attn/Constant_4_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.726926096 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.1/attn/Constant_35_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.726934497 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.3/attn/Constant_9_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.726943463 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.3/attn/Constant_7_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.726949639 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1130'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.726961407 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.3/attn/Constant_6_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.726970751 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.3/attn/Constant_1_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.726987690 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1697'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.726996398 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.5/attn/Constant_11_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727007853 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.9/attn/Constant_4_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727026396 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.5/attn/Constant_6_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727040449 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.4/attn/Constant_1_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727046362 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.1/attn/Constant_9_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727052257 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1971'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727061510 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_2517'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727072451 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_2245'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727080849 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_948'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727086965 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.3/attn/Constant_36_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727093014 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.10/attn/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727106127 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.11/attn/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727115041 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.4/attn/Constant_11_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727122398 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_3322'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727134932 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.0/attn/Constant_1_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727158625 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.5/attn/Constant_9_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727170154 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.8/attn/Constant_7_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727184134 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.5/attn/Constant_10_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727195549 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_2864'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727205686 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.8/attn/Constant_8_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727215256 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.0/attn/Constant_37_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727223604 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.0/attn/Constant_3_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727232439 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_2044'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727242475 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/Constant_1_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727254292 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_674'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727263071 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_2243'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727271768 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.9/attn/Constant_8_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727281389 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1663'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727290631 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_601'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727303248 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_324'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727312784 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.6/attn/Constant_10_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727323912 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1220'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727332772 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.0/attn/Constant_9_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727343404 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_873'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727354096 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.1/attn/Constant_12_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727366149 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.10/attn/Constant_4_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727376147 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1149'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727387342 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.0/attn/Constant_7_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727397679 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_305'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727406920 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_3065'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727415409 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.3/attn/Constant_5_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727429907 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.2/attn/Constant_7_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727438812 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.2/attn/Constant_36_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727446724 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_2519'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727456822 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1132'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727483079 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.3/attn/Constant_37_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727496342 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1404'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727505603 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.4/attn/Constant_37_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727513470 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.2/attn/Constant_10_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727524083 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.5/attn/Constant_5_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727532911 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.4/attn/Constant_9_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727541270 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1147'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727550157 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_290'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727556249 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1768'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727561713 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.4/attn/Constant_36_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727571882 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1937'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727587804 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.2/attn/Constant_35_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727596431 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1115'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727603306 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1969'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727614299 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.8/attn/Constant_5_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727623374 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.2/attn/Constant_3_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727629668 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_839'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727641339 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_2866'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727650309 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.0/attn/Constant_12_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727657931 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.1/attn/Constant_1_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727668026 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.0/attn/Constant_35_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727677772 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.9/attn/Constant_6_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727692156 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1678'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727701525 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.3/attn/Constant_10_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727708648 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.8/attn/Constant_36_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727717644 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_2316'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727724833 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.9/attn/Constant_10_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727733942 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.0/attn/Constant_8_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727742798 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.0/attn/Constant_4_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727753018 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_288'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727763150 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_2042'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727770204 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.1/attn/Constant_3_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727785613 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.7/attn/Constant_5_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727795374 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.0/attn/Constant_5_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727801098 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_2228'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727812195 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.5/attn/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727821961 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.4/attn/Constant_8_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727827925 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.0/attn/Constant_11_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727838530 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.4/attn/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727850076 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1770'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727859944 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.6/attn/Constant_3_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727874467 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.1/attn/Constant_5_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727883016 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.9/attn/Constant_12_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727889565 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_180'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727901038 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.1/attn/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727910250 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.9/attn/Constant_1_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727917809 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_567'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727928055 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.1/attn/Constant_4_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727940575 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.1/attn/Constant_6_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727950207 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.8/attn/Constant_11_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727961582 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_582'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727971145 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.5/attn/Constant_3_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727982427 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_584'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.727989828 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_599'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.728000846 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.1/attn/Constant_11_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.728018875 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1421'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.728028259 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.4/attn/Constant_7_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.728033955 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_399'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.728044997 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.0/attn/Constant_10_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.728054056 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_307'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.728059919 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.6/attn/Constant_4_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.728072473 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_672'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.728083364 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.1/attn/Constant_36_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.728093483 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_841'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.728100070 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.5/attn/Constant_1_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.728109105 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_2211'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.728125309 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_2483'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.728134727 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1494'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.728143511 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.8/attn/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.728156978 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.2/attn/Constant_12_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.728167120 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_3050'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.728179423 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.9/attn/Constant_36_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.728187748 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_875'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.728193793 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.2/attn/Constant_5_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.728199837 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.10/attn/Constant_6_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.728209749 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.5/attn/Constant_7_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.728221209 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.2/attn/Constant_11_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.728232554 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.2/attn/Constant_1_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.728243024 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.2/attn/Constant_4_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.728249074 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.6/attn/Constant_7_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.728257696 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.2/attn/Constant_6_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.728264385 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_856'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.728274899 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.9/attn/Constant_7_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.728283646 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_858'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.728291869 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.2/attn/Constant_9_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.728300451 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_946'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.728308974 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.9/attn/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:31.728318734 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.5/attn/Constant_8_output_0'. It is not used by any node and should be removed from the model.
# ...
# 2025-02-11 23:33:33.443932741 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.7/mlp/act/Constant_4_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:33.443942114 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.9/mlp/act/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:33.443974316 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.8/mlp/act/Constant_1_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:33.443985806 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.8/mlp/act/Constant_3_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:33.444010919 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.5/mlp/act/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:33.444023060 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.9/mlp/act/Constant_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:33.444056689 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.10/mlp/act/Constant_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:33.444067412 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.10/mlp/act/Constant_1_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:33.444073432 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.10/mlp/act/Constant_4_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:33.446353532 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.11/mlp/act/Constant_3_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:33.446387529 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.11/mlp/act/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:33.446393013 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.11/mlp/act/Constant_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:33.446424246 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.9/mlp/act/Constant_1_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:33.446434488 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.3/mlp/act/Constant_4_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:33.446453088 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.4/mlp/act/Constant_4_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:33.446482096 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.0/mlp/act/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:33.446514050 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.3/mlp/act/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:33.446531719 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.4/mlp/act/Constant_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:33.446570628 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.7/mlp/act/Constant_3_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:33.446599162 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.2/mlp/act/Constant_4_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:33.446610771 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.2/mlp/act/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:33.446621251 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.2/mlp/act/Constant_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:33.446631966 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.3/mlp/act/Constant_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:33.446646486 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.2/mlp/act/Constant_1_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:33.446662232 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.3/mlp/act/Constant_1_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:33.446704119 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.5/mlp/act/Constant_3_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:33.446715902 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.0/mlp/act/Constant_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:33.446722598 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.11/mlp/act/Constant_1_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:33.446732933 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.11/mlp/act/Constant_4_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:33.446744453 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.0/mlp/act/Constant_4_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:33.446772109 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.4/mlp/act/Constant_3_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:33.446841904 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.10/mlp/act/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:33.446856365 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.2/mlp/act/Constant_3_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:33.446883508 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.8/mlp/act/Constant_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:33.446905448 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.0/mlp/act/Constant_3_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:33.446915996 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.6/mlp/act/Constant_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:33.446932728 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.1/mlp/act/Constant_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:33.446970396 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.1/mlp/act/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:33.446983425 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.1/mlp/act/Constant_3_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:33.447000463 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.1/mlp/act/Constant_4_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:33.447014815 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.1/mlp/act/Constant_1_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:33.447056074 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.5/mlp/act/Constant_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:33.447066745 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.5/mlp/act/Constant_1_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:33.447072633 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.5/mlp/act/Constant_4_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:33.447089604 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.8/mlp/act/Constant_4_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:33.447103831 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.5/mlp/act/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:33.447114337 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.8/mlp/act/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:33.447133595 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.3/mlp/act/Constant_3_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:33.447146186 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.6/mlp/act/Constant_1_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:33.447157457 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.10/mlp/act/Constant_3_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:33.447166974 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.6/mlp/act/Constant_3_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:33.447173976 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.6/mlp/act/Constant_4_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:33.447195812 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.6/mlp/act/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:33.447206377 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.4/mlp/act/Constant_1_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:33.447236109 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.7/mlp/act/Constant_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:33.447246984 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.7/mlp/act/Constant_1_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:33.447253254 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.7/mlp/act/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:33.447263267 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.7/mlp/act/Constant_4_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:33.447270665 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.9/mlp/act/Constant_4_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:33.447283162 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.9/mlp/act/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:33.447295717 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.9/mlp/act/Constant_3_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:33.447327608 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.8/mlp/act/Constant_1_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:33.447339337 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.8/mlp/act/Constant_3_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:33.447352267 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.0/mlp/act/Constant_1_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:33.447364186 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.4/mlp/act/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:33.447389571 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.9/mlp/act/Constant_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:33.447422183 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.10/mlp/act/Constant_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:33.447432816 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.10/mlp/act/Constant_1_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:33:33.447438429 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.10/mlp/act/Constant_4_output_0'. It is not used by any node and should be removed from the model.

# %%
# %%script node
#
# (async () => {
#     console.log("🚀 بدء تشغيل النموذج...");
#
#     // استيراد مكتبة @xenova/transformers ديناميكيًا
#     const { pipeline } = await import('@xenova/transformers');
#
#     // تحميل نموذج مناسب لتوليد النصوص
#     const pipe = await pipeline('text-generation', 'onnx-community/Qwen2.5-0.5B-Instruct-ONNX-MHA');
#
#     // إدخال النص
#     const prompt = "Once upon a time,";
#
#     // توليد النص
#     const generatedText = await pipe(prompt, { max_new_tokens: 50 });
#
#     // طباعة النص الناتج
#     console.log("✅ النص الناتج:");
#     console.log(generatedText[0].generated_text);
# })();
# Out:
# 🚀 بدء تشغيل النموذج...
# file:///content/node_modules/@xenova/transformers/src/utils/hub.js:238
#     throw Error(`${message}: "${remoteURL}".`);
#           ^
#
# Error: Could not locate file: "https://huggingface.co/onnx-community/Qwen2.5-0.5B-Instruct-ONNX-MHA/resolve/main/onnx/decoder_model_merged_quantized.onnx".
#     at handleError (file:///content/node_modules/@xenova/transformers/src/utils/hub.js:238:11)
#     at getModelFile (file:///content/node_modules/@xenova/transformers/src/utils/hub.js:471:24)
#     at process.processTicksAndRejections (node:internal/process/task_queues:95:5)
#     at async constructSession (file:///content/node_modules/@xenova/transformers/src/models.js:123:18)
#     at async Promise.all (index 1)
#     at async Qwen2ForCausalLM.from_pretrained (file:///content/node_modules/@xenova/transformers/src/models.js:761:20)
#     at async AutoModelForCausalLM.from_pretrained (file:///content/node_modules/@xenova/transformers/src/models.js:5519:20)
#     at async Promise.all (index 1)
#     at async loadItems (file:///content/node_modules/@xenova/transformers/src/pipelines.js:3279:5)
#     at async pipeline (file:///content/node_modules/@xenova/transformers/src/pipelines.js:3219:21)
#
# Node.js v18.20.5
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-57-81c061071a9b> in <cell line: 0>()
# ----> 1 get_ipython().run_cell_magic('script', 'node', '\n(async () => {\n    console.log("🚀 بدء تشغيل النموذج...");\n\n    // استيراد مكتبة @xenova/transformers ديناميكيًا\n    const { pipeline } = await import(\'@xenova/transformers\');\n\n    // تحميل نموذج مناسب لتوليد النصوص\n    const pipe = await pipeline(\'text-generation\', \'onnx-community/Qwen2.5-0.5B-Instruct-ONNX-MHA\');\n\n    // إدخال النص\n    const prompt = "Once upon a time,";\n\n    // توليد النص\n    const generatedText = await pipe(prompt, { max_new_tokens: 50 });\n\n    // طباعة النص الناتج\n    console.log("✅ النص الناتج:");\n    console.log(generatedText[0].generated_text);\n})();\n')
#
# /usr/local/lib/python3.11/dist-packages/google/colab/_shell.py in run_cell_magic(self, magic_name, line, cell)
#     332     if line and not cell:
#     333       cell = ' '
# --> 334     return super().run_cell_magic(magic_name, line, cell)
#     335
#     336
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2471             with self.builtin_trap:
#    2472                 args = (magic_arg_s, cell)
# -> 2473                 result = fn(*args, **kwargs)
#    2474             return result
#    2475
#
# <decorator-gen-103> in shebang(self, line, cell)
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/magics/script.py in shebang(self, line, cell)
#     243             sys.stderr.flush()
#     244         if args.raise_error and p.returncode!=0:
# --> 245             raise CalledProcessError(p.returncode, cell, output=out, stderr=err)
#     246
#     247     def _run_script(self, p, cell, to_close):
#
# CalledProcessError: Command 'b'\n(async () => {\n    console.log("\xf0\x9f\x9a\x80 \xd8\xa8\xd8\xaf\xd8\xa1 \xd8\xaa\xd8\xb4\xd8\xba\xd9\x8a\xd9\x84 \xd8\xa7\xd9\x84\xd9\x86\xd9\x85\xd9\x88\xd8\xb0\xd8\xac...");\n\n    // \xd8\xa7\xd8\xb3\xd8\xaa\xd9\x8a\xd8\xb1\xd8\xa7\xd8\xaf \xd9\x85\xd9\x83\xd8\xaa\xd8\xa8\xd8\xa9 @xenova/transformers \xd8\xaf\xd9\x8a\xd9\x86\xd8\xa7\xd9\x85\xd9\x8a\xd9\x83\xd9\x8a\xd9\x8b\xd8\xa7\n    const { pipeline } = await import(\'@xenova/transformers\');\n\n    // \xd8\xaa\xd8\xad\xd9\x85\xd9\x8a\xd9\x84 \xd9\x86\xd9\x85\xd9\x88\xd8\xb0\xd8\xac \xd9\x85\xd9\x86\xd8\xa7\xd8\xb3\xd8\xa8 \xd9\x84\xd8\xaa\xd9\x88\xd9\x84\xd9\x8a\xd8\xaf \xd8\xa7\xd9\x84\xd9\x86\xd8\xb5\xd9\x88\xd8\xb5\n    const pipe = await pipeline(\'text-generation\', \'onnx-community/Qwen2.5-0.5B-Instruct-ONNX-MHA\');\n\n    // \xd8\xa5\xd8\xaf\xd8\xae\xd8\xa7\xd9\x84 \xd8\xa7\xd9\x84\xd9\x86\xd8\xb5\n    const prompt = "Once upon a time,";\n\n    // \xd8\xaa\xd9\x88\xd9\x84\xd9\x8a\xd8\xaf \xd8\xa7\xd9\x84\xd9\x86\xd8\xb5\n    const generatedText = await pipe(prompt, { max_new_tokens: 50 });\n\n    // \xd8\xb7\xd8\xa8\xd8\xa7\xd8\xb9\xd8\xa9 \xd8\xa7\xd9\x84\xd9\x86\xd8\xb5 \xd8\xa7\xd9\x84\xd9\x86\xd8\xa7\xd8\xaa\xd8\xac\n    console.log("\xe2\x9c\x85 \xd8\xa7\xd9\x84\xd9\x86\xd8\xb5 \xd8\xa7\xd9\x84\xd9\x86\xd8\xa7\xd8\xaa\xd8\xac:");\n    console.log(generatedText[0].generated_text);\n})();\n'' returned non-zero exit status 1.

# %%
# %%script node
#
# (async () => {
#     console.log("🚀 بدء تشغيل النموذج...");
#
#     // استيراد مكتبة @xenova/transformers ديناميكيًا
#     const { pipeline } = await import('@xenova/transformers');
#
#     console.log("⏳ تحميل النموذج...");
#     const pipe = await pipeline('text-generation', 'Xenova/gpt2');
#
#     console.log("✍️ إدخال النص...");
#     const prompt = "Once upon a time,";
#
#     console.log("⚡ توليد النص...");
#     const generatedText = await pipe(prompt, { max_new_tokens: 50 });
#
#     console.log("✅ النص الناتج:");
#     console.log(generatedText[0].generated_text);
#
#     // تأخير بسيط لضمان طباعة المخرجات قبل انتهاء السكريبت
#     await new Promise(resolve => setTimeout(resolve, 5000));
# })();
# Out:
# 🚀 بدء تشغيل النموذج...
# ⏳ تحميل النموذج...
# ✍️ إدخال النص...
# ⚡ توليد النص...
# ✅ النص الناتج:
# Once upon a time, I was in a room with a woman who was very attractive. She was very attractive. She was very attractive. She was very attractive. She was very attractive. She was very attractive. She was very attractive. She was very attractive. She was
# 2025-02-11 23:36:27.005784426 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.11/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.005952790 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.0/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.006031770 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.4/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.006258162 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.10/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.007075430 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.8/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.007336955 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.2/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.007385929 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.3/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.007529273 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.6/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.007599384 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.7/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.007702835 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.9/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.009744120 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.5/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.009801788 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.1/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.013761766 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.11/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.019735943 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.9/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.019894269 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.4/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.020133520 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.8/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.020175211 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.0/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.020243468 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.10/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.020383710 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.3/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.020496324 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.6/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.020579732 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.7/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.020633324 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.2/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.020745252 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.5/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.020766601 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.1/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.562795627 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.11/attn/Constant_37_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.562847217 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_3414'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.562853285 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_3412'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.562858264 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.11/attn/Constant_36_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.562863115 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.11/attn/Constant_35_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.562876367 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.11/attn/Constant_12_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.562881128 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.11/attn/Constant_11_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.562886353 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_3341'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.562891023 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.11/attn/Constant_8_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.562896364 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.11/attn/Constant_7_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.562901499 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_3324'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.562906571 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.11/attn/Constant_6_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.562911147 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.11/attn/Constant_5_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.562916182 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.11/attn/Constant_4_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.562921978 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.11/attn/Constant_3_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.562927998 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_3305'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.562936164 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_3307'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.562970161 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.3/attn/Constant_11_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.562981303 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1113'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.562989301 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_565'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.563002392 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.4/attn/Constant_10_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.563021196 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.3/attn/Constant_4_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.563034658 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1496'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.563045322 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.9/attn/Constant_11_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.563061914 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_397'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.563080032 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.6/attn/Constant_35_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.563090975 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.4/attn/Constant_12_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.563097373 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.1/attn/Constant_8_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.563107437 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.9/attn/Constant_3_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.563114252 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1406'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.563126524 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.4/attn/Constant_6_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.563138228 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1389'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.563148288 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.4/attn/Constant_3_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.563155015 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.3/attn/Constant_12_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.563168291 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_2502'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.563178381 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.3/attn/Constant_3_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.563184346 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.0/attn/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.563194887 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_2759'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.563209376 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.0/attn/Constant_6_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.563224133 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.11/attn/Constant_10_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.563236348 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.7/attn/Constant_37_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.563248793 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.4/attn/Constant_35_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.563259169 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1680'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.563270314 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.3/attn/Constant_35_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.563284091 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.10/attn/Constant_36_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.563296469 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.2/attn/Constant_8_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.563306892 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1661'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.563314272 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.1/attn/Constant_10_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.563325013 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1387'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.563336814 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.4/attn/Constant_5_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.563353816 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.5/attn/Constant_4_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.563359871 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.1/attn/Constant_35_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.563368028 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.3/attn/Constant_9_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.563378402 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.3/attn/Constant_7_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.563384503 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1130'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.563394048 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.3/attn/Constant_6_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.563404302 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.3/attn/Constant_1_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.563422158 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1697'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.563432701 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.5/attn/Constant_11_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.563444264 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.9/attn/Constant_4_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.563463254 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.5/attn/Constant_6_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.565598177 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.4/attn/Constant_1_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.565621849 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.1/attn/Constant_9_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.565628937 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1971'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.565635213 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_2517'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.565648985 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_2245'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.565654752 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_948'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.565661090 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.3/attn/Constant_36_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.565667820 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.10/attn/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.565681828 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.11/attn/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.565688449 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.4/attn/Constant_11_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.565696348 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_3322'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.565707222 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.0/attn/Constant_1_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.565731257 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.5/attn/Constant_9_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.565739451 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.8/attn/Constant_7_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.565752577 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.5/attn/Constant_10_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.565761200 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_2864'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.565767511 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.8/attn/Constant_8_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.565773481 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.0/attn/Constant_37_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.565782064 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.0/attn/Constant_3_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.565790953 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_2044'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.565815335 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/Constant_1_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.565825312 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_674'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.565829926 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_2243'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.565838811 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.9/attn/Constant_8_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.565846038 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1663'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.565851416 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_601'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.565865533 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_324'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.565872974 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.6/attn/Constant_10_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.565879696 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1220'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.565884686 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.0/attn/Constant_9_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.565894843 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_873'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.565902643 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.1/attn/Constant_12_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.565911974 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.10/attn/Constant_4_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.565918482 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1149'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.565926078 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.0/attn/Constant_7_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.565937523 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_305'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.565943697 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_3065'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.565952558 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.3/attn/Constant_5_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.565966638 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.2/attn/Constant_7_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.565972668 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.2/attn/Constant_36_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.565979626 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_2519'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.565986522 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1132'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.565999159 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.3/attn/Constant_37_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.566008334 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1404'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.566013263 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.4/attn/Constant_37_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.566021492 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.2/attn/Constant_10_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.566028386 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.5/attn/Constant_5_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.566033916 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.4/attn/Constant_9_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.566041397 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1147'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.566047095 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_290'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.566052861 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1768'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.566058423 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.4/attn/Constant_36_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.566064496 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1937'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.566076229 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.2/attn/Constant_35_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.566081897 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1115'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.566088494 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1969'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.566099427 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.8/attn/Constant_5_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.566105149 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.2/attn/Constant_3_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.566111126 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_839'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.566119409 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_2866'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.566124870 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.0/attn/Constant_12_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.566132809 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.1/attn/Constant_1_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.566140001 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.0/attn/Constant_35_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.566146224 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.9/attn/Constant_6_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.566157918 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1678'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.566163755 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.3/attn/Constant_10_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.566171458 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.8/attn/Constant_36_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.566177392 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_2316'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.566186055 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.9/attn/Constant_10_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.566191209 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.0/attn/Constant_8_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.566201073 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.0/attn/Constant_4_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.566208369 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_288'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.566214589 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_2042'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.566223171 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.1/attn/Constant_3_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.566229930 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.7/attn/Constant_5_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.566235988 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.0/attn/Constant_5_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.566242248 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_2228'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.566250163 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.5/attn/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.566256559 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.4/attn/Constant_8_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.566263829 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.0/attn/Constant_11_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.566275481 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.4/attn/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.566284563 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1770'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.566291601 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.6/attn/Constant_3_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.566302127 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.1/attn/Constant_5_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.566308198 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.9/attn/Constant_12_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.566314874 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_180'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.566323497 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.1/attn/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.566330164 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.9/attn/Constant_1_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.566338121 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_567'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.566344396 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.1/attn/Constant_4_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.566358011 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.1/attn/Constant_6_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.567513042 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.8/attn/Constant_11_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.567535037 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_582'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.567541874 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.5/attn/Constant_3_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.567548534 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_584'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.567557605 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_599'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.567566031 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.1/attn/Constant_11_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.567586463 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1421'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.567594346 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.4/attn/Constant_7_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.567600035 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_399'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.567615769 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.0/attn/Constant_10_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.567623183 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_307'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.567628831 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.6/attn/Constant_4_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.567639941 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_672'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.567648721 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.1/attn/Constant_36_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.567656409 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_841'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.567662622 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.5/attn/Constant_1_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.567669023 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_2211'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.567688380 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_2483'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.567694335 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1494'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.567706349 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.8/attn/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.567716757 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.2/attn/Constant_12_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.567724508 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_3050'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.567734793 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.9/attn/Constant_36_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.567740302 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_875'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.567745449 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.2/attn/Constant_5_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.567751946 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.10/attn/Constant_6_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.567759801 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.5/attn/Constant_7_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.567767575 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.2/attn/Constant_11_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.567777164 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.2/attn/Constant_1_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.567784012 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.2/attn/Constant_4_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.567790894 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.6/attn/Constant_7_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.567806334 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.2/attn/Constant_6_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.567814102 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_856'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.567822568 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.9/attn/Constant_7_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.567828964 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_858'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.567837743 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.2/attn/Constant_9_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.567842874 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_946'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.567855062 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.9/attn/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:27.567861105 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.5/attn/Constant_8_output_0'. It is not used by any node and should be removed from the model.
# ...
# 2025-02-11 23:36:29.147732957 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.7/mlp/act/Constant_4_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:29.147752713 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.9/mlp/act/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:29.147795902 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.8/mlp/act/Constant_1_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:29.147814001 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.8/mlp/act/Constant_3_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:29.147868724 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.5/mlp/act/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:29.147889364 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.9/mlp/act/Constant_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:29.147933018 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.10/mlp/act/Constant_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:29.147952279 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.10/mlp/act/Constant_1_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:29.147968801 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.10/mlp/act/Constant_4_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:29.150665071 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.11/mlp/act/Constant_3_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:29.150767306 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.11/mlp/act/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:29.150787082 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.11/mlp/act/Constant_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:29.150843265 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.9/mlp/act/Constant_1_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:29.150867905 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.3/mlp/act/Constant_4_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:29.150892328 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.4/mlp/act/Constant_4_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:29.150917532 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.0/mlp/act/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:29.150959025 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.3/mlp/act/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:29.150983604 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.4/mlp/act/Constant_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:29.151030856 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.7/mlp/act/Constant_3_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:29.151066063 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.2/mlp/act/Constant_4_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:29.151084520 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.2/mlp/act/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:29.151100791 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.2/mlp/act/Constant_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:29.151122708 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.3/mlp/act/Constant_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:29.151144322 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.2/mlp/act/Constant_1_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:29.151166801 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.3/mlp/act/Constant_1_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:29.151215162 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.5/mlp/act/Constant_3_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:29.151233454 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.0/mlp/act/Constant_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:29.151251183 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.11/mlp/act/Constant_1_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:29.151267693 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.11/mlp/act/Constant_4_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:29.151284790 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.0/mlp/act/Constant_4_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:29.151320468 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.4/mlp/act/Constant_3_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:29.151388514 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.10/mlp/act/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:29.151410854 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.2/mlp/act/Constant_3_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:29.151445448 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.8/mlp/act/Constant_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:29.151486746 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.0/mlp/act/Constant_3_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:29.151507392 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.6/mlp/act/Constant_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:29.151536101 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.1/mlp/act/Constant_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:29.151579631 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.1/mlp/act/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:29.151599005 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.1/mlp/act/Constant_3_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:29.151622923 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.1/mlp/act/Constant_4_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:29.151644695 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.1/mlp/act/Constant_1_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:29.151696277 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.5/mlp/act/Constant_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:29.151714821 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.5/mlp/act/Constant_1_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:29.151731453 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.5/mlp/act/Constant_4_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:29.151755793 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.8/mlp/act/Constant_4_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:29.151775663 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.5/mlp/act/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:29.151793214 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.8/mlp/act/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:29.151826156 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.3/mlp/act/Constant_3_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:29.151846340 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.6/mlp/act/Constant_1_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:29.151864027 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.10/mlp/act/Constant_3_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:29.151880120 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.6/mlp/act/Constant_3_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:29.151897548 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.6/mlp/act/Constant_4_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:29.151927398 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.6/mlp/act/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:29.151944147 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.4/mlp/act/Constant_1_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:29.152005086 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.7/mlp/act/Constant_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:29.152023992 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.7/mlp/act/Constant_1_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:29.152040782 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.7/mlp/act/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:29.152058024 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.7/mlp/act/Constant_4_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:29.152076468 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.9/mlp/act/Constant_4_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:29.152097003 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.9/mlp/act/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:29.152117151 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.9/mlp/act/Constant_3_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:29.152159414 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.8/mlp/act/Constant_1_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:29.152177818 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.8/mlp/act/Constant_3_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:29.152203079 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.0/mlp/act/Constant_1_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:29.152222332 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.4/mlp/act/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:29.152255750 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.9/mlp/act/Constant_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:29.152295132 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.10/mlp/act/Constant_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:29.152312171 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.10/mlp/act/Constant_1_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:36:29.152328880 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.10/mlp/act/Constant_4_output_0'. It is not used by any node and should be removed from the model.

# %%
# %%script node
# const { InferenceSession, Tensor } = require('onnxruntime-web');
#
# async function run() {
#     console.log("🚀 بدء تشغيل النموذج...");
#
#     // تحميل نموذج ONNX باستخدام onnxruntime-web
#     const session = await InferenceSession.create('./deepseek_model/model.onnx');
#
#     // إدخال النص
#     const prompt = "Once upon a time,";
#
#     // تحويل النص إلى مدخلات للنموذج (قد يختلف حسب النموذج)
#     const inputTensor = new Tensor('string', [prompt], [1]); // Adjust data type and shape as needed
#
#     // تشغيل النموذج
#     const results = await session.run({ input: inputTensor });
#
#     // استخراج النتائج (قد يختلف حسب النموذج)
#     const outputTensor = results.output; // Assuming 'output' is the name of the output node
#     const generatedText = outputTensor.data[0]; // Adjust data extraction as needed
#
#     // طباعة النص الناتج
#     console.log("✅ النص الناتج:");
#     console.log(generatedText);
# }
#
# // تشغيل الدالة
# run();
# Out:
# 🚀 بدء تشغيل النموذج...
# node:internal/process/promises:288
#             triggerUncaughtException(err, true /* fromPromise */);
#             ^
#
# [Error: ENOENT: no such file or directory, open './deepseek_model/model.onnx'] {
#   errno: -2,
#   code: 'ENOENT',
#   syscall: 'open',
#   path: './deepseek_model/model.onnx'
# }
#
# Node.js v18.20.5
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-60-e0f457e99b87> in <cell line: 0>()
# ----> 1 get_ipython().run_cell_magic('script', 'node', 'const { InferenceSession, Tensor } = require(\'onnxruntime-web\');\n\nasync function run() {\n    console.log("🚀 بدء تشغيل النموذج...");\n\n    // تحميل نموذج ONNX باستخدام onnxruntime-web\n    const session = await InferenceSession.create(\'./deepseek_model/model.onnx\');\n\n    // إدخال النص\n    const prompt = "Once upon a time,";\n\n    // تحويل النص إلى مدخلات للنموذج (قد يختلف حسب النموذج)\n    const inputTensor = new Tensor(\'string\', [prompt], [1]); // Adjust data type and shape as needed\n\n    // تشغيل النموذج\n    const results = await session.run({ input: inputTensor });\n\n    // استخراج النتائج (قد يختلف حسب النموذج)\n    const outputTensor = results.output; // Assuming \'output\' is the name of the output node\n    const generatedText = outputTensor.data[0]; // Adjust data extraction as needed\n\n    // طباعة النص الناتج\n    console.log("✅ النص الناتج:");\n    console.log(generatedText);\n}\n\n// تشغيل الدالة\nrun();\n')
#
# /usr/local/lib/python3.11/dist-packages/google/colab/_shell.py in run_cell_magic(self, magic_name, line, cell)
#     332     if line and not cell:
#     333       cell = ' '
# --> 334     return super().run_cell_magic(magic_name, line, cell)
#     335
#     336
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2471             with self.builtin_trap:
#    2472                 args = (magic_arg_s, cell)
# -> 2473                 result = fn(*args, **kwargs)
#    2474             return result
#    2475
#
# <decorator-gen-103> in shebang(self, line, cell)
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/magics/script.py in shebang(self, line, cell)
#     243             sys.stderr.flush()
#     244         if args.raise_error and p.returncode!=0:
# --> 245             raise CalledProcessError(p.returncode, cell, output=out, stderr=err)
#     246
#     247     def _run_script(self, p, cell, to_close):
#
# CalledProcessError: Command 'b'const { InferenceSession, Tensor } = require(\'onnxruntime-web\');\n\nasync function run() {\n    console.log("\xf0\x9f\x9a\x80 \xd8\xa8\xd8\xaf\xd8\xa1 \xd8\xaa\xd8\xb4\xd8\xba\xd9\x8a\xd9\x84 \xd8\xa7\xd9\x84\xd9\x86\xd9\x85\xd9\x88\xd8\xb0\xd8\xac...");\n\n    // \xd8\xaa\xd8\xad\xd9\x85\xd9\x8a\xd9\x84 \xd9\x86\xd9\x85\xd9\x88\xd8\xb0\xd8\xac ONNX \xd8\xa8\xd8\xa7\xd8\xb3\xd8\xaa\xd8\xae\xd8\xaf\xd8\xa7\xd9\x85 onnxruntime-web\n    const session = await InferenceSession.create(\'./deepseek_model/model.onnx\');\n\n    // \xd8\xa5\xd8\xaf\xd8\xae\xd8\xa7\xd9\x84 \xd8\xa7\xd9\x84\xd9\x86\xd8\xb5\n    const prompt = "Once upon a time,";\n\n    // \xd8\xaa\xd8\xad\xd9\x88\xd9\x8a\xd9\x84 \xd8\xa7\xd9\x84\xd9\x86\xd8\xb5 \xd8\xa5\xd9\x84\xd9\x89 \xd9\x85\xd8\xaf\xd8\xae\xd9\x84\xd8\xa7\xd8\xaa \xd9\x84\xd9\x84\xd9\x86\xd9\x85\xd9\x88\xd8\xb0\xd8\xac (\xd9\x82\xd8\xaf \xd9\x8a\xd8\xae\xd8\xaa\xd9\x84\xd9\x81 \xd8\xad\xd8\xb3\xd8\xa8 \xd8\xa7\xd9\x84\xd9\x86\xd9\x85\xd9\x88\xd8\xb0\xd8\xac)\n    const inputTensor = new Tensor(\'string\', [prompt], [1]); // Adjust data type and shape as needed\n\n    // \xd8\xaa\xd8\xb4\xd8\xba\xd9\x8a\xd9\x84 \xd8\xa7\xd9\x84\xd9\x86\xd9\x85\xd9\x88\xd8\xb0\xd8\xac\n    const results = await session.run({ input: inputTensor });\n\n    // \xd8\xa7\xd8\xb3\xd8\xaa\xd8\xae\xd8\xb1\xd8\xa7\xd8\xac \xd8\xa7\xd9\x84\xd9\x86\xd8\xaa\xd8\xa7\xd8\xa6\xd8\xac (\xd9\x82\xd8\xaf \xd9\x8a\xd8\xae\xd8\xaa\xd9\x84\xd...

# %%
# %%script node
# const { InferenceSession, Tensor } = require('onnxruntime-node'); // Use onnxruntime-node
#
# async function run() {
#     console.log("🚀 بدء تشغيل النموذج...");
#
#     // تحميل نموذج ONNX باستخدام onnxruntime-node
#     const session = await InferenceSession.create('./deepseek_model/model.onnx'); // Assuming the model is in 'deepseek_model' folder
#
#     // إدخال النص
#     const prompt = "Once upon a time,";
#
#     // تحويل النص إلى مدخلات للنموذج (قد يختلف حسب النموذج)
#     // Adjust data type and shape as needed - refer to your model's input requirements
#     const inputTensor = new Tensor('string', [prompt], [1]);
#
#     // تشغيل النموذج
#     const results = await session.run({ input: inputTensor });
#
#     // استخراج النتائج (قد يختلف حسب النموذج)
#     // Assuming 'output' is the name of the output node - refer to your model's output
#     const outputTensor = results.output;
#     const generatedText = outputTensor.data[0]; // Adjust data extraction as needed
#
#     // طباعة النص الناتج
#     console.log("✅ النص الناتج:");
#     console.log(generatedText);
# }
#
# // تشغيل الدالة
# run();
# Out:
# 🚀 بدء تشغيل النموذج...
# /content/node_modules/onnxruntime-node/dist/backend.js:24
#             __classPrivateFieldGet(this, _OnnxruntimeSessionHandler_inferenceSession, "f").loadModel(pathOrBuffer, options);
#                                                                                            ^
#
# Error: Load model from ./deepseek_model/model.onnx failed:Load model ./deepseek_model/model.onnx failed. File doesn't exist
#     at new OnnxruntimeSessionHandler (/content/node_modules/onnxruntime-node/dist/backend.js:24:92)
#     at Immediate.<anonymous> (/content/node_modules/onnxruntime-node/dist/backend.js:64:29)
#     at process.processImmediate (node:internal/timers:476:21)
#
# Node.js v18.20.5
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-61-d7ff45eae9b4> in <cell line: 0>()
# ----> 1 get_ipython().run_cell_magic('script', 'node', 'const { InferenceSession, Tensor } = require(\'onnxruntime-node\'); // Use onnxruntime-node\n\nasync function run() {\n    console.log("🚀 بدء تشغيل النموذج...");\n\n    // تحميل نموذج ONNX باستخدام onnxruntime-node\n    const session = await InferenceSession.create(\'./deepseek_model/model.onnx\'); // Assuming the model is in \'deepseek_model\' folder\n\n    // إدخال النص\n    const prompt = "Once upon a time,";\n\n    // تحويل النص إلى مدخلات للنموذج (قد يختلف حسب النموذج)\n    // Adjust data type and shape as needed - refer to your model\'s input requirements\n    const inputTensor = new Tensor(\'string\', [prompt], [1]); \n\n    // تشغيل النموذج\n    const results = await session.run({ input: inputTensor });\n\n    // استخراج النتائج (قد يختلف حسب النموذج)\n    // Assuming \'output\' is the name of the output node - refer to your model\'s output\n    const outputTensor = results.output;  \n    const generatedText = outputTensor.data[0]; // Adjust data extraction as needed\n\n    // طباعة النص الناتج\n    console.log("✅ النص الناتج:");\n    console.log(generatedText);\n}\n\n// تشغيل الدالة\nrun();\n')
#
# /usr/local/lib/python3.11/dist-packages/google/colab/_shell.py in run_cell_magic(self, magic_name, line, cell)
#     332     if line and not cell:
#     333       cell = ' '
# --> 334     return super().run_cell_magic(magic_name, line, cell)
#     335
#     336
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2471             with self.builtin_trap:
#    2472                 args = (magic_arg_s, cell)
# -> 2473                 result = fn(*args, **kwargs)
#    2474             return result
#    2475
#
# <decorator-gen-103> in shebang(self, line, cell)
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/magics/script.py in shebang(self, line, cell)
#     243             sys.stderr.flush()
#     244         if args.raise_error and p.returncode!=0:
# --> 245             raise CalledProcessError(p.returncode, cell, output=out, stderr=err)
#     246
#     247     def _run_script(self, p, cell, to_close):
#
# CalledProcessError: Command 'b'const { InferenceSession, Tensor } = require(\'onnxruntime-node\'); // Use onnxruntime-node\n\nasync function run() {\n    console.log("\xf0\x9f\x9a\x80 \xd8\xa8\xd8\xaf\xd8\xa1 \xd8\xaa\xd8\xb4\xd8\xba\xd9\x8a\xd9\x84 \xd8\xa7\xd9\x84\xd9\x86\xd9\x85\xd9\x88\xd8\xb0\xd8\xac...");\n\n    // \xd8\xaa\xd8\xad\xd9\x85\xd9\x8a\xd9\x84 \xd9\x86\xd9\x85\xd9\x88\xd8\xb0\xd8\xac ONNX \xd8\xa8\xd8\xa7\xd8\xb3\xd8\xaa\xd8\xae\xd8\xaf\xd8\xa7\xd9\x85 onnxruntime-node\n    const session = await InferenceSession.create(\'./deepseek_model/model.onnx\'); // Assuming the model is in \'deepseek_model\' folder\n\n    // \xd8\xa5\xd8\xaf\xd8\xae\xd8\xa7\xd9\x84 \xd8\xa7\xd9\x84\xd9\x86\xd8\xb5\n    const prompt = "Once upon a time,";\n\n    // \xd8\xaa\xd8\xad\xd9\x88\xd9\x8a\xd9\x84 \xd8\xa7\xd9\x84\xd9\x86\xd8\xb5 \xd8\xa5\xd9\x84\xd9\x89 \xd9\x85\xd8\xaf\xd8\xae\xd9\x84\xd8\xa7\xd8\xaa \xd9\x84\xd9\x84\xd9\x86\xd9\x85\xd9\x88\xd8\xb0\xd8\xac (\xd9\x82\xd8\xaf \xd9\x8a\xd8\xae\xd8\xaa\xd9\x84\xd9\x81 \xd8\xad\xd8\xb3\xd8\xa8 \xd8\xa7\xd9\x84\xd9\x86\xd9\x85\xd9\x88\xd8\xb0\xd8\xac)\n    // Adjust data type and shape as needed - refer to your model\'s input requirements\n    const inputTensor = new Tensor(\'string\', [prompt], [1]); \n\n    // \xd8\xaa\xd8\xb4\xd8\xba\xd9\x8a\xd9\x84 \xd8\xa7\xd9\x84\xd9\x86\xd9\x85\xd9\x88\xd8\xb0\xd8\xac\n    const results = await session.run({ input: inputTensor });\n\n    // \xd8\xa7\xd8\xb3\xd8\xaa\xd8\xae\xd8\...

# %% [markdown]
# https://ipython.readthedocs.io/en/stable/interactive/magics.html

# %% [markdown]
# شغال بدون كتابة ملف جافا ويعمل فى خلية كولاب

# %%
# %%script node
#
# (async () => {
#     console.log("🚀 بدء تشغيل النموذج...");
#
#     // استيراد مكتبة @xenova/transformers ديناميكيًا
#     const { pipeline } = await import('@xenova/transformers');
#
#     console.log("⏳ تحميل النموذج...");
#     const pipe = await pipeline('text-generation', 'Xenova/Qwen1.5-1.8B');
#
#     console.log("✍️ إدخال النص...");
#     const prompt = "Once upon a time,";
#
#     console.log("⚡ توليد النص...");
#     const generatedText = await pipe(prompt, { max_new_tokens: 50 });
#
#     console.log("✅ النص الناتج:");
#     console.log(generatedText[0].generated_text);
# })();
# Out:
# 🚀 بدء تشغيل النموذج...
# ⏳ تحميل النموذج...
# ✍️ إدخال النص...
# ⚡ توليد النص...
# ✅ النص الناتج:
# Once upon a time, I was a very good student. I studied hard and got good grades. I was a good student. I was a good student. I was a good student. I was a good student. I was a good student. I was a good student

# %% [markdown]
# شغال

# %%
# %%script node
#
# (async () => {
#     console.log("🚀 بدء تشغيل النموذج...");
#
#     // استيراد مكتبة @xenova/transformers ديناميكيًا
#     const { pipeline } = await import('@xenova/transformers');
#
#     console.log("⏳ تحميل النموذج...");
#     const pipe = await pipeline('text-generation', 'Xenova/gpt2');
#
#     console.log("✍️ إدخال النص...");
#     const prompt = "Once upon a time,";
#
#     console.log("⚡ توليد النص...");
#     const generatedText = await pipe(prompt, { max_new_tokens: 50 });
#
#     console.log("✅ النص الناتج:");
#     console.log(generatedText[0].generated_text);
# })();
# Out:
# 🚀 بدء تشغيل النموذج...
# ⏳ تحميل النموذج...
# ✍️ إدخال النص...
# ⚡ توليد النص...
# ✅ النص الناتج:
# Once upon a time, I was in a room with a woman who was very attractive. She was very attractive. She was very attractive. She was very attractive. She was very attractive. She was very attractive. She was very attractive. She was very attractive. She was
# 2025-02-11 23:39:13.988402079 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.11/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:13.988590922 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.0/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:13.988657710 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.4/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:13.988860927 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.10/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:13.988927485 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.8/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:13.989097771 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.2/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:13.989138916 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.3/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:13.989220934 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.6/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:13.989272230 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.7/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:13.989361697 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.9/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:13.989410083 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.5/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:13.989428368 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.1/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:13.992499881 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.11/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:13.992656696 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.9/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:13.992724002 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.4/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:13.992912688 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.8/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:13.992947421 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.0/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:13.993008817 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.10/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:13.993126489 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.3/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:13.993208786 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.6/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:13.993277517 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.7/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:13.993322691 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.2/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:13.993422212 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.5/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:13.993443937 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.1/attn/Constant_18_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.230894632 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.11/attn/Constant_37_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.231010374 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_3414'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.231032693 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_3412'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.231051194 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.11/attn/Constant_36_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.231068357 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.11/attn/Constant_35_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.231093770 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.11/attn/Constant_12_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.231111056 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.11/attn/Constant_11_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.231128564 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_3341'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.231145276 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.11/attn/Constant_8_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.231163441 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.11/attn/Constant_7_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.231179514 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_3324'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.231196468 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.11/attn/Constant_6_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.231212958 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.11/attn/Constant_5_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.231229378 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.11/attn/Constant_4_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.231246044 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.11/attn/Constant_3_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.231262435 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_3305'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.231281037 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_3307'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.231317213 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.3/attn/Constant_11_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.231334635 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1113'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.231352390 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_565'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.231371584 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.4/attn/Constant_10_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.231394993 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.3/attn/Constant_4_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.231413205 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1496'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.231430252 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.9/attn/Constant_11_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.231455643 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_397'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.231492435 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.6/attn/Constant_35_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.231512575 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.4/attn/Constant_12_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.231529024 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.1/attn/Constant_8_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.231545531 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.9/attn/Constant_3_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.231563186 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1406'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.231581145 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.4/attn/Constant_6_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.231599470 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1389'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.231615793 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.4/attn/Constant_3_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.231632360 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.3/attn/Constant_12_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.231652703 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_2502'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.231668909 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.3/attn/Constant_3_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.231684995 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.0/attn/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.231704828 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_2759'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.231725263 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.0/attn/Constant_6_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.231745425 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.11/attn/Constant_10_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.231763363 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.7/attn/Constant_37_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.231783834 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.4/attn/Constant_35_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.231800711 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1680'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.231821683 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.3/attn/Constant_35_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.231842069 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.10/attn/Constant_36_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.231869908 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.2/attn/Constant_8_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.231886184 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1661'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.231902862 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.1/attn/Constant_10_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.231919660 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1387'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.231937093 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.4/attn/Constant_5_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.231959986 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.5/attn/Constant_4_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.231975966 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.1/attn/Constant_35_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.231999188 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.3/attn/Constant_9_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.232017462 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.3/attn/Constant_7_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.232051460 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1130'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.232070978 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.3/attn/Constant_6_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.232088404 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.3/attn/Constant_1_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.232117320 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1697'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.232135095 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.5/attn/Constant_11_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.232156848 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.9/attn/Constant_4_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.232182029 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.5/attn/Constant_6_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.232203800 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.4/attn/Constant_1_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.232221023 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.1/attn/Constant_9_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.232237583 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1971'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.232254331 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_2517'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.232275238 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_2245'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.232292126 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_948'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.232308998 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.3/attn/Constant_36_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.232326389 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.10/attn/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.232348880 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.11/attn/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.232366836 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.4/attn/Constant_11_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.232385763 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_3322'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.232406201 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.0/attn/Constant_1_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.232437861 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.5/attn/Constant_9_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.232458610 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.8/attn/Constant_7_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.232481879 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.5/attn/Constant_10_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.232515012 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_2864'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.232533644 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.8/attn/Constant_8_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.232551062 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.0/attn/Constant_37_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.232570571 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.0/attn/Constant_3_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.232587580 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_2044'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.232608861 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/Constant_1_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.232628955 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_674'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.232645618 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_2243'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.232665087 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.9/attn/Constant_8_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.232684112 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1663'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.232701369 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_601'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.232725176 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_324'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.232742679 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.6/attn/Constant_10_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.232760971 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1220'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.232777562 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.0/attn/Constant_9_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.232798008 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_873'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.232817662 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.1/attn/Constant_12_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.232837226 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.10/attn/Constant_4_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.232862708 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1149'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.232881810 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.0/attn/Constant_7_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.232903750 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_305'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.232921702 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_3065'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.232941034 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.3/attn/Constant_5_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.232964471 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.2/attn/Constant_7_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.232981200 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.2/attn/Constant_36_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.233000362 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_2519'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.233018321 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1132'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.233042213 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.3/attn/Constant_37_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.233062916 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1404'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.233080845 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.4/attn/Constant_37_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.233099808 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.2/attn/Constant_10_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.233119430 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.5/attn/Constant_5_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.233135948 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.4/attn/Constant_9_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.233154916 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1147'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.233172182 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_290'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.233188533 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1768'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.233205416 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.4/attn/Constant_36_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.233222536 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1937'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.233245205 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.2/attn/Constant_35_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.233262798 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1115'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.233280648 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1969'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.233299977 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.8/attn/Constant_5_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.233317042 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.2/attn/Constant_3_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.233334551 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_839'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.233354329 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_2866'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.233370752 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.0/attn/Constant_12_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.233389429 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.1/attn/Constant_1_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.233407370 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.0/attn/Constant_35_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.233425019 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.9/attn/Constant_6_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.233446984 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1678'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.233464226 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.3/attn/Constant_10_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.233496462 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.8/attn/Constant_36_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.233514377 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_2316'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.233533325 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.9/attn/Constant_10_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.233549575 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.0/attn/Constant_8_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.233569324 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.0/attn/Constant_4_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.233587825 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_288'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.233605705 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_2042'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.233624072 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.1/attn/Constant_3_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.233641327 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.7/attn/Constant_5_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.233658048 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.0/attn/Constant_5_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.233674798 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_2228'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.233693219 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.5/attn/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.233710419 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.4/attn/Constant_8_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.233727445 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.0/attn/Constant_11_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.233749202 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.4/attn/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.233768392 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1770'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.233785332 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.6/attn/Constant_3_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.233807882 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.1/attn/Constant_5_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.233825194 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.9/attn/Constant_12_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.233842012 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_180'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.233869143 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.1/attn/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.233885904 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.9/attn/Constant_1_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.233906274 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_567'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.233923941 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.1/attn/Constant_4_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.233947229 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.1/attn/Constant_6_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.233964968 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.8/attn/Constant_11_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.233983141 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_582'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.234000188 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.5/attn/Constant_3_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.234017643 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_584'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.234035498 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_599'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.234053727 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.1/attn/Constant_11_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.234079504 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1421'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.234096900 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.4/attn/Constant_7_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.234113984 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_399'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.234136602 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.0/attn/Constant_10_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.234153561 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_307'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.234169799 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.6/attn/Constant_4_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.234188544 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_672'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.234207669 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.1/attn/Constant_36_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.234225937 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_841'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.234243350 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.5/attn/Constant_1_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.234260551 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_2211'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.234300213 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_2483'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.234317320 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_1494'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.234336696 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.8/attn/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.234355965 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.2/attn/Constant_12_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.234373509 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_3050'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.234393781 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.9/attn/Constant_36_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.234409990 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_875'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.234426467 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.2/attn/Constant_5_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.234444660 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.10/attn/Constant_6_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.234462163 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.5/attn/Constant_7_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.234479923 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.2/attn/Constant_11_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.234510761 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.2/attn/Constant_1_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.234528218 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.2/attn/Constant_4_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.234545184 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.6/attn/Constant_7_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.234561292 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.2/attn/Constant_6_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.234579490 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_856'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.234596058 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.9/attn/Constant_7_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.234612321 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_858'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.234630713 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.2/attn/Constant_9_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.234646670 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Unsqueeze_946'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.234665680 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.9/attn/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:14.234682038 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.5/attn/Constant_8_output_0'. It is not used by any node and should be removed from the model.
# ...
# 2025-02-11 23:39:15.632290224 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.7/mlp/act/Constant_4_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:15.632309342 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.9/mlp/act/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:15.632347368 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.8/mlp/act/Constant_1_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:15.632366640 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.8/mlp/act/Constant_3_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:15.632402266 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.5/mlp/act/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:15.632421028 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.9/mlp/act/Constant_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:15.632465085 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.10/mlp/act/Constant_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:15.632500732 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.10/mlp/act/Constant_1_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:15.632517898 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.10/mlp/act/Constant_4_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:15.634958238 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.11/mlp/act/Constant_3_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:15.635033842 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.11/mlp/act/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:15.635054382 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.11/mlp/act/Constant_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:15.635098176 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.9/mlp/act/Constant_1_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:15.635122020 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.3/mlp/act/Constant_4_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:15.635146625 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.4/mlp/act/Constant_4_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:15.635171832 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.0/mlp/act/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:15.635207768 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.3/mlp/act/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:15.635232076 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.4/mlp/act/Constant_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:15.635277153 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.7/mlp/act/Constant_3_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:15.635312714 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.2/mlp/act/Constant_4_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:15.635331816 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.2/mlp/act/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:15.635348985 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.2/mlp/act/Constant_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:15.635370493 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.3/mlp/act/Constant_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:15.635391005 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.2/mlp/act/Constant_1_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:15.635413752 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.3/mlp/act/Constant_1_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:15.635459771 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.5/mlp/act/Constant_3_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:15.635496603 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.0/mlp/act/Constant_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:15.635515334 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.11/mlp/act/Constant_1_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:15.635533226 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.11/mlp/act/Constant_4_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:15.635550692 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.0/mlp/act/Constant_4_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:15.635587107 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.4/mlp/act/Constant_3_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:15.635658128 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.10/mlp/act/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:15.635682448 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.2/mlp/act/Constant_3_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:15.635716485 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.8/mlp/act/Constant_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:15.635744541 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.0/mlp/act/Constant_3_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:15.635761774 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.6/mlp/act/Constant_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:15.635788599 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.1/mlp/act/Constant_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:15.635839206 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.1/mlp/act/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:15.635860587 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.1/mlp/act/Constant_3_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:15.635883963 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.1/mlp/act/Constant_4_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:15.635905751 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.1/mlp/act/Constant_1_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:15.635957657 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.5/mlp/act/Constant_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:15.635976262 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.5/mlp/act/Constant_1_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:15.635993616 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.5/mlp/act/Constant_4_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:15.636017425 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.8/mlp/act/Constant_4_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:15.636038432 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.5/mlp/act/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:15.636055816 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.8/mlp/act/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:15.636080634 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.3/mlp/act/Constant_3_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:15.636101204 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.6/mlp/act/Constant_1_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:15.636118948 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.10/mlp/act/Constant_3_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:15.636135266 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.6/mlp/act/Constant_3_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:15.636153163 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.6/mlp/act/Constant_4_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:15.636183220 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.6/mlp/act/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:15.636201139 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.4/mlp/act/Constant_1_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:15.636242989 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.7/mlp/act/Constant_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:15.636261776 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.7/mlp/act/Constant_1_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:15.636279201 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.7/mlp/act/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:15.636295708 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.7/mlp/act/Constant_4_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:15.636313979 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.9/mlp/act/Constant_4_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:15.636333906 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.9/mlp/act/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:15.636352807 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.9/mlp/act/Constant_3_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:15.636393337 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.8/mlp/act/Constant_1_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:15.636411298 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.8/mlp/act/Constant_3_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:15.636435959 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.0/mlp/act/Constant_1_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:15.636453880 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.4/mlp/act/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:15.636502332 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.9/mlp/act/Constant_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:15.636546368 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.10/mlp/act/Constant_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:15.636563597 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.10/mlp/act/Constant_1_output_0'. It is not used by any node and should be removed from the model.
# 2025-02-11 23:39:15.636579647 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/transformer/h.10/mlp/act/Constant_4_output_0'. It is not used by any node and should be removed from the model.

# %%
# %%script node
#
# const ort = require('onnxruntime-node');
# const fs = require('fs');
#
# (async () => {
#     console.log("🚀 بدء تشغيل النموذج...");
#
#     // تحقق من وجود الملف
#     const modelPath = "/content/gpt2_onnx/model.onnx";
#     if (!fs.existsSync(modelPath)) {
#         console.error(`❌ خطأ: الملف غير موجود في ${modelPath}`);
#         return;
#     }
#
#     console.log("⏳ تحميل النموذج...");
#     const session = await ort.InferenceSession.create(modelPath);
#
#     console.log("✍️ إدخال النص...");
#     const prompt = "Once upon a time,";
#
#     console.log("⚡ توليد النص...");
#     const inputTensor = new ort.Tensor("float32", new Float32Array([prompt.length]), [1, prompt.length]);
#
#     const outputs = await session.run({ input_ids: inputTensor });
#
#     console.log("✅ النص الناتج:");
#     console.log(outputs);
# })();
# Out:
# 🚀 بدء تشغيل النموذج...
# ⏳ تحميل النموذج...
# ✍️ إدخال النص...
# ⚡ توليد النص...
# /content/node_modules/onnxruntime-common/dist/cjs/tensor-impl.js:226
#                 throw new Error(`Tensor's size(${size}) does not match data length(${this.cpuData.length}).`);
#                       ^
#
# Error: Tensor's size(17) does not match data length(1).
#     at new Tensor (/content/node_modules/onnxruntime-common/dist/cjs/tensor-impl.js:226:23)
#     at [stdin]:22:25
#
# Node.js v18.20.5
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-4-2d61640d9175> in <cell line: 0>()
# ----> 1 get_ipython().run_cell_magic('script', 'node', '\nconst ort = require(\'onnxruntime-node\');\nconst fs = require(\'fs\');\n\n(async () => {\n    console.log("🚀 بدء تشغيل النموذج...");\n\n    // تحقق من وجود الملف\n    const modelPath = "/content/gpt2_onnx/model.onnx";\n    if (!fs.existsSync(modelPath)) {\n        console.error(`❌ خطأ: الملف غير موجود في ${modelPath}`);\n        return;\n    }\n\n    console.log("⏳ تحميل النموذج...");\n    const session = await ort.InferenceSession.create(modelPath);\n\n    console.log("✍️ إدخال النص...");\n    const prompt = "Once upon a time,";\n\n    console.log("⚡ توليد النص...");\n    const inputTensor = new ort.Tensor("float32", new Float32Array([prompt.length]), [1, prompt.length]);\n\n    const outputs = await session.run({ input_ids: inputTensor });\n\n    console.log("✅ النص الناتج:");\n    console.log(outputs);\n})();\n')
#
# /usr/local/lib/python3.11/dist-packages/google/colab/_shell.py in run_cell_magic(self, magic_name, line, cell)
#     332     if line and not cell:
#     333       cell = ' '
# --> 334     return super().run_cell_magic(magic_name, line, cell)
#     335
#     336
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2471             with self.builtin_trap:
#    2472                 args = (magic_arg_s, cell)
# -> 2473                 result = fn(*args, **kwargs)
#    2474             return result
#    2475
#
# <decorator-gen-103> in shebang(self, line, cell)
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/magics/script.py in shebang(self, line, cell)
#     243             sys.stderr.flush()
#     244         if args.raise_error and p.returncode!=0:
# --> 245             raise CalledProcessError(p.returncode, cell, output=out, stderr=err)
#     246
#     247     def _run_script(self, p, cell, to_close):
#
# CalledProcessError: Command 'b'\nconst ort = require(\'onnxruntime-node\');\nconst fs = require(\'fs\');\n\n(async () => {\n    console.log("\xf0\x9f\x9a\x80 \xd8\xa8\xd8\xaf\xd8\xa1 \xd8\xaa\xd8\xb4\xd8\xba\xd9\x8a\xd9\x84 \xd8\xa7\xd9\x84\xd9\x86\xd9\x85\xd9\x88\xd8\xb0\xd8\xac...");\n\n    // \xd8\xaa\xd8\xad\xd9\x82\xd9\x82 \xd9\x85\xd9\x86 \xd9\x88\xd8\xac\xd9\x88\xd8\xaf \xd8\xa7\xd9\x84\xd9\x85\xd9\x84\xd9\x81\n    const modelPath = "/content/gpt2_onnx/model.onnx";\n    if (!fs.existsSync(modelPath)) {\n        console.error(`\xe2\x9d\x8c \xd8\xae\xd8\xb7\xd8\xa3: \xd8\xa7\xd9\x84\xd9\x85\xd9\x84\xd9\x81 \xd8\xba\xd9\x8a\xd8\xb1 \xd9\x85\xd9\x88\xd8\xac\xd9\x88\xd8\xaf \xd9\x81\xd9\x8a ${modelPath}`);\n        return;\n    }\n\n    console.log("\xe2\x8f\xb3 \xd8\xaa\xd8\xad\xd9\x85\xd9\x8a\xd9\x84 \xd8\xa7\xd9\x84\xd9\x86\xd9\x85\xd9\x88\xd8\xb0\xd8\xac...");\n    const session = await ort.InferenceSession.create(modelPath);\n\n    console.log("\xe2\x9c\x8d\xef\xb8\x8f \xd8\xa5\xd8\xaf\xd8\xae\xd8\xa7\xd9\x84 \xd8\xa7\xd9\x84\xd9\x86\xd8\xb5...");\n    const prompt = "Once upon a time,";\n\n    console.log("\xe2\x9a\xa1 \xd8\xaa\xd9\x88\xd9\x84\xd9\x8a\xd8\xaf \xd8\xa7\xd9\x84\xd9\x86\xd8\xb5...");\n    const inputTensor = new ort.Tensor("float32", new Float32Array([prompt.length]), [1, prompt.length]);\n\n    const outputs = await session.run({ input_ids: inputTensor });\n\n    console.log("\xe2\x9c\x85 \xd8\xa7\xd9\x84\xd9\x86\xd8\xb5 \xd8\xa7\xd9\x84\x...

# %%
# %%script node
#
# const ort = require('onnxruntime-node');
# const fs = require('fs');
#
# (async () => {
#     console.log("🚀 بدء تشغيل النموذج...");
#
#     // تحقق من وجود الملف
#     const modelPath = "./Qwen2.5-0.5B-Instruct-ONNX-MHA/onnx/decoder_model_merged_quantized.onnx";
#     if (!fs.existsSync(modelPath)) {
#         console.error(`❌ خطأ: الملف غير موجود في ${modelPath}`);
#         return;
#     }
#
#     console.log("⏳ تحميل النموذج...");
#     const session = await ort.InferenceSession.create(modelPath);
#
#     console.log("✍️ إدخال النص...");
#     const prompt = "Once upon a time,";
#
#     console.log("⚡ توليد النص...");
#     const inputTensor = new ort.Tensor("float32", new Float32Array([prompt.length]), [1, prompt.length]);
#
#     const outputs = await session.run({ input_ids: inputTensor });
#
#     console.log("✅ النص الناتج:");
#     console.log(outputs);
# })();
# Out:
# 🚀 بدء تشغيل النموذج...
# ❌ خطأ: الملف غير موجود في ./Qwen2.5-0.5B-Instruct-ONNX-MHA/onnx/decoder_model_merged_quantized.onnx

# %%
# %%script node
#
# (async () => {
#     console.log("🚀 بدء تشغيل النموذج...");
#
#     // استيراد مكتبة @xenova/transformers ديناميكيًا
#     const { pipeline } = await import('@xenova/transformers');
#
#     console.log("⏳ تحميل النموذج...");
#     const pipe = await pipeline('text-generation', 'Xenova/gpt2');
#
#     console.log("✍️ إدخال النص...");
#     const prompt = "Once upon a time,";
#
#     console.log("⚡ توليد النص...");
#     const generatedText = await pipe(prompt, { max_new_tokens: 50 });
#
#     console.log("✅ النص الناتج:");
#     console.log(generatedText[0].generated_text);
# })();

# %%
# %%script node
# const ort = require('onnxruntime-node');
# const fs = require('fs');
#
# async function runModel() {
#     console.log("🚀 تحميل النموذج...");
#
#     // تحميل النموذج
#     const session = await ort.InferenceSession.create("./Qwen2.5-0.5B-Instruct-ONNX-MHA/onnx/decoder_model_merged_quantized.onnx");
#
#     // إدخال بيانات عشوائية (حسب احتياجات النموذج)
#     const inputTensor = new ort.Tensor("float32", new Float32Array([0.5, 0.5, 0.5]), [1, 3]);
#
#     // تنفيذ النموذج
#     const results = await session.run({ input: inputTensor });
#
#     console.log("✅ النتائج:", results);
# }
#
# runModel().catch(console.error);
# Out:
# 🚀 تحميل النموذج...
# Error: Load model from ./Qwen2.5-0.5B-Instruct-ONNX-MHA/onnx/decoder_model_merged_quantized.onnx failed:Load model ./Qwen2.5-0.5B-Instruct-ONNX-MHA/onnx/decoder_model_merged_quantized.onnx failed. File doesn't exist
#     at new OnnxruntimeSessionHandler (/content/node_modules/onnxruntime-node/dist/backend.js:24:92)
#     at Immediate.<anonymous> (/content/node_modules/onnxruntime-node/dist/backend.js:64:29)
#     at process.processImmediate (node:internal/timers:476:21)

# %%
Xenova/Qwen1.5-1.8B-Chat

# %%
# %%script node
# const ort = require('onnxruntime-node');
# const fs = require('fs');
#
# async function runModel() {
#     console.log("🚀 تحميل النموذج...");
#
#     // تحميل النموذج
#     const session = await ort.InferenceSession.create("Xenova/Qwen1.5-1.8B-Chat");
#
#     // إدخال بيانات عشوائية (حسب احتياجات النموذج)
#     const inputTensor = new ort.Tensor("float32", new Float32Array([0.5, 0.5, 0.5]), [1, 3]);
#
#     // تنفيذ النموذج
#     const results = await session.run({ input: inputTensor });
#
#     console.log("✅ النتائج:", results);
# }
#
# runModel().catch(console.error);
# Out:
# 🚀 تحميل النموذج...
# Error: Load model from Xenova/Qwen1.5-1.8B-Chat failed:Load model Xenova/Qwen1.5-1.8B-Chat failed. File doesn't exist
#     at new OnnxruntimeSessionHandler (/content/node_modules/onnxruntime-node/dist/backend.js:24:92)
#     at Immediate.<anonymous> (/content/node_modules/onnxruntime-node/dist/backend.js:64:29)
#     at process.processImmediate (node:internal/timers:476:21)

# %%
from huggingface_hub import hf_hub_download

model_path = hf_hub_download(
    repo_id="onnx-community/Qwen2.5-0.5B-Instruct-ONNX-MHA",
    filename="model.onnx",
    cache_dir="./qwen_model"
)

print(f"Model downloaded to: {model_path}")

# %%
const ort = require('onnxruntime-node');
const fs = require('fs');

(async () => {
  // ... (rest of your code)

  // Update the model path:
  const modelPath = './qwen_model/model.onnx';

  // ... (rest of your code)
})();

# %%
# %%script node
#
# const ort = require('onnxruntime-node');
# const fs = require('fs');
#
# (async () => {
#     console.log("🚀 بدء تشغيل النموذج...");
#
#     // تحقق من وجود الملف
#     const modelPath = "./gpt2_onnx/model.onnx";
#     if (!fs.existsSync(modelPath)) {
#         console.error(`❌ خطأ: الملف غير موجود في ${modelPath}`);
#         return;
#     }
#
#     console.log("⏳ تحميل النموذج...");
#     const session = await ort.InferenceSession.create(modelPath);
#
#     console.log("✍️ إدخال النص...");
#     const prompt = "Once upon a time,";
#
#     console.log("⚡ توليد النص...");
#     const inputTensor = new ort.Tensor("float32", new Float32Array([prompt.length]), [1, prompt.length]);
#
#     const outputs = await session.run({ input_ids: inputTensor });
#
#     console.log("✅ النص الناتج:");
#     console.log(outputs);
# })();
# Out:
# 🚀 بدء تشغيل النموذج...
# ⏳ تحميل النموذج...
# ✍️ إدخال النص...
# ⚡ توليد النص...
# /content/node_modules/onnxruntime-common/dist/cjs/tensor-impl.js:226
#                 throw new Error(`Tensor's size(${size}) does not match data length(${this.cpuData.length}).`);
#                       ^
#
# Error: Tensor's size(17) does not match data length(1).
#     at new Tensor (/content/node_modules/onnxruntime-common/dist/cjs/tensor-impl.js:226:23)
#     at [stdin]:22:25
#
# Node.js v18.20.5
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-5-12e7c1e29df1> in <cell line: 0>()
# ----> 1 get_ipython().run_cell_magic('script', 'node', '\nconst ort = require(\'onnxruntime-node\');\nconst fs = require(\'fs\');\n\n(async () => {\n    console.log("🚀 بدء تشغيل النموذج...");\n\n    // تحقق من وجود الملف\n    const modelPath = "./gpt2_onnx/model.onnx";\n    if (!fs.existsSync(modelPath)) {\n        console.error(`❌ خطأ: الملف غير موجود في ${modelPath}`);\n        return;\n    }\n\n    console.log("⏳ تحميل النموذج...");\n    const session = await ort.InferenceSession.create(modelPath);\n\n    console.log("✍️ إدخال النص...");\n    const prompt = "Once upon a time,";\n\n    console.log("⚡ توليد النص...");\n    const inputTensor = new ort.Tensor("float32", new Float32Array([prompt.length]), [1, prompt.length]);\n\n    const outputs = await session.run({ input_ids: inputTensor });\n\n    console.log("✅ النص الناتج:");\n    console.log(outputs);\n})();\n')
#
# /usr/local/lib/python3.11/dist-packages/google/colab/_shell.py in run_cell_magic(self, magic_name, line, cell)
#     332     if line and not cell:
#     333       cell = ' '
# --> 334     return super().run_cell_magic(magic_name, line, cell)
#     335
#     336
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2471             with self.builtin_trap:
#    2472                 args = (magic_arg_s, cell)
# -> 2473                 result = fn(*args, **kwargs)
#    2474             return result
#    2475
#
# <decorator-gen-103> in shebang(self, line, cell)
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/magics/script.py in shebang(self, line, cell)
#     243             sys.stderr.flush()
#     244         if args.raise_error and p.returncode!=0:
# --> 245             raise CalledProcessError(p.returncode, cell, output=out, stderr=err)
#     246
#     247     def _run_script(self, p, cell, to_close):
#
# CalledProcessError: Command 'b'\nconst ort = require(\'onnxruntime-node\');\nconst fs = require(\'fs\');\n\n(async () => {\n    console.log("\xf0\x9f\x9a\x80 \xd8\xa8\xd8\xaf\xd8\xa1 \xd8\xaa\xd8\xb4\xd8\xba\xd9\x8a\xd9\x84 \xd8\xa7\xd9\x84\xd9\x86\xd9\x85\xd9\x88\xd8\xb0\xd8\xac...");\n\n    // \xd8\xaa\xd8\xad\xd9\x82\xd9\x82 \xd9\x85\xd9\x86 \xd9\x88\xd8\xac\xd9\x88\xd8\xaf \xd8\xa7\xd9\x84\xd9\x85\xd9\x84\xd9\x81\n    const modelPath = "./gpt2_onnx/model.onnx";\n    if (!fs.existsSync(modelPath)) {\n        console.error(`\xe2\x9d\x8c \xd8\xae\xd8\xb7\xd8\xa3: \xd8\xa7\xd9\x84\xd9\x85\xd9\x84\xd9\x81 \xd8\xba\xd9\x8a\xd8\xb1 \xd9\x85\xd9\x88\xd8\xac\xd9\x88\xd8\xaf \xd9\x81\xd9\x8a ${modelPath}`);\n        return;\n    }\n\n    console.log("\xe2\x8f\xb3 \xd8\xaa\xd8\xad\xd9\x85\xd9\x8a\xd9\x84 \xd8\xa7\xd9\x84\xd9\x86\xd9\x85\xd9\x88\xd8\xb0\xd8\xac...");\n    const session = await ort.InferenceSession.create(modelPath);\n\n    console.log("\xe2\x9c\x8d\xef\xb8\x8f \xd8\xa5\xd8\xaf\xd8\xae\xd8\xa7\xd9\x84 \xd8\xa7\xd9\x84\xd9\x86\xd8\xb5...");\n    const prompt = "Once upon a time,";\n\n    console.log("\xe2\x9a\xa1 \xd8\xaa\xd9\x88\xd9\x84\xd9\x8a\xd8\xaf \xd8\xa7\xd9\x84\xd9\x86\xd8\xb5...");\n    const inputTensor = new ort.Tensor("float32", new Float32Array([prompt.length]), [1, prompt.length]);\n\n    const outputs = await session.run({ input_ids: inputTensor });\n\n    console.log("\xe2\x9c\x85 \xd8\xa7\xd9\x84\xd9\x86\xd8\xb5 \xd8\xa7\xd9\x84\xd9\x86\...

# %%
const encoded = tokenizer.encode(prompt);
const inputIds = new ort.Tensor("int32", Int32Array.from(encoded.input_ids), [1, encoded.input_ids.length]);

# %%
# %%script node
#
# const ort = require('onnxruntime-node');
# const fs = require('fs');
#
# // تحميل مكتبة tokenizer (مثل @xenova/transformers)
# const { AutoTokenizer } = require('@xenova/transformers');
#
# (async () => {
#     console.log("🚀 بدء تشغيل النموذج...");
#
#     // تحقق من وجود النموذج
#     const modelPath = "/content/gpt2_onnx/model.onnx";
#     if (!fs.existsSync(modelPath)) {
#         console.error(`❌ خطأ: الملف غير موجود في ${modelPath}`);
#         return;
#     }
#
#     console.log("⏳ تحميل النموذج...");
#     const session = await ort.InferenceSession.create(modelPath);
#
#     console.log("⏳ تحميل التوكنرايزر...");
#     const tokenizer = await AutoTokenizer.from_pretrained("/content/gpt2_onnx/model.onnx");
#
#     console.log("✍️ إدخال النص...");
#     const prompt = "Once upon a time,";
#
#     console.log("🔢 ترميز النص...");
#     const encoded = tokenizer.encode(prompt);
#     const inputIds = new ort.Tensor("int32", Int32Array.from(encoded.input_ids), [1, encoded.input_ids.length]);
#
#     console.log("⚡ تشغيل النموذج...");
#     const outputs = await session.run({ input_ids: inputIds });
#
#     console.log("✅ النص الناتج:");
#     console.log(outputs);
# })();
# Out:
# node:internal/modules/cjs/loader:1419
#       throw err;
#       ^
#
# Error [ERR_REQUIRE_ESM]: require() of ES Module /content/node_modules/@xenova/transformers/src/transformers.js from /content/[stdin] not supported.
# Instead change the require of transformers.js in /content/[stdin] to a dynamic import() which is available in all CommonJS modules.
#     at [stdin]:6:27
#     at [stdin]-wrapper:6:24
#     at Socket.emit (node:events:529:35) {
#   code: 'ERR_REQUIRE_ESM'
# }
#
# Node.js v18.20.5
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-7-4e39f677f3ff> in <cell line: 0>()
# ----> 1 get_ipython().run_cell_magic('script', 'node', '\nconst ort = require(\'onnxruntime-node\');\nconst fs = require(\'fs\');\n\n// تحميل مكتبة tokenizer (مثل @xenova/transformers)\nconst { AutoTokenizer } = require(\'@xenova/transformers\');\n\n(async () => {\n    console.log("🚀 بدء تشغيل النموذج...");\n\n    // تحقق من وجود النموذج\n    const modelPath = "/content/gpt2_onnx/model.onnx";\n    if (!fs.existsSync(modelPath)) {\n        console.error(`❌ خطأ: الملف غير موجود في ${modelPath}`);\n        return;\n    }\n\n    console.log("⏳ تحميل النموذج...");\n    const session = await ort.InferenceSession.create(modelPath);\n\n    console.log("⏳ تحميل التوكنرايزر...");\n    const tokenizer = await AutoTokenizer.from_pretrained("/content/gpt2_onnx/model.onnx");\n\n    console.log("✍️ إدخال النص...");\n    const prompt = "Once upon a time,";\n\n    console.log("🔢 ترميز النص...");\n    const encoded = tokenizer.encode(prompt);\n    const inputIds = new ort.Tensor("int32", Int32Array.from(encoded.input_ids), [1, encoded.input_ids.length]);\n\n    console.log("⚡ تشغيل النموذج...");\n    const outputs = await session.run({ input_ids: inputIds });\n\n    console.log("✅ النص الناتج:");\n    console.log(outputs);\n})();\n')
#
# /usr/local/lib/python3.11/dist-packages/google/colab/_shell.py in run_cell_magic(self, magic_name, line, cell)
#     332     if line and not cell:
#     333       cell = ' '
# --> 334     return super().run_cell_magic(magic_name, line, cell)
#     335
#     336
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2471             with self.builtin_trap:
#    2472                 args = (magic_arg_s, cell)
# -> 2473                 result = fn(*args, **kwargs)
#    2474             return result
#    2475
#
# <decorator-gen-103> in shebang(self, line, cell)
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/magics/script.py in shebang(self, line, cell)
#     243             sys.stderr.flush()
#     244         if args.raise_error and p.returncode!=0:
# --> 245             raise CalledProcessError(p.returncode, cell, output=out, stderr=err)
#     246
#     247     def _run_script(self, p, cell, to_close):
#
# CalledProcessError: Command 'b'\nconst ort = require(\'onnxruntime-node\');\nconst fs = require(\'fs\');\n\n// \xd8\xaa\xd8\xad\xd9\x85\xd9\x8a\xd9\x84 \xd9\x85\xd9\x83\xd8\xaa\xd8\xa8\xd8\xa9 tokenizer (\xd9\x85\xd8\xab\xd9\x84 @xenova/transformers)\nconst { AutoTokenizer } = require(\'@xenova/transformers\');\n\n(async () => {\n    console.log("\xf0\x9f\x9a\x80 \xd8\xa8\xd8\xaf\xd8\xa1 \xd8\xaa\xd8\xb4\xd8\xba\xd9\x8a\xd9\x84 \xd8\xa7\xd9\x84\xd9\x86\xd9\x85\xd9\x88\xd8\xb0\xd8\xac...");\n\n    // \xd8\xaa\xd8\xad\xd9\x82\xd9\x82 \xd9\x85\xd9\x86 \xd9\x88\xd8\xac\xd9\x88\xd8\xaf \xd8\xa7\xd9\x84\xd9\x86\xd9\x85\xd9\x88\xd8\xb0\xd8\xac\n    const modelPath = "/content/gpt2_onnx/model.onnx";\n    if (!fs.existsSync(modelPath)) {\n        console.error(`\xe2\x9d\x8c \xd8\xae\xd8\xb7\xd8\xa3: \xd8\xa7\xd9\x84\xd9\x85\xd9\x84\xd9\x81 \xd8\xba\xd9\x8a\xd8\xb1 \xd9\x85\xd9\x88\xd8\xac\xd9\x88\xd8\xaf \xd9\x81\xd9\x8a ${modelPath}`);\n        return;\n    }\n\n    console.log("\xe2\x8f\xb3 \xd8\xaa\xd8\xad\xd9\x85\xd9\x8a\xd9\x84 \xd8\xa7\xd9\x84\xd9\x86\xd9\x85\xd9\x88\xd8\xb0\xd8\xac...");\n    const session = await ort.InferenceSession.create(modelPath);\n\n    console.log("\xe2\x8f\xb3 \xd8\xaa\xd8\xad\xd9\x85\xd9\x8a\xd9\x84 \xd8\xa7\xd9\x84\xd8\xaa\xd9\x88\xd9\x83\xd9\x86\xd8\xb1\xd8\xa7\xd9\x8a\xd8\xb2\xd8\xb1...");\n    const tokenizer = await AutoTokenizer.from_pretrained("/content/gpt2_onnx/model.onnx");\n\n    console.log("\xe2\x9c\x8d\xef\xb8\x8f \xd8\xa5\...

# %%
# %%script node
#
# (async () => {
#     console.log("🚀 بدء تشغيل النموذج...");
#
#     // استيراد مكتبة @xenova/transformers ديناميكيًا
#     const { pipeline } = await import('@xenova/transformers');
#
#     console.log("⏳ تحميل النموذج...");
#     const pipe = await pipeline('text-generation', '/content/gpt2_onnx');
#
#
#     console.log("✍️ إدخال النص...");
#     const prompt = "Once upon a time,";
#
#     console.log("⚡ توليد النص...");
#     const generatedText = await pipe(prompt, { max_new_tokens: 50 });
#
#     console.log("✅ النص الناتج:");
#     console.log(generatedText[0].generated_text);
# })();
# Out:
# 🚀 بدء تشغيل النموذج...
# node:internal/errors:496
#     ErrorCaptureStackTrace(err);
#     ^
#
# Error [ERR_MODULE_NOT_FOUND]: Cannot find package '@xenova/transformers' imported from /content/[stdin]
#     at new NodeError (node:internal/errors:405:5)
#     at packageResolve (node:internal/modules/esm/resolve:916:9)
#     at moduleResolve (node:internal/modules/esm/resolve:973:20)
#     at defaultResolve (node:internal/modules/esm/resolve:1206:11)
#     at ModuleLoader.defaultResolve (node:internal/modules/esm/loader:404:12)
#     at ModuleLoader.resolve (node:internal/modules/esm/loader:373:25)
#     at ModuleLoader.getModuleJob (node:internal/modules/esm/loader:250:38)
#     at ModuleLoader.import (node:internal/modules/esm/loader:336:34)
#     at importModuleDynamically (node:internal/process/execution:87:29)
#     at importModuleDynamicallyWrapper (node:internal/vm/module:432:21) {
#   code: 'ERR_MODULE_NOT_FOUND'
# }
#
# Node.js v18.20.5
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-1-20ab2f7e7f71> in <cell line: 0>()
# ----> 1 get_ipython().run_cell_magic('script', 'node', '\n(async () => {\n    console.log("🚀 بدء تشغيل النموذج...");\n\n    // استيراد مكتبة @xenova/transformers ديناميكيًا\n    const { pipeline } = await import(\'@xenova/transformers\');\n\n    console.log("⏳ تحميل النموذج...");\n    const pipe = await pipeline(\'text-generation\', \'/content/gpt2_onnx\');\n\n\n    console.log("✍️ إدخال النص...");\n    const prompt = "Once upon a time,";\n\n    console.log("⚡ توليد النص...");\n    const generatedText = await pipe(prompt, { max_new_tokens: 50 });\n\n    console.log("✅ النص الناتج:");\n    console.log(generatedText[0].generated_text);\n})();\n')
#
# /usr/local/lib/python3.11/dist-packages/google/colab/_shell.py in run_cell_magic(self, magic_name, line, cell)
#     332     if line and not cell:
#     333       cell = ' '
# --> 334     return super().run_cell_magic(magic_name, line, cell)
#     335
#     336
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2471             with self.builtin_trap:
#    2472                 args = (magic_arg_s, cell)
# -> 2473                 result = fn(*args, **kwargs)
#    2474             return result
#    2475
#
# <decorator-gen-103> in shebang(self, line, cell)
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/magics/script.py in shebang(self, line, cell)
#     243             sys.stderr.flush()
#     244         if args.raise_error and p.returncode!=0:
# --> 245             raise CalledProcessError(p.returncode, cell, output=out, stderr=err)
#     246
#     247     def _run_script(self, p, cell, to_close):
#
# CalledProcessError: Command 'b'\n(async () => {\n    console.log("\xf0\x9f\x9a\x80 \xd8\xa8\xd8\xaf\xd8\xa1 \xd8\xaa\xd8\xb4\xd8\xba\xd9\x8a\xd9\x84 \xd8\xa7\xd9\x84\xd9\x86\xd9\x85\xd9\x88\xd8\xb0\xd8\xac...");\n\n    // \xd8\xa7\xd8\xb3\xd8\xaa\xd9\x8a\xd8\xb1\xd8\xa7\xd8\xaf \xd9\x85\xd9\x83\xd8\xaa\xd8\xa8\xd8\xa9 @xenova/transformers \xd8\xaf\xd9\x8a\xd9\x86\xd8\xa7\xd9\x85\xd9\x8a\xd9\x83\xd9\x8a\xd9\x8b\xd8\xa7\n    const { pipeline } = await import(\'@xenova/transformers\');\n\n    console.log("\xe2\x8f\xb3 \xd8\xaa\xd8\xad\xd9\x85\xd9\x8a\xd9\x84 \xd8\xa7\xd9\x84\xd9\x86\xd9\x85\xd9\x88\xd8\xb0\xd8\xac...");\n    const pipe = await pipeline(\'text-generation\', \'/content/gpt2_onnx\');\n\n\n    console.log("\xe2\x9c\x8d\xef\xb8\x8f \xd8\xa5\xd8\xaf\xd8\xae\xd8\xa7\xd9\x84 \xd8\xa7\xd9\x84\xd9\x86\xd8\xb5...");\n    const prompt = "Once upon a time,";\n\n    console.log("\xe2\x9a\xa1 \xd8\xaa\xd9\x88\xd9\x84\xd9\x8a\xd8\xaf \xd8\xa7\xd9\x84\xd9\x86\xd8\xb5...");\n    const generatedText = await pipe(prompt, { max_new_tokens: 50 });\n\n    console.log("\xe2\x9c\x85 \xd8\xa7\xd9\x84\xd9\x86\xd8\xb5 \xd8\xa7\xd9\x84\xd9\x86\xd8\xa7\xd8\xaa\xd8\xac:");\n    console.log(generatedText[0].generated_text);\n})();\n'' returned non-zero exit status 1.
